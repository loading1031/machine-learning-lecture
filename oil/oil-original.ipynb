# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
train_X = pd.read_excel('train_x_data.xlsx')
train_y = pd.read_excel('train_y_data.xlsx')
test_X = pd.read_excel('test_x_data.xlsx')
test_y = pd.read_excel('test_y_data.xlsx')

train_X
# Out:
#      Commodity       Date  Close Commodity.1     Date.1     Close.1  \
# 0        Cocoa 2018-01-02   1936      Coffee 2018-01-02  130.199997
# 1        Cocoa 2018-01-03   1907      Coffee 2018-01-03  128.600006
# 2        Cocoa 2018-01-04   1905      Coffee 2018-01-04  129.550003
# 3        Cocoa 2018-01-05   1895      Coffee 2018-01-05  128.449997
# 4        Cocoa 2018-01-08   1914      Coffee 2018-01-08  125.150002
# ...        ...        ...    ...         ...        ...         ...
# 1342     Cocoa 2023-06-26   3206      Coffee 2023-06-26  167.949997
# 1343     Cocoa 2023-06-27   3212      Coffee 2023-06-27  169.449997
# 1344     Cocoa 2023-06-28   3292      Coffee 2023-06-28  165.649994
# 1345     Cocoa 2023-06-29   3218      Coffee 2023-06-29  163.600006
# 1346     Cocoa 2023-06-30   3318      Coffee 2023-06-30  161.000000
#
#      Commodity.2     Date.2    Close.2 Commodity.3  ... Close.13  \
# 0         Cotton 2018-01-02  77.500000       Sugar  ...    3.056
# 1         Cotton 2018-01-03  78.110001       Sugar  ...    3.008
# 2         Cotton 2018-01-04  79.250000       Sugar  ...    2.880
# 3         Cotton 2018-01-05  78.010002       Sugar  ...    2.795
# 4         Cotton 2018-01-08  78.139999       Sugar  ...    2.835
# ...          ...        ...        ...         ...  ...      ...
# 1342      Cotton 2023-06-26  77.070000       Sugar  ...    2.791
# 1343      Cotton 2023-06-27  77.639999       Sugar  ...    2.763
# 1344      Cotton 2023-06-28  80.120003       Sugar  ...    2.603
# 1345      Cotton 2023-06-29  81.250000       Sugar  ...    2.701
# 1346      Cotton 2023-06-30  82.839996       Sugar  ...    2.798
#
#        Commodity.14    Date.14    Close.14  Commodity.15    Date.15  \
# 0     Feeder Cattle 2018-01-02  149.524994     Lean Hogs 2018-01-02
# 1     Feeder Cattle 2018-01-03  149.375000     Lean Hogs 2018-01-03
# 2     Feeder Cattle 2018-01-04  149.024994     Lean Hogs 2018-01-04
# 3     Feeder Cattle 2018-01-05  146.625000     Lean Hogs 2018-01-05
# 4     Feeder Cattle 2018-01-08  146.449997     Lean Hogs 2018-01-08
# ...             ...        ...         ...           ...        ...
# 1342  Feeder Cattle 2023-06-26  233.675003     Lean Hogs 2023-06-26
# 1343  Feeder Cattle 2023-06-27  238.500000     Lean Hogs 2023-06-27
# 1344  Feeder Cattle 2023-06-28  240.250000     Lean Hogs 2023-06-28
# 1345  Feeder Cattle 2023-06-29  242.375000     Lean Hogs 2023-06-29
# 1346  Feeder Cattle 2023-06-30  247.574997     Lean Hogs 2023-06-30
#
#        Close.15  Commodity.16    Date.16    Close.16
# 0     70.724998   Live Cattle 2018-01-02  123.349998
# 1     71.050003   Live Cattle 2018-01-03  122.949997
# 2     71.375000   Live Cattle 2018-01-04  122.250000
# 3     71.425003   Live Cattle 2018-01-05  119.250000
# 4     72.974998   Live Cattle 2018-01-08  117.224998
# ...         ...           ...        ...         ...
# 1342  93.400002   Live Cattle 2023-06-26  177.699997
# 1343  94.125000   Live Cattle 2023-06-27  179.300003
# 1344  94.275002   Live Cattle 2023-06-28  179.625000
# 1345  95.449997   Live Cattle 2023-06-29  179.750000
# 1346  95.650002   Live Cattle 2023-06-30  181.500000
#
# [1347 rows x 51 columns]

# %%
# 결측치 확인
print(train_X.isnull().sum())
print(train_y.isnull().sum())
print(test_X.isnull().sum())
print(test_y.isnull().sum())
# Out:
# Commodity       0
# Date            0
# Close           0
# Commodity.1     0
# Date.1          0
# Close.1         0
# Commodity.2     0
# Date.2          0
# Close.2         0
# Commodity.3     0
# Date.3          0
# Close.3         0
# Commodity.4     0
# Date.4          0
# Close.4         0
# Commodity.5     0
# Date.5          0
# Close.5         0
# Commodity.6     0
# Date.6          0
# Close.6         0
# Commodity.7     0
# Date.7          0
# Close.7         0
# Commodity.8     0
# Date.8          0
# Close.8         0
# Commodity.9     0
# Date.9          0
# Close.9         0
# Commodity.10    0
# Date.10         0
# Close.10        0
# Commodity.11    0
# Date.11         0
# Close.11        0
# Commodity.12    0
# Date.12         0
# Close.12        0
# Commodity.13    0
# Date.13         0
# Close.13        0
# Commodity.14    0
# Date.14         0
# Close.14        0
# Commodity.15    0
# Date.15         0
# Close.15        0
# Commodity.16    0
# Date.16         0
# Close.16        0
# dtype: int64
# Commodity    0
# Date         0
# Close        0
# dtype: int64
# Commodity       0
# Date            0
# Close           0
# Commodity.1     0
# Date.1          0
# Close.1         0
# Commodity.2     0
# Date.2          0
# Close.2         0
# Commodity.3     0
# Date.3          0
# Close.3         0
# Commodity.4     0
# Date.4          0
# Close.4         0
# Commodity.5     0
# Date.5          0
# Close.5         0
# Commodity.6     0
# Date.6          0
# Close.6         0
# Commodity.7     0
# Date.7          0
# Close.7         0
# Commodity.8     0
# Date.8          0
# Close.8         0
# Commodity.9     0
# Date.9          0
# Close.9         0
# Commodity.10    0
# Date.10         0
# Close.10        0
# Commodity.11    0
# Date.11         0
# Close.11        0
# Commodity.12    0
# Date.12         0
# Close.12        0
# Commodity.13    0
# Date.13         0
# Close.13        0
# Commodity.14    0
# Date.14         0
# Close.14        0
# Commodity.15    0
# Date.15         0
# Close.15        0
# Commodity.16    0
# Date.16         0
# Close.16        0
# dtype: int64
# Commodity    0
# Date         0
# Close        0
# dtype: int64

# %%
# 3개 단위로 나누기 (예: 'Commodity', 'Date', 'Close')
grouped_train_X_cols = [train_X.columns[i:i+3] for i in range(0, len(train_X.columns), 3)]
grouped_test_X_cols = [test_X.columns[i:i+3] for i in range(0, len(test_X.columns), 3)]
grouped_train_y_cols = [train_y.columns[i:i+3] for i in range(0, len(train_y.columns), 3)]
grouped_test_y_cols = [test_y.columns[i:i+3] for i in range(0, len(test_y.columns), 3)]
grouped_train_X_cols
# Out:
# [Index(['Commodity', 'Date', 'Close'], dtype='object'),
#  Index(['Commodity.1', 'Date.1', 'Close.1'], dtype='object'),
#  Index(['Commodity.2', 'Date.2', 'Close.2'], dtype='object'),
#  Index(['Commodity.3', 'Date.3', 'Close.3'], dtype='object'),
#  Index(['Commodity.4', 'Date.4', 'Close.4'], dtype='object'),
#  Index(['Commodity.5', 'Date.5', 'Close.5'], dtype='object'),
#  Index(['Commodity.6', 'Date.6', 'Close.6'], dtype='object'),
#  Index(['Commodity.7', 'Date.7', 'Close.7'], dtype='object'),
#  Index(['Commodity.8', 'Date.8', 'Close.8'], dtype='object'),
#  Index(['Commodity.9', 'Date.9', 'Close.9'], dtype='object'),
#  Index(['Commodity.10', 'Date.10', 'Close.10'], dtype='object'),
#  Index(['Commodity.11', 'Date.11', 'Close.11'], dtype='object'),
#  Index(['Commodity.12', 'Date.12', 'Close.12'], dtype='object'),
#  Index(['Commodity.13', 'Date.13', 'Close.13'], dtype='object'),
#  Index(['Commodity.14', 'Date.14', 'Close.14'], dtype='object'),
#  Index(['Commodity.15', 'Date.15', 'Close.15'], dtype='object'),
#  Index(['Commodity.16', 'Date.16', 'Close.16'], dtype='object')]

# %%
# Long Format으로 변환
long_train_X_data = []
long_test_X_data = []

for group in grouped_train_X_cols:
    temp = train_X[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_train_X_data.append(temp)

# 모든 그룹을 하나로 합치기
long_train_X = pd.concat(long_train_X_data, ignore_index=True)

for group in grouped_test_X_cols:
    temp = test_X[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_test_X_data.append(temp)

# 모든 그룹을 하나로 합치기
long_test_X = pd.concat(long_test_X_data, ignore_index=True)

# 결과 확인
long_train_X.head()
# Out:
#   Commodity       Date   Close
# 0     Cocoa 2018-01-02  1936.0
# 1     Cocoa 2018-01-03  1907.0
# 2     Cocoa 2018-01-04  1905.0
# 3     Cocoa 2018-01-05  1895.0
# 4     Cocoa 2018-01-08  1914.0

# %%
# Long Format으로 변환
long_train_y_data = []
long_test_y_data = []

for group in grouped_train_y_cols:
    temp = train_y[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_train_y_data.append(temp)

# 모든 그룹을 하나로 합치기
long_train_y = pd.concat(long_train_y_data, ignore_index=True)

for group in grouped_test_y_cols:
    temp = test_y[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_test_y_data.append(temp)

# 모든 그룹을 하나로 합치기
long_test_y = pd.concat(long_test_y_data, ignore_index=True)

# 결과 확인
long_train_y.head()
# Out:
#          Commodity       Date      Close
# 0  Brent Crude Oil 2018-01-02  66.570000
# 1  Brent Crude Oil 2018-01-03  67.839996
# 2  Brent Crude Oil 2018-01-04  68.070000
# 3  Brent Crude Oil 2018-01-05  67.620003
# 4  Brent Crude Oil 2018-01-08  67.779999

# %%
# 날짜 형식 변환
long_train_X['Date'] = pd.to_datetime(long_train_X['Date'])
long_test_X['Date'] = pd.to_datetime(long_test_X['Date'])
long_train_y['Date'] = pd.to_datetime(long_train_y['Date'])
long_test_y['Date'] = pd.to_datetime(long_test_y['Date'])

# 중복 제거
long_train_X = long_train_X.drop_duplicates()
long_test_X = long_test_X.drop_duplicates()
long_train_y = long_train_y.drop_duplicates()
long_test_y = long_test_y.drop_duplicates()

# 결과 확인
long_train_X
# Out:
#          Commodity       Date        Close
# 0            Cocoa 2018-01-02  1936.000000
# 1            Cocoa 2018-01-03  1907.000000
# 2            Cocoa 2018-01-04  1905.000000
# 3            Cocoa 2018-01-05  1895.000000
# 4            Cocoa 2018-01-08  1914.000000
# ...            ...        ...          ...
# 22894  Live Cattle 2023-06-26   177.699997
# 22895  Live Cattle 2023-06-27   179.300003
# 22896  Live Cattle 2023-06-28   179.625000
# 22897  Live Cattle 2023-06-29   179.750000
# 22898  Live Cattle 2023-06-30   181.500000
#
# [22899 rows x 3 columns]

# %%
# Date 기준 정렬
long_train_X = long_train_X.sort_values(by='Date')
long_test_X = long_train_X.sort_values(by='Date')
long_train_y = long_train_y.sort_values(by='Date')
long_test_y = long_train_y.sort_values(by='Date')

# 결과 확인
long_train_X
# Out:
#            Commodity       Date        Close
# 0              Cocoa 2018-01-02  1936.000000
# 16164         Silver 2018-01-02    17.121000
# 21552    Live Cattle 2018-01-02   123.349998
# 1347          Coffee 2018-01-02   130.199997
# 2694          Cotton 2018-01-02    77.500000
# ...              ...        ...          ...
# 2693          Coffee 2023-06-30   161.000000
# 20204  Feeder Cattle 2023-06-30   247.574997
# 21551      Lean Hogs 2023-06-30    95.650002
# 8081      Rough Rice 2023-06-30  1805.500000
# 22898    Live Cattle 2023-06-30   181.500000
#
# [22899 rows x 3 columns]

# %%
# Date를 인덱스로 설정하고 Pivot
pivot_train_X = long_train_X.pivot(index='Date', columns='Commodity', values='Close')
pivot_test_X = long_test_X.pivot(index='Date', columns='Commodity', values='Close')
pivot_train_y = long_train_y.pivot(index='Date', columns='Commodity', values='Close')
pivot_test_y = long_test_y.pivot(index='Date', columns='Commodity', values='Close')

# MultiIndex 제거
pivot_train_X.columns.name = None
pivot_train_X = pivot_train_X.reset_index()
pivot_train_y.columns.name = None
pivot_train_y = pivot_train_y.reset_index()
pivot_test_X.columns.name = None
pivot_test_X = pivot_test_X.reset_index()
pivot_test_y.columns.name = None
pivot_test_y = pivot_test_y.reset_index()

# 결과 확인
pivot_train_X.head()
# Out:
#         Date   Cocoa      Coffee  Copper     Cotton  Feeder Cattle  \
# 0 2018-01-02  1936.0  130.199997  3.2560  77.500000     149.524994
# 1 2018-01-03  1907.0  128.600006  3.2370  78.110001     149.375000
# 2 2018-01-04  1905.0  129.550003  3.2425  79.250000     149.024994
# 3 2018-01-05  1895.0  128.449997  3.2070  78.010002     146.625000
# 4 2018-01-08  1914.0  125.150002  3.2010  78.139999     146.449997
#
#           Gold  Kansas Wheat  Lean Hogs  Live Cattle  Natural Gas    Oats  \
# 0  1313.699951        434.75  70.724998   123.349998        3.056  242.50
# 1  1316.199951        441.00  71.050003   122.949997        3.008  244.50
# 2  1319.400024        439.75  71.375000   122.250000        2.880  245.75
# 3  1320.300049        437.50  71.425003   119.250000        2.795  248.50
# 4  1318.599976        433.25  72.974998   117.224998        2.835  250.00
#
#      Palladium    Platinum  Rough Rice     Silver  Soybeans  Sugar
# 0  1090.000000  943.799988      1153.5  17.121000    955.00  15.33
# 1  1086.000000  957.799988      1141.0  17.184999    959.75  15.31
# 2  1097.400024  966.099976      1147.5  17.188999    959.25  15.25
# 3  1084.849976  971.200012      1156.5  17.205000    961.50  15.08
# 4  1098.550049  972.299988      1164.5  17.063999    958.25  14.78

# %%
print(pivot_train_X.columns)
print(pivot_test_X.columns)
print(pivot_train_y.columns)
print(pivot_test_y.columns)
pivot_train_y.head()
# Out:
# Index(['Date', 'Cocoa', 'Coffee', 'Copper', 'Cotton', 'Feeder Cattle', 'Gold',
#        'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats',
#        'Palladium', 'Platinum', 'Rough Rice', 'Silver', 'Soybeans', 'Sugar'],
#       dtype='object')
# Index(['Date', 'Cocoa', 'Coffee', 'Copper', 'Cotton', 'Feeder Cattle', 'Gold',
#        'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats',
#        'Palladium', 'Platinum', 'Rough Rice', 'Silver', 'Soybeans', 'Sugar'],
#       dtype='object')
# Index(['Date', 'Brent Crude Oil'], dtype='object')
# Index(['Date', 'Brent Crude Oil'], dtype='object')
#         Date  Brent Crude Oil
# 0 2018-01-02        66.570000
# 1 2018-01-03        67.839996
# 2 2018-01-04        68.070000
# 3 2018-01-05        67.620003
# 4 2018-01-08        67.779999

# %%
pivot_test_X.reset_index(inplace=True)
pivot_train_X.reset_index(inplace=True)
pivot_test_y.reset_index(inplace=True)
pivot_train_y.reset_index(inplace=True)

pivot_train_X.drop('Date',axis=1, inplace=True)
pivot_test_X.drop('Date',axis=1, inplace=True)
pivot_train_y.drop('Date',axis=1, inplace=True)
pivot_test_y.drop('Date',axis=1, inplace=True)

pivot_train_y.head()
# Out:
#    index  Brent Crude Oil
# 0      0        66.570000
# 1      1        67.839996
# 2      2        68.070000
# 3      3        67.620003
# 4      4        67.779999

# %%
# 'index' 열 삭제
pivot_train_X.drop('index', axis=1, inplace=True)
pivot_test_X.drop('index', axis=1, inplace=True)
pivot_train_y.drop('index', axis=1, inplace=True)
pivot_test_y.drop('index', axis=1, inplace=True)

# 결과 확인
pivot_train_y.head()
# Out:
#    Brent Crude Oil
# 0        66.570000
# 1        67.839996
# 2        68.070000
# 3        67.620003
# 4        67.779999

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 데이터 표준화
pivot_train_X_scaled = scaler.fit_transform(pivot_train_X)
pivot_test_X_scaled = scaler.transform(pivot_test_X)
pivot_train_y_scaled = scaler.fit_transform(pivot_train_y)
pivot_test_y_scaled = scaler.transform(pivot_test_y)

# 표준화된 결과 확인
print(pivot_train_X_scaled[:5])  # 첫 5개 행 출력
# Out:
# [[-2.27881345 -0.31896259 -0.19448044 -0.30428429 -0.19937907 -1.28457483
#   -0.95273171 -0.350508   -0.05303156 -0.25792155 -0.90395425 -1.35633492
#    0.00694284 -0.89151216 -0.72490451 -0.74203782 -0.065912  ]
#  [-2.40155207 -0.35243856 -0.22114479 -0.27476546 -0.20632476 -1.27468632
#   -0.92318337 -0.33254535 -0.07342589 -0.28513215 -0.89014585 -1.36385248
#    0.13323774 -0.9435787  -0.70979497 -0.72563201 -0.07108287]
#  [-2.4100168  -0.33256215 -0.21342607 -0.21959921 -0.22253229 -1.26202873
#   -0.92909304 -0.31458312 -0.10911567 -0.35769349 -0.8815156  -1.34242738
#    0.20811247 -0.9165041  -0.70885068 -0.72735893 -0.08659597]
#  [-2.45234046 -0.35557715 -0.26324623 -0.27960453 -0.33366747 -1.25846876
#   -0.93973044 -0.31181951 -0.26207253 -0.40587886 -0.86252905 -1.36601383
#    0.25412023 -0.87901619 -0.70507307 -0.71958776 -0.13054947]
#  [-2.3719255  -0.42462164 -0.27166659 -0.27331378 -0.34177124 -1.26519324
#   -0.95982332 -0.22615294 -0.36531849 -0.38320342 -0.85217275 -1.34026604
#    0.26404318 -0.8456936  -0.73836188 -0.73081279 -0.20811447]]

# %% [markdown]
# ## 윈도우 크기 결정

# %%
def create_windows(X, y, window_size):
    X_windows, y_windows = [], []
    for i in range(len(X) - window_size):
        X_windows.append(X[i:i + window_size])  # .iloc 대신 기본 인덱싱 사용
        y_windows.append(y[i + window_size])    # .iloc 대신 기본 인덱싱 사용
    return np.array(X_windows), np.array(y_windows)

# %%
# 윈도우 크기
window_size = 30

# Train 데이터 슬라이싱
X_train, y_train = create_windows(
    pivot_train_X_scaled,  
    pivot_train_y_scaled,  
    window_size
)

# Test 데이터 슬라이싱
X_test, y_test = create_windows(
    pivot_test_X_scaled,  
    pivot_test_y_scaled,  
    window_size
)

# 결과 확인
print(f"Train X Shape: {X_train.shape}, Train y Shape: {y_train.shape}")
print(f"Test X Shape: {X_test.shape}, Test y Shape: {y_test.shape}")
# Out:
# Train X Shape: (1317, 30, 17), Train y Shape: (1317, 1)
# Test X Shape: (1317, 30, 17), Test y Shape: (1317, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras import backend as K

# RMSE 정의
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# LSTM 모델 정의
model = Sequential([
    LSTM(64, activation='relu', input_shape=(window_size, X_train.shape[2]), return_sequences=True),
    Dropout(0.2),
    LSTM(64, activation='relu'),
    Dropout(0.2),
    Dense(y_train.shape[1])  # 타겟 변수 개수 (예: 1개면 Dense(1))
])

# 모델 컴파일 (loss에 rmse 사용)
model.compile(optimizer='adam', loss='mse', metrics=[rmse, 'mae'])

# %%
# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,  # 에포크 조정
    batch_size=128,  # 배치 크기 조정
    verbose=1
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 4s 93ms/step - loss: 0.4351 - rmse: 0.6337 - mae: 0.4965 - val_loss: 0.1381 - val_rmse: 0.3393 - val_mae: 0.2857
# Epoch 2/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1445 - rmse: 0.3742 - mae: 0.2871 - val_loss: 0.0839 - val_rmse: 0.2587 - val_mae: 0.2120
# Epoch 3/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0984 - rmse: 0.3117 - mae: 0.2403 - val_loss: 0.0622 - val_rmse: 0.2211 - val_mae: 0.1852
# Epoch 4/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0841 - rmse: 0.2829 - mae: 0.2137 - val_loss: 0.0465 - val_rmse: 0.1910 - val_mae: 0.1594
# Epoch 5/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0700 - rmse: 0.2606 - mae: 0.2001 - val_loss: 0.0410 - val_rmse: 0.1795 - val_mae: 0.1523
# Epoch 6/100
# 11/11 [==============================] - 0s 47ms/step - loss: 0.0635 - rmse: 0.2491 - mae: 0.1943 - val_loss: 0.0425 - val_rmse: 0.1878 - val_mae: 0.1576
# Epoch 7/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0567 - rmse: 0.2392 - mae: 0.1822 - val_loss: 0.0337 - val_rmse: 0.1687 - val_mae: 0.1387
# Epoch 8/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0575 - rmse: 0.2392 - mae: 0.1805 - val_loss: 0.0340 - val_rmse: 0.1719 - val_mae: 0.1428
# Epoch 9/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0559 - rmse: 0.2359 - mae: 0.1817 - val_loss: 0.0356 - val_rmse: 0.1736 - val_mae: 0.1433
# Epoch 10/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0546 - rmse: 0.2299 - mae: 0.1744 - val_loss: 0.0277 - val_rmse: 0.1536 - val_mae: 0.1268
# Epoch 11/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0501 - rmse: 0.2289 - mae: 0.1717 - val_loss: 0.0288 - val_rmse: 0.1564 - val_mae: 0.1295
# Epoch 12/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0539 - rmse: 0.2322 - mae: 0.1728 - val_loss: 0.0275 - val_rmse: 0.1592 - val_mae: 0.1270
# Epoch 13/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0509 - rmse: 0.2190 - mae: 0.1687 - val_loss: 0.0237 - val_rmse: 0.1433 - val_mae: 0.1152
# Epoch 14/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0412 - rmse: 0.2024 - mae: 0.1545 - val_loss: 0.0231 - val_rmse: 0.1426 - val_mae: 0.1137
# Epoch 15/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0396 - rmse: 0.1936 - mae: 0.1488 - val_loss: 0.0234 - val_rmse: 0.1468 - val_mae: 0.1138
# Epoch 16/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0386 - rmse: 0.1947 - mae: 0.1470 - val_loss: 0.0242 - val_rmse: 0.1449 - val_mae: 0.1154
# Epoch 17/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0411 - rmse: 0.2003 - mae: 0.1487 - val_loss: 0.0205 - val_rmse: 0.1322 - val_mae: 0.1035
# Epoch 18/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0412 - rmse: 0.2008 - mae: 0.1485 - val_loss: 0.0221 - val_rmse: 0.1378 - val_mae: 0.1082
# Epoch 19/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0354 - rmse: 0.1841 - mae: 0.1398 - val_loss: 0.0205 - val_rmse: 0.1300 - val_mae: 0.1029
# Epoch 20/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0373 - rmse: 0.1895 - mae: 0.1375 - val_loss: 0.0228 - val_rmse: 0.1381 - val_mae: 0.1079
# Epoch 21/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0363 - rmse: 0.1884 - mae: 0.1408 - val_loss: 0.0251 - val_rmse: 0.1460 - val_mae: 0.1172
# Epoch 22/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0423 - rmse: 0.2060 - mae: 0.1491 - val_loss: 0.0213 - val_rmse: 0.1359 - val_mae: 0.1073
# Epoch 23/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0355 - rmse: 0.1895 - mae: 0.1395 - val_loss: 0.0192 - val_rmse: 0.1298 - val_mae: 0.0986
# Epoch 24/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0345 - rmse: 0.1846 - mae: 0.1336 - val_loss: 0.0190 - val_rmse: 0.1282 - val_mae: 0.0997
# Epoch 25/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0333 - rmse: 0.1807 - mae: 0.1327 - val_loss: 0.0175 - val_rmse: 0.1230 - val_mae: 0.0946
# Epoch 26/100
# 11/11 [==============================] - 0s 47ms/step - loss: 0.0329 - rmse: 0.1795 - mae: 0.1311 - val_loss: 0.0182 - val_rmse: 0.1217 - val_mae: 0.0949
# Epoch 27/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0347 - rmse: 0.1833 - mae: 0.1323 - val_loss: 0.0209 - val_rmse: 0.1280 - val_mae: 0.1031
# Epoch 28/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0353 - rmse: 0.1848 - mae: 0.1337 - val_loss: 0.0191 - val_rmse: 0.1259 - val_mae: 0.1018
# Epoch 29/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0311 - rmse: 0.1736 - mae: 0.1285 - val_loss: 0.0189 - val_rmse: 0.1246 - val_mae: 0.0979
# Epoch 30/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0294 - rmse: 0.1714 - mae: 0.1252 - val_loss: 0.0153 - val_rmse: 0.1125 - val_mae: 0.0867
# Epoch 31/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0301 - rmse: 0.1712 - mae: 0.1266 - val_loss: 0.0172 - val_rmse: 0.1185 - val_mae: 0.0916
# Epoch 32/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0339 - rmse: 0.1830 - mae: 0.1310 - val_loss: 0.0172 - val_rmse: 0.1211 - val_mae: 0.0949
# Epoch 33/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0333 - rmse: 0.1824 - mae: 0.1313 - val_loss: 0.0165 - val_rmse: 0.1184 - val_mae: 0.0922
# Epoch 34/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0283 - rmse: 0.1674 - mae: 0.1210 - val_loss: 0.0187 - val_rmse: 0.1259 - val_mae: 0.0993
# Epoch 35/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0311 - rmse: 0.1771 - mae: 0.1290 - val_loss: 0.0153 - val_rmse: 0.1136 - val_mae: 0.0878
# Epoch 36/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0300 - rmse: 0.1723 - mae: 0.1240 - val_loss: 0.0171 - val_rmse: 0.1202 - val_mae: 0.0958
# Epoch 37/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0285 - rmse: 0.1672 - mae: 0.1216 - val_loss: 0.0204 - val_rmse: 0.1249 - val_mae: 0.0979
# Epoch 38/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0332 - rmse: 0.1780 - mae: 0.1268 - val_loss: 0.0234 - val_rmse: 0.1378 - val_mae: 0.1102
# Epoch 39/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0305 - rmse: 0.1728 - mae: 0.1256 - val_loss: 0.0197 - val_rmse: 0.1251 - val_mae: 0.0986
# Epoch 40/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0308 - rmse: 0.1744 - mae: 0.1257 - val_loss: 0.0164 - val_rmse: 0.1190 - val_mae: 0.0933
# Epoch 41/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0295 - rmse: 0.1724 - mae: 0.1225 - val_loss: 0.0163 - val_rmse: 0.1169 - val_mae: 0.0921
# Epoch 42/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0306 - rmse: 0.1776 - mae: 0.1239 - val_loss: 0.0216 - val_rmse: 0.1293 - val_mae: 0.1026
# Epoch 43/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0315 - rmse: 0.1762 - mae: 0.1214 - val_loss: 0.0205 - val_rmse: 0.1300 - val_mae: 0.1011
# Epoch 44/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0323 - rmse: 0.1781 - mae: 0.1272 - val_loss: 0.0217 - val_rmse: 0.1331 - val_mae: 0.1068
# Epoch 45/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0301 - rmse: 0.1694 - mae: 0.1277 - val_loss: 0.0227 - val_rmse: 0.1392 - val_mae: 0.1111
# Epoch 46/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0298 - rmse: 0.1696 - mae: 0.1264 - val_loss: 0.0142 - val_rmse: 0.1093 - val_mae: 0.0850
# Epoch 47/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0269 - rmse: 0.1640 - mae: 0.1180 - val_loss: 0.0152 - val_rmse: 0.1151 - val_mae: 0.0901
# Epoch 48/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0295 - rmse: 0.1726 - mae: 0.1257 - val_loss: 0.0147 - val_rmse: 0.1108 - val_mae: 0.0852
# Epoch 49/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0255 - rmse: 0.1584 - mae: 0.1135 - val_loss: 0.0141 - val_rmse: 0.1097 - val_mae: 0.0851
# Epoch 50/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0284 - rmse: 0.1671 - mae: 0.1217 - val_loss: 0.0141 - val_rmse: 0.1103 - val_mae: 0.0848
# Epoch 51/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0294 - rmse: 0.1753 - mae: 0.1214 - val_loss: 0.0137 - val_rmse: 0.1087 - val_mae: 0.0849
# Epoch 52/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0283 - rmse: 0.1693 - mae: 0.1192 - val_loss: 0.0188 - val_rmse: 0.1233 - val_mae: 0.0947
# Epoch 53/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0366 - rmse: 0.1902 - mae: 0.1301 - val_loss: 0.0146 - val_rmse: 0.1109 - val_mae: 0.0871
# Epoch 54/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0256 - rmse: 0.1578 - mae: 0.1153 - val_loss: 0.0141 - val_rmse: 0.1094 - val_mae: 0.0841
# Epoch 55/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0247 - rmse: 0.1558 - mae: 0.1128 - val_loss: 0.0152 - val_rmse: 0.1144 - val_mae: 0.0902
# Epoch 56/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0266 - rmse: 0.1600 - mae: 0.1149 - val_loss: 0.0180 - val_rmse: 0.1185 - val_mae: 0.0941
# Epoch 57/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0290 - rmse: 0.1669 - mae: 0.1189 - val_loss: 0.0180 - val_rmse: 0.1240 - val_mae: 0.0985
# Epoch 58/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0277 - rmse: 0.1621 - mae: 0.1188 - val_loss: 0.0144 - val_rmse: 0.1112 - val_mae: 0.0877
# Epoch 59/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0258 - rmse: 0.1633 - mae: 0.1153 - val_loss: 0.0137 - val_rmse: 0.1091 - val_mae: 0.0857
# Epoch 60/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0276 - rmse: 0.1660 - mae: 0.1204 - val_loss: 0.0154 - val_rmse: 0.1156 - val_mae: 0.0906
# Epoch 61/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0247 - rmse: 0.1564 - mae: 0.1156 - val_loss: 0.0142 - val_rmse: 0.1121 - val_mae: 0.0853
# Epoch 62/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0270 - rmse: 0.1636 - mae: 0.1199 - val_loss: 0.0119 - val_rmse: 0.1018 - val_mae: 0.0783
# Epoch 63/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0254 - rmse: 0.1599 - mae: 0.1135 - val_loss: 0.0154 - val_rmse: 0.1110 - val_mae: 0.0875
# Epoch 64/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0327 - rmse: 0.1796 - mae: 0.1246 - val_loss: 0.0155 - val_rmse: 0.1143 - val_mae: 0.0923
# Epoch 65/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0258 - rmse: 0.1560 - mae: 0.1165 - val_loss: 0.0134 - val_rmse: 0.1075 - val_mae: 0.0825
# Epoch 66/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0262 - rmse: 0.1635 - mae: 0.1174 - val_loss: 0.0132 - val_rmse: 0.1078 - val_mae: 0.0858
# Epoch 67/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0282 - rmse: 0.1687 - mae: 0.1212 - val_loss: 0.0136 - val_rmse: 0.1087 - val_mae: 0.0854
# Epoch 68/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0274 - rmse: 0.1663 - mae: 0.1185 - val_loss: 0.0138 - val_rmse: 0.1098 - val_mae: 0.0864
# Epoch 69/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0247 - rmse: 0.1555 - mae: 0.1145 - val_loss: 0.0137 - val_rmse: 0.1093 - val_mae: 0.0872
# Epoch 70/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0242 - rmse: 0.1553 - mae: 0.1124 - val_loss: 0.0126 - val_rmse: 0.1053 - val_mae: 0.0832
# Epoch 71/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0238 - rmse: 0.1533 - mae: 0.1129 - val_loss: 0.0162 - val_rmse: 0.1141 - val_mae: 0.0910
# Epoch 72/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0253 - rmse: 0.1571 - mae: 0.1123 - val_loss: 0.0139 - val_rmse: 0.1089 - val_mae: 0.0868
# Epoch 73/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0250 - rmse: 0.1616 - mae: 0.1135 - val_loss: 0.0148 - val_rmse: 0.1100 - val_mae: 0.0876
# Epoch 74/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0235 - rmse: 0.1503 - mae: 0.1098 - val_loss: 0.0124 - val_rmse: 0.1039 - val_mae: 0.0814
# Epoch 75/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0242 - rmse: 0.1548 - mae: 0.1082 - val_loss: 0.0112 - val_rmse: 0.0985 - val_mae: 0.0757
# Epoch 76/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0235 - rmse: 0.1533 - mae: 0.1098 - val_loss: 0.0116 - val_rmse: 0.1009 - val_mae: 0.0788
# Epoch 77/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0233 - rmse: 0.1531 - mae: 0.1092 - val_loss: 0.0112 - val_rmse: 0.0984 - val_mae: 0.0765
# Epoch 78/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0248 - rmse: 0.1539 - mae: 0.1122 - val_loss: 0.0186 - val_rmse: 0.1186 - val_mae: 0.0959
# Epoch 79/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0263 - rmse: 0.1610 - mae: 0.1137 - val_loss: 0.0124 - val_rmse: 0.1033 - val_mae: 0.0807
# Epoch 80/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0243 - rmse: 0.1592 - mae: 0.1108 - val_loss: 0.0117 - val_rmse: 0.1013 - val_mae: 0.0778
# Epoch 81/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0253 - rmse: 0.1583 - mae: 0.1151 - val_loss: 0.0123 - val_rmse: 0.1037 - val_mae: 0.0817
# Epoch 82/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0223 - rmse: 0.1482 - mae: 0.1070 - val_loss: 0.0122 - val_rmse: 0.1045 - val_mae: 0.0806
# Epoch 83/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0215 - rmse: 0.1451 - mae: 0.1073 - val_loss: 0.0137 - val_rmse: 0.1054 - val_mae: 0.0837
# Epoch 84/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0236 - rmse: 0.1515 - mae: 0.1091 - val_loss: 0.0102 - val_rmse: 0.0955 - val_mae: 0.0752
# Epoch 85/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0216 - rmse: 0.1445 - mae: 0.1052 - val_loss: 0.0098 - val_rmse: 0.0934 - val_mae: 0.0726
# Epoch 86/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0222 - rmse: 0.1487 - mae: 0.1069 - val_loss: 0.0123 - val_rmse: 0.1036 - val_mae: 0.0816
# Epoch 87/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0242 - rmse: 0.1553 - mae: 0.1119 - val_loss: 0.0108 - val_rmse: 0.0996 - val_mae: 0.0780
# Epoch 88/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0213 - rmse: 0.1465 - mae: 0.1072 - val_loss: 0.0111 - val_rmse: 0.0998 - val_mae: 0.0795
# Epoch 89/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0214 - rmse: 0.1481 - mae: 0.1077 - val_loss: 0.0144 - val_rmse: 0.1087 - val_mae: 0.0850
# Epoch 90/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0239 - rmse: 0.1527 - mae: 0.1080 - val_loss: 0.0151 - val_rmse: 0.1112 - val_mae: 0.0895
# Epoch 91/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0234 - rmse: 0.1533 - mae: 0.1095 - val_loss: 0.0111 - val_rmse: 0.1004 - val_mae: 0.0805
# Epoch 92/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0235 - rmse: 0.1507 - mae: 0.1090 - val_loss: 0.0128 - val_rmse: 0.1068 - val_mae: 0.0858
# Epoch 93/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0246 - rmse: 0.1582 - mae: 0.1135 - val_loss: 0.0111 - val_rmse: 0.1003 - val_mae: 0.0793
# Epoch 94/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0237 - rmse: 0.1533 - mae: 0.1109 - val_loss: 0.0097 - val_rmse: 0.0942 - val_mae: 0.0727
# Epoch 95/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0253 - rmse: 0.1563 - mae: 0.1125 - val_loss: 0.0138 - val_rmse: 0.1065 - val_mae: 0.0835
# Epoch 96/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0224 - rmse: 0.1476 - mae: 0.1081 - val_loss: 0.0112 - val_rmse: 0.0994 - val_mae: 0.0791
# Epoch 97/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0219 - rmse: 0.1479 - mae: 0.1063 - val_loss: 0.0152 - val_rmse: 0.1102 - val_mae: 0.0877
# Epoch 98/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0234 - rmse: 0.1524 - mae: 0.1090 - val_loss: 0.0148 - val_rmse: 0.1092 - val_mae: 0.0873
# Epoch 99/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0249 - rmse: 0.1556 - mae: 0.1120 - val_loss: 0.0106 - val_rmse: 0.0974 - val_mae: 0.0751
# Epoch 100/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0249 - rmse: 0.1583 - mae: 0.1098 - val_loss: 0.0098 - val_rmse: 0.0936 - val_mae: 0.0737

# %%
# 모델 평가
loss, rmse, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss}, Test RMSE: {rmse}, Test MAE: {mae}")
# Out:
# Test Loss: 0.009809385053813457, Test RMSE: 0.09013744443655014, Test MAE: 0.0736914798617363

# %%
# 예측
y_pred = model.predict(X_test)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted Prices')
plt.show()
# Out:
# 42/42 [==============================] - 1s 8ms/step
