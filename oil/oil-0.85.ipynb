# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
train_X = pd.read_excel('train_x_data.xlsx')
train_y = pd.read_excel('train_y_data.xlsx')
test_X = pd.read_excel('test_x_data.xlsx')
test_y = pd.read_excel('test_y_data.xlsx')

train_X
# Out:
#      Commodity       Date  Close Commodity.1     Date.1     Close.1  \
# 0        Cocoa 2018-01-02   1936      Coffee 2018-01-02  130.199997
# 1        Cocoa 2018-01-03   1907      Coffee 2018-01-03  128.600006
# 2        Cocoa 2018-01-04   1905      Coffee 2018-01-04  129.550003
# 3        Cocoa 2018-01-05   1895      Coffee 2018-01-05  128.449997
# 4        Cocoa 2018-01-08   1914      Coffee 2018-01-08  125.150002
# ...        ...        ...    ...         ...        ...         ...
# 1342     Cocoa 2023-06-26   3206      Coffee 2023-06-26  167.949997
# 1343     Cocoa 2023-06-27   3212      Coffee 2023-06-27  169.449997
# 1344     Cocoa 2023-06-28   3292      Coffee 2023-06-28  165.649994
# 1345     Cocoa 2023-06-29   3218      Coffee 2023-06-29  163.600006
# 1346     Cocoa 2023-06-30   3318      Coffee 2023-06-30  161.000000
#
#      Commodity.2     Date.2    Close.2 Commodity.3  ... Close.13  \
# 0         Cotton 2018-01-02  77.500000       Sugar  ...    3.056
# 1         Cotton 2018-01-03  78.110001       Sugar  ...    3.008
# 2         Cotton 2018-01-04  79.250000       Sugar  ...    2.880
# 3         Cotton 2018-01-05  78.010002       Sugar  ...    2.795
# 4         Cotton 2018-01-08  78.139999       Sugar  ...    2.835
# ...          ...        ...        ...         ...  ...      ...
# 1342      Cotton 2023-06-26  77.070000       Sugar  ...    2.791
# 1343      Cotton 2023-06-27  77.639999       Sugar  ...    2.763
# 1344      Cotton 2023-06-28  80.120003       Sugar  ...    2.603
# 1345      Cotton 2023-06-29  81.250000       Sugar  ...    2.701
# 1346      Cotton 2023-06-30  82.839996       Sugar  ...    2.798
#
#        Commodity.14    Date.14    Close.14  Commodity.15    Date.15  \
# 0     Feeder Cattle 2018-01-02  149.524994     Lean Hogs 2018-01-02
# 1     Feeder Cattle 2018-01-03  149.375000     Lean Hogs 2018-01-03
# 2     Feeder Cattle 2018-01-04  149.024994     Lean Hogs 2018-01-04
# 3     Feeder Cattle 2018-01-05  146.625000     Lean Hogs 2018-01-05
# 4     Feeder Cattle 2018-01-08  146.449997     Lean Hogs 2018-01-08
# ...             ...        ...         ...           ...        ...
# 1342  Feeder Cattle 2023-06-26  233.675003     Lean Hogs 2023-06-26
# 1343  Feeder Cattle 2023-06-27  238.500000     Lean Hogs 2023-06-27
# 1344  Feeder Cattle 2023-06-28  240.250000     Lean Hogs 2023-06-28
# 1345  Feeder Cattle 2023-06-29  242.375000     Lean Hogs 2023-06-29
# 1346  Feeder Cattle 2023-06-30  247.574997     Lean Hogs 2023-06-30
#
#        Close.15  Commodity.16    Date.16    Close.16
# 0     70.724998   Live Cattle 2018-01-02  123.349998
# 1     71.050003   Live Cattle 2018-01-03  122.949997
# 2     71.375000   Live Cattle 2018-01-04  122.250000
# 3     71.425003   Live Cattle 2018-01-05  119.250000
# 4     72.974998   Live Cattle 2018-01-08  117.224998
# ...         ...           ...        ...         ...
# 1342  93.400002   Live Cattle 2023-06-26  177.699997
# 1343  94.125000   Live Cattle 2023-06-27  179.300003
# 1344  94.275002   Live Cattle 2023-06-28  179.625000
# 1345  95.449997   Live Cattle 2023-06-29  179.750000
# 1346  95.650002   Live Cattle 2023-06-30  181.500000
#
# [1347 rows x 51 columns]

# %%
# 결측치 확인
print(train_X.isnull().sum())
print(train_y.isnull().sum())
print(test_X.isnull().sum())
print(test_y.isnull().sum())
# Out:
# Commodity       0
# Date            0
# Close           0
# Commodity.1     0
# Date.1          0
# Close.1         0
# Commodity.2     0
# Date.2          0
# Close.2         0
# Commodity.3     0
# Date.3          0
# Close.3         0
# Commodity.4     0
# Date.4          0
# Close.4         0
# Commodity.5     0
# Date.5          0
# Close.5         0
# Commodity.6     0
# Date.6          0
# Close.6         0
# Commodity.7     0
# Date.7          0
# Close.7         0
# Commodity.8     0
# Date.8          0
# Close.8         0
# Commodity.9     0
# Date.9          0
# Close.9         0
# Commodity.10    0
# Date.10         0
# Close.10        0
# Commodity.11    0
# Date.11         0
# Close.11        0
# Commodity.12    0
# Date.12         0
# Close.12        0
# Commodity.13    0
# Date.13         0
# Close.13        0
# Commodity.14    0
# Date.14         0
# Close.14        0
# Commodity.15    0
# Date.15         0
# Close.15        0
# Commodity.16    0
# Date.16         0
# Close.16        0
# dtype: int64
# Commodity    0
# Date         0
# Close        0
# dtype: int64
# Commodity       0
# Date            0
# Close           0
# Commodity.1     0
# Date.1          0
# Close.1         0
# Commodity.2     0
# Date.2          0
# Close.2         0
# Commodity.3     0
# Date.3          0
# Close.3         0
# Commodity.4     0
# Date.4          0
# Close.4         0
# Commodity.5     0
# Date.5          0
# Close.5         0
# Commodity.6     0
# Date.6          0
# Close.6         0
# Commodity.7     0
# Date.7          0
# Close.7         0
# Commodity.8     0
# Date.8          0
# Close.8         0
# Commodity.9     0
# Date.9          0
# Close.9         0
# Commodity.10    0
# Date.10         0
# Close.10        0
# Commodity.11    0
# Date.11         0
# Close.11        0
# Commodity.12    0
# Date.12         0
# Close.12        0
# Commodity.13    0
# Date.13         0
# Close.13        0
# Commodity.14    0
# Date.14         0
# Close.14        0
# Commodity.15    0
# Date.15         0
# Close.15        0
# Commodity.16    0
# Date.16         0
# Close.16        0
# dtype: int64
# Commodity    0
# Date         0
# Close        0
# dtype: int64

# %%
# 3개 단위로 나누기 (예: 'Commodity', 'Date', 'Close')
grouped_train_X_cols = [train_X.columns[i:i+3] for i in range(0, len(train_X.columns), 3)]
grouped_test_X_cols = [test_X.columns[i:i+3] for i in range(0, len(test_X.columns), 3)]
grouped_train_y_cols = [train_y.columns[i:i+3] for i in range(0, len(train_y.columns), 3)]
grouped_test_y_cols = [test_y.columns[i:i+3] for i in range(0, len(test_y.columns), 3)]
grouped_train_X_cols
# Out:
# [Index(['Commodity', 'Date', 'Close'], dtype='object'),
#  Index(['Commodity.1', 'Date.1', 'Close.1'], dtype='object'),
#  Index(['Commodity.2', 'Date.2', 'Close.2'], dtype='object'),
#  Index(['Commodity.3', 'Date.3', 'Close.3'], dtype='object'),
#  Index(['Commodity.4', 'Date.4', 'Close.4'], dtype='object'),
#  Index(['Commodity.5', 'Date.5', 'Close.5'], dtype='object'),
#  Index(['Commodity.6', 'Date.6', 'Close.6'], dtype='object'),
#  Index(['Commodity.7', 'Date.7', 'Close.7'], dtype='object'),
#  Index(['Commodity.8', 'Date.8', 'Close.8'], dtype='object'),
#  Index(['Commodity.9', 'Date.9', 'Close.9'], dtype='object'),
#  Index(['Commodity.10', 'Date.10', 'Close.10'], dtype='object'),
#  Index(['Commodity.11', 'Date.11', 'Close.11'], dtype='object'),
#  Index(['Commodity.12', 'Date.12', 'Close.12'], dtype='object'),
#  Index(['Commodity.13', 'Date.13', 'Close.13'], dtype='object'),
#  Index(['Commodity.14', 'Date.14', 'Close.14'], dtype='object'),
#  Index(['Commodity.15', 'Date.15', 'Close.15'], dtype='object'),
#  Index(['Commodity.16', 'Date.16', 'Close.16'], dtype='object')]

# %%
# Long Format으로 변환
long_train_X_data = []
long_test_X_data = []

for group in grouped_train_X_cols:
    temp = train_X[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_train_X_data.append(temp)

# 모든 그룹을 하나로 합치기
long_train_X = pd.concat(long_train_X_data, ignore_index=True)

for group in grouped_test_X_cols:
    temp = test_X[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_test_X_data.append(temp)

# 모든 그룹을 하나로 합치기
long_test_X = pd.concat(long_test_X_data, ignore_index=True)

# 결과 확인
long_train_X.head()
# Out:
#   Commodity       Date   Close
# 0     Cocoa 2018-01-02  1936.0
# 1     Cocoa 2018-01-03  1907.0
# 2     Cocoa 2018-01-04  1905.0
# 3     Cocoa 2018-01-05  1895.0
# 4     Cocoa 2018-01-08  1914.0

# %%
# Long Format으로 변환
long_train_y_data = []
long_test_y_data = []

for group in grouped_train_y_cols:
    temp = train_y[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_train_y_data.append(temp)

# 모든 그룹을 하나로 합치기
long_train_y = pd.concat(long_train_y_data, ignore_index=True)

for group in grouped_test_y_cols:
    temp = test_y[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_test_y_data.append(temp)

# 모든 그룹을 하나로 합치기
long_test_y = pd.concat(long_test_y_data, ignore_index=True)

# 결과 확인
long_train_y.head()
# Out:
#          Commodity       Date      Close
# 0  Brent Crude Oil 2018-01-02  66.570000
# 1  Brent Crude Oil 2018-01-03  67.839996
# 2  Brent Crude Oil 2018-01-04  68.070000
# 3  Brent Crude Oil 2018-01-05  67.620003
# 4  Brent Crude Oil 2018-01-08  67.779999

# %%
# 날짜 형식 변환
long_train_X['Date'] = pd.to_datetime(long_train_X['Date'])
long_test_X['Date'] = pd.to_datetime(long_test_X['Date'])
long_train_y['Date'] = pd.to_datetime(long_train_y['Date'])
long_test_y['Date'] = pd.to_datetime(long_test_y['Date'])

# 중복 제거
long_train_X = long_train_X.drop_duplicates()
long_test_X = long_test_X.drop_duplicates()
long_train_y = long_train_y.drop_duplicates()
long_test_y = long_test_y.drop_duplicates()

# 결과 확인
long_train_X
# Out:
#          Commodity       Date        Close
# 0            Cocoa 2018-01-02  1936.000000
# 1            Cocoa 2018-01-03  1907.000000
# 2            Cocoa 2018-01-04  1905.000000
# 3            Cocoa 2018-01-05  1895.000000
# 4            Cocoa 2018-01-08  1914.000000
# ...            ...        ...          ...
# 22894  Live Cattle 2023-06-26   177.699997
# 22895  Live Cattle 2023-06-27   179.300003
# 22896  Live Cattle 2023-06-28   179.625000
# 22897  Live Cattle 2023-06-29   179.750000
# 22898  Live Cattle 2023-06-30   181.500000
#
# [22899 rows x 3 columns]

# %%
# Date 기준 정렬
long_train_X = long_train_X.sort_values(by='Date')
long_test_X = long_train_X.sort_values(by='Date')
long_train_y = long_train_y.sort_values(by='Date')
long_test_y = long_train_y.sort_values(by='Date')

# 결과 확인
long_train_X
# Out:
#            Commodity       Date        Close
# 0              Cocoa 2018-01-02  1936.000000
# 16164         Silver 2018-01-02    17.121000
# 21552    Live Cattle 2018-01-02   123.349998
# 1347          Coffee 2018-01-02   130.199997
# 2694          Cotton 2018-01-02    77.500000
# ...              ...        ...          ...
# 2693          Coffee 2023-06-30   161.000000
# 20204  Feeder Cattle 2023-06-30   247.574997
# 21551      Lean Hogs 2023-06-30    95.650002
# 8081      Rough Rice 2023-06-30  1805.500000
# 22898    Live Cattle 2023-06-30   181.500000
#
# [22899 rows x 3 columns]

# %%
# Date를 인덱스로 설정하고 Pivot
pivot_train_X = long_train_X.pivot(index='Date', columns='Commodity', values='Close')
pivot_test_X = long_test_X.pivot(index='Date', columns='Commodity', values='Close')
pivot_train_y = long_train_y.pivot(index='Date', columns='Commodity', values='Close')
pivot_test_y = long_test_y.pivot(index='Date', columns='Commodity', values='Close')

# MultiIndex 제거
pivot_train_X.columns.name = None
pivot_train_X = pivot_train_X.reset_index()
pivot_train_y.columns.name = None
pivot_train_y = pivot_train_y.reset_index()
pivot_test_X.columns.name = None
pivot_test_X = pivot_test_X.reset_index()
pivot_test_y.columns.name = None
pivot_test_y = pivot_test_y.reset_index()

# 결과 확인
pivot_train_X.head()
# Out:
#         Date   Cocoa      Coffee  Copper     Cotton  Feeder Cattle  \
# 0 2018-01-02  1936.0  130.199997  3.2560  77.500000     149.524994
# 1 2018-01-03  1907.0  128.600006  3.2370  78.110001     149.375000
# 2 2018-01-04  1905.0  129.550003  3.2425  79.250000     149.024994
# 3 2018-01-05  1895.0  128.449997  3.2070  78.010002     146.625000
# 4 2018-01-08  1914.0  125.150002  3.2010  78.139999     146.449997
#
#           Gold  Kansas Wheat  Lean Hogs  Live Cattle  Natural Gas    Oats  \
# 0  1313.699951        434.75  70.724998   123.349998        3.056  242.50
# 1  1316.199951        441.00  71.050003   122.949997        3.008  244.50
# 2  1319.400024        439.75  71.375000   122.250000        2.880  245.75
# 3  1320.300049        437.50  71.425003   119.250000        2.795  248.50
# 4  1318.599976        433.25  72.974998   117.224998        2.835  250.00
#
#      Palladium    Platinum  Rough Rice     Silver  Soybeans  Sugar
# 0  1090.000000  943.799988      1153.5  17.121000    955.00  15.33
# 1  1086.000000  957.799988      1141.0  17.184999    959.75  15.31
# 2  1097.400024  966.099976      1147.5  17.188999    959.25  15.25
# 3  1084.849976  971.200012      1156.5  17.205000    961.50  15.08
# 4  1098.550049  972.299988      1164.5  17.063999    958.25  14.78

# %%
print(pivot_train_X.columns)
print(pivot_test_X.columns)
print(pivot_train_y.columns)
print(pivot_test_y.columns)
pivot_train_y.head()
# Out:
# Index(['Date', 'Cocoa', 'Coffee', 'Copper', 'Cotton', 'Feeder Cattle', 'Gold',
#        'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats',
#        'Palladium', 'Platinum', 'Rough Rice', 'Silver', 'Soybeans', 'Sugar'],
#       dtype='object')
# Index(['Date', 'Cocoa', 'Coffee', 'Copper', 'Cotton', 'Feeder Cattle', 'Gold',
#        'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats',
#        'Palladium', 'Platinum', 'Rough Rice', 'Silver', 'Soybeans', 'Sugar'],
#       dtype='object')
# Index(['Date', 'Brent Crude Oil'], dtype='object')
# Index(['Date', 'Brent Crude Oil'], dtype='object')
#         Date  Brent Crude Oil
# 0 2018-01-02        66.570000
# 1 2018-01-03        67.839996
# 2 2018-01-04        68.070000
# 3 2018-01-05        67.620003
# 4 2018-01-08        67.779999

# %%
pivot_test_X.reset_index(inplace=True)
pivot_train_X.reset_index(inplace=True)
pivot_test_y.reset_index(inplace=True)
pivot_train_y.reset_index(inplace=True)

pivot_train_X.drop('Date',axis=1, inplace=True)
pivot_test_X.drop('Date',axis=1, inplace=True)
pivot_train_y.drop('Date',axis=1, inplace=True)
pivot_test_y.drop('Date',axis=1, inplace=True)

pivot_train_y.head()
# Out:
#    index  Brent Crude Oil
# 0      0        66.570000
# 1      1        67.839996
# 2      2        68.070000
# 3      3        67.620003
# 4      4        67.779999

# %%
# 'index' 열 삭제
pivot_train_X.drop('index', axis=1, inplace=True)
pivot_test_X.drop('index', axis=1, inplace=True)
pivot_train_y.drop('index', axis=1, inplace=True)
pivot_test_y.drop('index', axis=1, inplace=True)

# 결과 확인
pivot_train_y.head()
# Out:
#    Brent Crude Oil
# 0        66.570000
# 1        67.839996
# 2        68.070000
# 3        67.620003
# 4        67.779999

# %%
# 데이터 통합
train_data = pd.concat([pivot_train_X, pivot_train_y], axis=1)
test_data = pd.concat([pivot_test_X, pivot_test_y], axis=1)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)
# Out:
# 타겟 변수와의 상관관계:
#  Brent Crude Oil    1.000000
# Cotton             0.819240
# Kansas Wheat       0.782843
# Natural Gas        0.745098
# Coffee             0.731278
# Soybeans           0.687027
# Lean Hogs          0.672630
# Live Cattle        0.638459
# Copper             0.620224
# Oats               0.613573
# Feeder Cattle      0.594026
# Sugar              0.584207
# Rough Rice         0.415543
# Platinum           0.270246
# Silver             0.176611
# Gold               0.127774
# Cocoa              0.085087
# Palladium         -0.030591
# Name: Brent Crude Oil, dtype: float64
# 타겟 변수와의 상관관계:
#  Brent Crude Oil    1.000000
# Cotton             0.819240
# Kansas Wheat       0.782843
# Natural Gas        0.745098
# Coffee             0.731278
# Soybeans           0.687027
# Lean Hogs          0.672630
# Live Cattle        0.638459
# Copper             0.620224
# Oats               0.613573
# Feeder Cattle      0.594026
# Sugar              0.584207
# Rough Rice         0.415543
# Platinum           0.270246
# Silver             0.176611
# Gold               0.127774
# Cocoa              0.085087
# Palladium         -0.030591
# Name: Brent Crude Oil, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 상관관계 히트맵
plt.figure(figsize=(12, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 타겟 변수 제외한 상관관계 기반 Feature Selection
threshold=0.6
correlation_with_target = correlation['Brent Crude Oil'].drop(labels=['Brent Crude Oil'])
selected_features = correlation_with_target[correlation_with_target.abs() > threshold].index.tolist()

print("선택된 변수들:", selected_features)
# Out:
# 선택된 변수들: ['Coffee', 'Copper', 'Cotton', 'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats', 'Soybeans']

# %%
# 피처 셀렉션
pivot_train_X=pivot_train_X[selected_features]
pivot_test_X=pivot_test_X[selected_features]

pivot_test_X
# Out:
#           Coffee  Copper     Cotton  Kansas Wheat  Lean Hogs  Live Cattle  \
# 0     130.199997  3.2560  77.500000        434.75  70.724998   123.349998
# 1     128.600006  3.2370  78.110001        441.00  71.050003   122.949997
# 2     129.550003  3.2425  79.250000        439.75  71.375000   122.250000
# 3     128.449997  3.2070  78.010002        437.50  71.425003   119.250000
# 4     125.150002  3.2010  78.139999        433.25  72.974998   117.224998
# ...          ...     ...        ...           ...        ...          ...
# 1342  167.949997  3.7865  77.070000        866.50  93.400002   177.699997
# 1343  169.449997  3.7815  77.639999        837.75  94.125000   179.300003
# 1344  165.649994  3.7205  80.120003        800.75  94.275002   179.625000
# 1345  163.600006  3.6775  81.250000        794.25  95.449997   179.750000
# 1346  161.000000  3.7410  82.839996        801.25  95.650002   181.500000
#
#       Natural Gas    Oats  Soybeans
# 0           3.056  242.50    955.00
# 1           3.008  244.50    959.75
# 2           2.880  245.75    959.25
# 3           2.795  248.50    961.50
# 4           2.835  250.00    958.25
# ...           ...     ...       ...
# 1342        2.791  391.25   1521.00
# 1343        2.763  385.00   1495.00
# 1344        2.603  377.00   1451.00
# 1345        2.701  367.75   1483.00
# 1346        2.798  377.25   1557.25
#
# [1347 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 데이터 표준화
pivot_train_X_scaled = scaler.fit_transform(pivot_train_X)
pivot_test_X_scaled = scaler.transform(pivot_test_X)
pivot_train_y_scaled = scaler.fit_transform(pivot_train_y)
pivot_test_y_scaled = scaler.transform(pivot_test_y)

# 표준화된 결과 확인
print(pivot_train_X_scaled[:5])  # 첫 5개 행 출력
# Out:
# [[-0.31896259 -0.19448044 -0.30428429 -0.95273171 -0.350508   -0.05303156
#   -0.25792155 -0.90395425 -0.74203782]
#  [-0.35243856 -0.22114479 -0.27476546 -0.92318337 -0.33254535 -0.07342589
#   -0.28513215 -0.89014585 -0.72563201]
#  [-0.33256215 -0.21342607 -0.21959921 -0.92909304 -0.31458312 -0.10911567
#   -0.35769349 -0.8815156  -0.72735893]
#  [-0.35557715 -0.26324623 -0.27960453 -0.93973044 -0.31181951 -0.26207253
#   -0.40587886 -0.86252905 -0.71958776]
#  [-0.42462164 -0.27166659 -0.27331378 -0.95982332 -0.22615294 -0.36531849
#   -0.38320342 -0.85217275 -0.73081279]]

# %% [markdown]
# ## 윈도우 크기 결정

# %%
def create_windows(X, y, window_size):
    X_windows, y_windows = [], []
    for i in range(len(X) - window_size):
        X_windows.append(X[i:i + window_size])  # .iloc 대신 기본 인덱싱 사용
        y_windows.append(y[i + window_size])    # .iloc 대신 기본 인덱싱 사용
    return np.array(X_windows), np.array(y_windows)

# %%
# 윈도우 크기
window_size = 30

# Train 데이터 슬라이싱
X_train, y_train = create_windows(
    pivot_train_X_scaled,  
    pivot_train_y_scaled,  
    window_size
)

# Test 데이터 슬라이싱
X_test, y_test = create_windows(
    pivot_test_X_scaled,  
    pivot_test_y_scaled,  
    window_size
)

# 결과 확인
print(f"Train X Shape: {X_train.shape}, Train y Shape: {y_train.shape}")
print(f"Test X Shape: {X_test.shape}, Test y Shape: {y_test.shape}")
# Out:
# Train X Shape: (1317, 30, 9), Train y Shape: (1317, 1)
# Test X Shape: (1317, 30, 9), Test y Shape: (1317, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, GRU
from tensorflow.keras import backend as K

# RMSE 정의
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# LSTM과 GRU 혼합 모델
model = Sequential([
    LSTM(64, activation='relu', input_shape=(window_size, X_train.shape[2]), return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),  # 추가 Dense 레이어
    Dense(y_train.shape[1])  # 출력 레이어 (타겟 변수 개수에 맞춤)
])

# 모델 컴파일 (loss에 rmse 사용)
model.compile(optimizer='adam', loss='mse', metrics=[rmse, 'mae'])

# %%
# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,  # 에포크 조정
    batch_size=128,  # 배치 크기 조정
    verbose=1
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 4s 93ms/step - loss: 0.4807 - rmse: 0.6637 - mae: 0.5202 - val_loss: 0.2665 - val_rmse: 0.4786 - val_mae: 0.4048
# Epoch 2/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.2356 - rmse: 0.4751 - mae: 0.3798 - val_loss: 0.2042 - val_rmse: 0.4160 - val_mae: 0.3515
# Epoch 3/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.1870 - rmse: 0.4313 - mae: 0.3379 - val_loss: 0.1504 - val_rmse: 0.3584 - val_mae: 0.2946
# Epoch 4/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.1475 - rmse: 0.3786 - mae: 0.2888 - val_loss: 0.1169 - val_rmse: 0.3226 - val_mae: 0.2620
# Epoch 5/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.1136 - rmse: 0.3350 - mae: 0.2575 - val_loss: 0.0974 - val_rmse: 0.2994 - val_mae: 0.2461
# Epoch 6/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0979 - rmse: 0.3085 - mae: 0.2423 - val_loss: 0.0769 - val_rmse: 0.2665 - val_mae: 0.2117
# Epoch 7/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0787 - rmse: 0.2785 - mae: 0.2134 - val_loss: 0.0598 - val_rmse: 0.2290 - val_mae: 0.1868
# Epoch 8/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0608 - rmse: 0.2423 - mae: 0.1924 - val_loss: 0.0448 - val_rmse: 0.2053 - val_mae: 0.1663
# Epoch 9/100
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0516 - rmse: 0.2262 - mae: 0.1776 - val_loss: 0.0388 - val_rmse: 0.1881 - val_mae: 0.1545
# Epoch 10/100
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0436 - rmse: 0.2107 - mae: 0.1609 - val_loss: 0.0353 - val_rmse: 0.1808 - val_mae: 0.1481
# Epoch 11/100
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0413 - rmse: 0.2002 - mae: 0.1547 - val_loss: 0.0293 - val_rmse: 0.1604 - val_mae: 0.1329
# Epoch 12/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0369 - rmse: 0.1942 - mae: 0.1466 - val_loss: 0.0278 - val_rmse: 0.1584 - val_mae: 0.1250
# Epoch 13/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0328 - rmse: 0.1820 - mae: 0.1388 - val_loss: 0.0280 - val_rmse: 0.1552 - val_mae: 0.1270
# Epoch 14/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0330 - rmse: 0.1790 - mae: 0.1377 - val_loss: 0.0300 - val_rmse: 0.1592 - val_mae: 0.1283
# Epoch 15/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0337 - rmse: 0.1800 - mae: 0.1386 - val_loss: 0.0278 - val_rmse: 0.1540 - val_mae: 0.1243
# Epoch 16/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0293 - rmse: 0.1695 - mae: 0.1301 - val_loss: 0.0233 - val_rmse: 0.1413 - val_mae: 0.1138
# Epoch 17/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0282 - rmse: 0.1669 - mae: 0.1256 - val_loss: 0.0270 - val_rmse: 0.1492 - val_mae: 0.1206
# Epoch 18/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0302 - rmse: 0.1731 - mae: 0.1267 - val_loss: 0.0196 - val_rmse: 0.1290 - val_mae: 0.1023
# Epoch 19/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0253 - rmse: 0.1582 - mae: 0.1189 - val_loss: 0.0221 - val_rmse: 0.1394 - val_mae: 0.1139
# Epoch 20/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0249 - rmse: 0.1578 - mae: 0.1176 - val_loss: 0.0191 - val_rmse: 0.1297 - val_mae: 0.1035
# Epoch 21/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0268 - rmse: 0.1629 - mae: 0.1204 - val_loss: 0.0178 - val_rmse: 0.1236 - val_mae: 0.0971
# Epoch 22/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0250 - rmse: 0.1572 - mae: 0.1153 - val_loss: 0.0185 - val_rmse: 0.1260 - val_mae: 0.1006
# Epoch 23/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0235 - rmse: 0.1517 - mae: 0.1136 - val_loss: 0.0222 - val_rmse: 0.1350 - val_mae: 0.1084
# Epoch 24/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0235 - rmse: 0.1529 - mae: 0.1110 - val_loss: 0.0166 - val_rmse: 0.1201 - val_mae: 0.0946
# Epoch 25/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0205 - rmse: 0.1448 - mae: 0.1039 - val_loss: 0.0175 - val_rmse: 0.1211 - val_mae: 0.0972
# Epoch 26/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0227 - rmse: 0.1560 - mae: 0.1072 - val_loss: 0.0169 - val_rmse: 0.1191 - val_mae: 0.0939
# Epoch 27/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0215 - rmse: 0.1439 - mae: 0.1033 - val_loss: 0.0196 - val_rmse: 0.1261 - val_mae: 0.0986
# Epoch 28/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0233 - rmse: 0.1479 - mae: 0.1079 - val_loss: 0.0186 - val_rmse: 0.1269 - val_mae: 0.1018
# Epoch 29/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0224 - rmse: 0.1474 - mae: 0.1112 - val_loss: 0.0160 - val_rmse: 0.1189 - val_mae: 0.0914
# Epoch 30/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0187 - rmse: 0.1340 - mae: 0.1003 - val_loss: 0.0186 - val_rmse: 0.1215 - val_mae: 0.0950
# Epoch 31/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0189 - rmse: 0.1354 - mae: 0.0998 - val_loss: 0.0151 - val_rmse: 0.1135 - val_mae: 0.0888
# Epoch 32/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0183 - rmse: 0.1325 - mae: 0.0976 - val_loss: 0.0153 - val_rmse: 0.1144 - val_mae: 0.0887
# Epoch 33/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0184 - rmse: 0.1361 - mae: 0.0985 - val_loss: 0.0149 - val_rmse: 0.1119 - val_mae: 0.0879
# Epoch 34/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0180 - rmse: 0.1340 - mae: 0.0988 - val_loss: 0.0182 - val_rmse: 0.1220 - val_mae: 0.0972
# Epoch 35/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0200 - rmse: 0.1422 - mae: 0.1026 - val_loss: 0.0186 - val_rmse: 0.1233 - val_mae: 0.0963
# Epoch 36/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0202 - rmse: 0.1431 - mae: 0.1023 - val_loss: 0.0151 - val_rmse: 0.1110 - val_mae: 0.0876
# Epoch 37/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0212 - rmse: 0.1412 - mae: 0.1019 - val_loss: 0.0152 - val_rmse: 0.1108 - val_mae: 0.0861
# Epoch 38/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0199 - rmse: 0.1393 - mae: 0.1029 - val_loss: 0.0149 - val_rmse: 0.1118 - val_mae: 0.0872
# Epoch 39/100
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0190 - rmse: 0.1370 - mae: 0.1004 - val_loss: 0.0179 - val_rmse: 0.1244 - val_mae: 0.0989
# Epoch 40/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0190 - rmse: 0.1341 - mae: 0.0990 - val_loss: 0.0147 - val_rmse: 0.1126 - val_mae: 0.0882
# Epoch 41/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0184 - rmse: 0.1380 - mae: 0.0989 - val_loss: 0.0156 - val_rmse: 0.1152 - val_mae: 0.0897
# Epoch 42/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0168 - rmse: 0.1283 - mae: 0.0941 - val_loss: 0.0161 - val_rmse: 0.1168 - val_mae: 0.0933
# Epoch 43/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0192 - rmse: 0.1365 - mae: 0.0996 - val_loss: 0.0166 - val_rmse: 0.1141 - val_mae: 0.0888
# Epoch 44/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0199 - rmse: 0.1400 - mae: 0.1033 - val_loss: 0.0158 - val_rmse: 0.1136 - val_mae: 0.0893
# Epoch 45/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0187 - rmse: 0.1354 - mae: 0.0980 - val_loss: 0.0163 - val_rmse: 0.1163 - val_mae: 0.0910
# Epoch 46/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0174 - rmse: 0.1327 - mae: 0.0934 - val_loss: 0.0140 - val_rmse: 0.1080 - val_mae: 0.0851
# Epoch 47/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0162 - rmse: 0.1249 - mae: 0.0909 - val_loss: 0.0150 - val_rmse: 0.1115 - val_mae: 0.0871
# Epoch 48/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0180 - rmse: 0.1334 - mae: 0.0952 - val_loss: 0.0142 - val_rmse: 0.1078 - val_mae: 0.0839
# Epoch 49/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0177 - rmse: 0.1374 - mae: 0.0941 - val_loss: 0.0147 - val_rmse: 0.1147 - val_mae: 0.0877
# Epoch 50/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0186 - rmse: 0.1314 - mae: 0.0970 - val_loss: 0.0133 - val_rmse: 0.1053 - val_mae: 0.0816
# Epoch 51/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0182 - rmse: 0.1309 - mae: 0.0962 - val_loss: 0.0152 - val_rmse: 0.1137 - val_mae: 0.0889
# Epoch 52/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0182 - rmse: 0.1330 - mae: 0.0943 - val_loss: 0.0131 - val_rmse: 0.1066 - val_mae: 0.0819
# Epoch 53/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0158 - rmse: 0.1272 - mae: 0.0894 - val_loss: 0.0133 - val_rmse: 0.1064 - val_mae: 0.0824
# Epoch 54/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0143 - rmse: 0.1174 - mae: 0.0849 - val_loss: 0.0122 - val_rmse: 0.1016 - val_mae: 0.0779
# Epoch 55/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0171 - rmse: 0.1289 - mae: 0.0904 - val_loss: 0.0145 - val_rmse: 0.1102 - val_mae: 0.0863
# Epoch 56/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0160 - rmse: 0.1254 - mae: 0.0893 - val_loss: 0.0146 - val_rmse: 0.1102 - val_mae: 0.0867
# Epoch 57/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0172 - rmse: 0.1295 - mae: 0.0936 - val_loss: 0.0123 - val_rmse: 0.1025 - val_mae: 0.0790
# Epoch 58/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0162 - rmse: 0.1297 - mae: 0.0901 - val_loss: 0.0134 - val_rmse: 0.1058 - val_mae: 0.0819
# Epoch 59/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0171 - rmse: 0.1306 - mae: 0.0909 - val_loss: 0.0129 - val_rmse: 0.1028 - val_mae: 0.0799
# Epoch 60/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0171 - rmse: 0.1329 - mae: 0.0927 - val_loss: 0.0135 - val_rmse: 0.1081 - val_mae: 0.0857
# Epoch 61/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0158 - rmse: 0.1225 - mae: 0.0923 - val_loss: 0.0131 - val_rmse: 0.1060 - val_mae: 0.0834
# Epoch 62/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0153 - rmse: 0.1228 - mae: 0.0888 - val_loss: 0.0142 - val_rmse: 0.1076 - val_mae: 0.0845
# Epoch 63/100
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0161 - rmse: 0.1272 - mae: 0.0907 - val_loss: 0.0126 - val_rmse: 0.1039 - val_mae: 0.0804
# Epoch 64/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0160 - rmse: 0.1250 - mae: 0.0897 - val_loss: 0.0161 - val_rmse: 0.1138 - val_mae: 0.0915
# Epoch 65/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0183 - rmse: 0.1350 - mae: 0.0962 - val_loss: 0.0128 - val_rmse: 0.1040 - val_mae: 0.0796
# Epoch 66/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0147 - rmse: 0.1202 - mae: 0.0878 - val_loss: 0.0123 - val_rmse: 0.1032 - val_mae: 0.0794
# Epoch 67/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0158 - rmse: 0.1243 - mae: 0.0899 - val_loss: 0.0117 - val_rmse: 0.0993 - val_mae: 0.0775
# Epoch 68/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0147 - rmse: 0.1185 - mae: 0.0876 - val_loss: 0.0122 - val_rmse: 0.1023 - val_mae: 0.0800
# Epoch 69/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0144 - rmse: 0.1202 - mae: 0.0877 - val_loss: 0.0125 - val_rmse: 0.1034 - val_mae: 0.0814
# Epoch 70/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0160 - rmse: 0.1271 - mae: 0.0915 - val_loss: 0.0118 - val_rmse: 0.0988 - val_mae: 0.0767
# Epoch 71/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0190 - rmse: 0.1360 - mae: 0.0983 - val_loss: 0.0129 - val_rmse: 0.1046 - val_mae: 0.0815
# Epoch 72/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0175 - rmse: 0.1293 - mae: 0.0956 - val_loss: 0.0137 - val_rmse: 0.1080 - val_mae: 0.0857
# Epoch 73/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0156 - rmse: 0.1217 - mae: 0.0888 - val_loss: 0.0122 - val_rmse: 0.0998 - val_mae: 0.0775
# Epoch 74/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0149 - rmse: 0.1203 - mae: 0.0862 - val_loss: 0.0120 - val_rmse: 0.0994 - val_mae: 0.0787
# Epoch 75/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0157 - rmse: 0.1240 - mae: 0.0889 - val_loss: 0.0170 - val_rmse: 0.1112 - val_mae: 0.0877
# Epoch 76/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0196 - rmse: 0.1371 - mae: 0.0955 - val_loss: 0.0162 - val_rmse: 0.1109 - val_mae: 0.0879
# Epoch 77/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0173 - rmse: 0.1287 - mae: 0.0940 - val_loss: 0.0109 - val_rmse: 0.0956 - val_mae: 0.0739
# Epoch 78/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0146 - rmse: 0.1237 - mae: 0.0856 - val_loss: 0.0111 - val_rmse: 0.0969 - val_mae: 0.0753
# Epoch 79/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0160 - rmse: 0.1281 - mae: 0.0871 - val_loss: 0.0118 - val_rmse: 0.0975 - val_mae: 0.0754
# Epoch 80/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0156 - rmse: 0.1229 - mae: 0.0873 - val_loss: 0.0120 - val_rmse: 0.0997 - val_mae: 0.0781
# Epoch 81/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0141 - rmse: 0.1201 - mae: 0.0837 - val_loss: 0.0108 - val_rmse: 0.0950 - val_mae: 0.0740
# Epoch 82/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0150 - rmse: 0.1254 - mae: 0.0858 - val_loss: 0.0117 - val_rmse: 0.0999 - val_mae: 0.0764
# Epoch 83/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0148 - rmse: 0.1211 - mae: 0.0890 - val_loss: 0.0113 - val_rmse: 0.0970 - val_mae: 0.0737
# Epoch 84/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0135 - rmse: 0.1139 - mae: 0.0820 - val_loss: 0.0105 - val_rmse: 0.0941 - val_mae: 0.0729
# Epoch 85/100
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0142 - rmse: 0.1185 - mae: 0.0851 - val_loss: 0.0109 - val_rmse: 0.0966 - val_mae: 0.0737
# Epoch 86/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0134 - rmse: 0.1128 - mae: 0.0832 - val_loss: 0.0105 - val_rmse: 0.0943 - val_mae: 0.0733
# Epoch 87/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0119 - rmse: 0.1081 - mae: 0.0804 - val_loss: 0.0105 - val_rmse: 0.0945 - val_mae: 0.0732
# Epoch 88/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0133 - rmse: 0.1116 - mae: 0.0813 - val_loss: 0.0100 - val_rmse: 0.0919 - val_mae: 0.0715
# Epoch 89/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0125 - rmse: 0.1098 - mae: 0.0805 - val_loss: 0.0112 - val_rmse: 0.0986 - val_mae: 0.0781
# Epoch 90/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0134 - rmse: 0.1141 - mae: 0.0842 - val_loss: 0.0107 - val_rmse: 0.0969 - val_mae: 0.0753
# Epoch 91/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0130 - rmse: 0.1134 - mae: 0.0824 - val_loss: 0.0101 - val_rmse: 0.0933 - val_mae: 0.0730
# Epoch 92/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0123 - rmse: 0.1093 - mae: 0.0812 - val_loss: 0.0111 - val_rmse: 0.0981 - val_mae: 0.0770
# Epoch 93/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0122 - rmse: 0.1092 - mae: 0.0815 - val_loss: 0.0116 - val_rmse: 0.0975 - val_mae: 0.0773
# Epoch 94/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0132 - rmse: 0.1136 - mae: 0.0831 - val_loss: 0.0100 - val_rmse: 0.0937 - val_mae: 0.0729
# Epoch 95/100
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0121 - rmse: 0.1086 - mae: 0.0791 - val_loss: 0.0098 - val_rmse: 0.0929 - val_mae: 0.0719
# Epoch 96/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0112 - rmse: 0.1036 - mae: 0.0779 - val_loss: 0.0092 - val_rmse: 0.0889 - val_mae: 0.0693
# Epoch 97/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0122 - rmse: 0.1092 - mae: 0.0801 - val_loss: 0.0097 - val_rmse: 0.0917 - val_mae: 0.0714
# Epoch 98/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0122 - rmse: 0.1114 - mae: 0.0805 - val_loss: 0.0107 - val_rmse: 0.0969 - val_mae: 0.0769
# Epoch 99/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0122 - rmse: 0.1094 - mae: 0.0800 - val_loss: 0.0097 - val_rmse: 0.0917 - val_mae: 0.0709
# Epoch 100/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0117 - rmse: 0.1068 - mae: 0.0783 - val_loss: 0.0088 - val_rmse: 0.0877 - val_mae: 0.0690

# %%
# 모델 평가
loss, rmse, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss}, Test RMSE: {rmse}, Test MAE: {mae}")
# Out:
# Test Loss: 0.008771012537181377, Test RMSE: 0.08586088567972183, Test MAE: 0.06895473599433899

# %%
# 예측
y_pred = model.predict(X_test)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted Prices')
plt.show()
# Out:
# 42/42 [==============================] - 1s 8ms/step
