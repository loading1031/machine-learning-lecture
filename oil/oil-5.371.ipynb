# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
train_X = pd.read_excel('.\\preprocess\\train_x_data.xlsx')
train_y = pd.read_excel('.\\preprocess\\train_y_data.xlsx')
test_X = pd.read_excel('.\\preprocess\\test_x_data.xlsx')
test_y = pd.read_excel('.\\preprocess\\test_y_data.xlsx')

train_X
# Out:
#            Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0    2018-01-02                 0  33.279999   1936  130.199997  77.500000
# 1    2018-01-03                 1  33.570000   1907  128.600006  78.110001
# 2    2018-01-04                 2  33.700001   1905  129.550003  79.250000
# 3    2018-01-05                 3  34.029999   1895  128.449997  78.010002
# 4    2018-01-08                 6  34.099998   1914  125.150002  78.139999
# ...         ...               ...        ...    ...         ...        ...
# 1342 2023-06-26              2001  59.279999   3206  167.949997  77.070000
# 1343 2023-06-27              2002  59.930000   3212  169.449997  77.639999
# 1344 2023-06-28              2003  60.000000   3292  165.649994  80.120003
# 1345 2023-06-29              2004  60.209999   3218  163.600006  81.250000
# 1346 2023-06-30              2005  61.010000   3318  161.000000  82.839996
#
#           Sugar    Oats  Rough Rice  Soybeans  Kansas Wheat  Copper  \
# 0     15.330000  242.50      1153.5    955.00        434.75  3.2560
# 1     15.310000  244.50      1141.0    959.75        441.00  3.2370
# 2     15.250000  245.75      1147.5    959.25        439.75  3.2425
# 3     15.080000  248.50      1156.5    961.50        437.50  3.2070
# 4     14.780000  250.00      1164.5    958.25        433.25  3.2010
# ...         ...     ...         ...       ...           ...     ...
# 1342  23.719999  391.25      1794.0   1521.00        866.50  3.7865
# 1343  23.030001  385.00      1767.5   1495.00        837.75  3.7815
# 1344  22.570000  377.00      1748.5   1451.00        800.75  3.7205
# 1345  22.070000  367.75      1770.5   1483.00        794.25  3.6775
# 1346  22.889999  377.25      1805.5   1557.25        801.25  3.7410
#
#              Gold    Palladium    Platinum     Silver  Natural Gas  \
# 0     1313.699951  1090.000000  943.799988  17.121000        3.056
# 1     1316.199951  1086.000000  957.799988  17.184999        3.008
# 2     1319.400024  1097.400024  966.099976  17.188999        2.880
# 3     1320.300049  1084.849976  971.200012  17.205000        2.795
# 4     1318.599976  1098.550049  972.299988  17.063999        2.835
# ...           ...          ...         ...        ...          ...
# 1342  1923.699951  1291.800049  936.700012  22.805000        2.791
# 1343  1914.000000  1283.199951  936.599976  22.938999        2.763
# 1344  1912.300049  1236.000000  923.400024  22.868000        2.603
# 1345  1909.199951  1218.800049  897.799988  22.591000        2.701
# 1346  1921.099976  1213.400024  904.500000  22.809999        2.798
#
#       Feeder Cattle  Lean Hogs  Live Cattle
# 0        149.524994  70.724998   123.349998
# 1        149.375000  71.050003   122.949997
# 2        149.024994  71.375000   122.250000
# 3        146.625000  71.425003   119.250000
# 4        146.449997  72.974998   117.224998
# ...             ...        ...          ...
# 1342     233.675003  93.400002   177.699997
# 1343     238.500000  94.125000   179.300003
# 1344     240.250000  94.275002   179.625000
# 1345     242.375000  95.449997   179.750000
# 1346     247.574997  95.650002   181.500000
#
# [1347 rows x 20 columns]

# %%
import pandas as pd
import numpy as np

time_columns=['sin_month','cos_month', 'day_of_week','days_since_start','sin_day_of_week','cos_day_of_week']

# Date 컬럼을 날짜 형식으로 변환
train_X['Date'] = pd.to_datetime(train_X['Date'])
test_X['Date'] = pd.to_datetime(test_X['Date'])


# 월(Month) 추출
train_X['Month'] = train_X['Date'].dt.month
test_X['Month'] = test_X['Date'].dt.month

# 월 주기 변환 (sin, cos)
train_X['sin_month'] = np.sin(2 * np.pi * train_X['Month'] / 12)
train_X['cos_month'] = np.cos(2 * np.pi * train_X['Month'] / 12)

test_X['sin_month'] = np.sin(2 * np.pi * test_X['Month'] / 12)
test_X['cos_month'] = np.cos(2 * np.pi * test_X['Month'] / 12)

print(train_X.head())
test_X.head()
# Out:
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2018-01-02                 0  33.279999   1936  130.199997  77.500000
# 1 2018-01-03                 1  33.570000   1907  128.600006  78.110001
# 2 2018-01-04                 2  33.700001   1905  129.550003  79.250000
# 3 2018-01-05                 3  34.029999   1895  128.449997  78.010002
# 4 2018-01-08                 6  34.099998   1914  125.150002  78.139999
#
#    Sugar    Oats  Rough Rice  Soybeans  ...    Palladium    Platinum  \
# 0  15.33  242.50      1153.5    955.00  ...  1090.000000  943.799988
# 1  15.31  244.50      1141.0    959.75  ...  1086.000000  957.799988
# 2  15.25  245.75      1147.5    959.25  ...  1097.400024  966.099976
# 3  15.08  248.50      1156.5    961.50  ...  1084.849976  971.200012
# 4  14.78  250.00      1164.5    958.25  ...  1098.550049  972.299988
#
#       Silver  Natural Gas  Feeder Cattle  Lean Hogs  Live Cattle  Month  \
# 0  17.121000        3.056     149.524994  70.724998   123.349998      1
# 1  17.184999        3.008     149.375000  71.050003   122.949997      1
# 2  17.188999        2.880     149.024994  71.375000   122.250000      1
# 3  17.205000        2.795     146.625000  71.425003   119.250000      1
# 4  17.063999        2.835     146.449997  72.974998   117.224998      1
#
#    sin_month  cos_month
# 0        0.5   0.866025
# 1        0.5   0.866025
# 2        0.5   0.866025
# 3        0.5   0.866025
# 4        0.5   0.866025
#
# [5 rows x 23 columns]
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2023-07-03              1998  61.049999   3364  162.500000  83.430000
# 1 2023-07-05              2000  60.939999   3334  161.050003  82.449997
# 2 2023-07-06              2001  60.470001   3277  162.350006  82.879997
# 3 2023-07-07              2002  60.240002   3274  162.800003  81.199997
# 4 2023-07-10              2005  60.209999   3299  161.750000  79.949997
#
#        Sugar    Oats  Rough Rice  Soybeans  ...    Palladium    Platinum  \
# 0  23.320000  379.25      1804.5   1562.00  ...  1218.400024  909.299988
# 1  23.530001  402.50      1827.0   1547.25  ...  1249.300049  918.099976
# 2  23.250000  416.75      1864.0   1525.75  ...  1230.800049  904.500000
# 3  23.530001  406.25      1868.5   1485.50  ...  1236.500000  910.099976
# 4  23.440001  414.00      1910.0   1508.00  ...  1228.099976  929.200012
#
#       Silver  Natural Gas  Feeder Cattle   Lean Hogs  Live Cattle  Month  \
# 0  22.896000        2.709     247.899994   97.824997   176.824997      7
# 1  23.197001        2.657     244.699997  101.275002   174.949997      7
# 2  22.686001        2.609     242.274994  100.050003   174.574997      7
# 3  23.091999        2.582     245.425003   99.000000   177.000000      7
# 4  23.150999        2.669     246.250000   98.800003   177.199997      7
#
#    sin_month  cos_month
# 0       -0.5  -0.866025
# 1       -0.5  -0.866025
# 2       -0.5  -0.866025
# 3       -0.5  -0.866025
# 4       -0.5  -0.866025
#
# [5 rows x 23 columns]

# %%
# 요일 계산 (days_since_start를 7로 나눈 나머지)
train_X['day_of_week'] = train_X['days_since_start'] % 7
test_X['day_of_week'] = test_X['days_since_start'] % 7


# 요일 주기 변환 (sin, cos)
train_X['sin_day_of_week'] = np.sin(2 * np.pi * train_X['day_of_week'] / 7)
train_X['cos_day_of_week'] = np.cos(2 * np.pi * train_X['day_of_week'] / 7)

test_X['sin_day_of_week'] = np.sin(2 * np.pi * test_X['day_of_week'] / 7)
test_X['cos_day_of_week'] = np.cos(2 * np.pi * test_X['day_of_week'] / 7)

print(train_X.head())
test_X.head()
# Out:
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2018-01-02                 0  33.279999   1936  130.199997  77.500000
# 1 2018-01-03                 1  33.570000   1907  128.600006  78.110001
# 2 2018-01-04                 2  33.700001   1905  129.550003  79.250000
# 3 2018-01-05                 3  34.029999   1895  128.449997  78.010002
# 4 2018-01-08                 6  34.099998   1914  125.150002  78.139999
#
#    Sugar    Oats  Rough Rice  Soybeans  ...  Natural Gas  Feeder Cattle  \
# 0  15.33  242.50      1153.5    955.00  ...        3.056     149.524994
# 1  15.31  244.50      1141.0    959.75  ...        3.008     149.375000
# 2  15.25  245.75      1147.5    959.25  ...        2.880     149.024994
# 3  15.08  248.50      1156.5    961.50  ...        2.795     146.625000
# 4  14.78  250.00      1164.5    958.25  ...        2.835     146.449997
#
#    Lean Hogs  Live Cattle  Month  sin_month  cos_month  day_of_week  \
# 0  70.724998   123.349998      1        0.5   0.866025            0
# 1  71.050003   122.949997      1        0.5   0.866025            1
# 2  71.375000   122.250000      1        0.5   0.866025            2
# 3  71.425003   119.250000      1        0.5   0.866025            3
# 4  72.974998   117.224998      1        0.5   0.866025            6
#
#    sin_day_of_week  cos_day_of_week
# 0         0.000000         1.000000
# 1         0.781831         0.623490
# 2         0.974928        -0.222521
# 3         0.433884        -0.900969
# 4        -0.781831         0.623490
#
# [5 rows x 26 columns]
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2023-07-03              1998  61.049999   3364  162.500000  83.430000
# 1 2023-07-05              2000  60.939999   3334  161.050003  82.449997
# 2 2023-07-06              2001  60.470001   3277  162.350006  82.879997
# 3 2023-07-07              2002  60.240002   3274  162.800003  81.199997
# 4 2023-07-10              2005  60.209999   3299  161.750000  79.949997
#
#        Sugar    Oats  Rough Rice  Soybeans  ...  Natural Gas  Feeder Cattle  \
# 0  23.320000  379.25      1804.5   1562.00  ...        2.709     247.899994
# 1  23.530001  402.50      1827.0   1547.25  ...        2.657     244.699997
# 2  23.250000  416.75      1864.0   1525.75  ...        2.609     242.274994
# 3  23.530001  406.25      1868.5   1485.50  ...        2.582     245.425003
# 4  23.440001  414.00      1910.0   1508.00  ...        2.669     246.250000
#
#     Lean Hogs  Live Cattle  Month  sin_month  cos_month  day_of_week  \
# 0   97.824997   176.824997      7       -0.5  -0.866025            3
# 1  101.275002   174.949997      7       -0.5  -0.866025            5
# 2  100.050003   174.574997      7       -0.5  -0.866025            6
# 3   99.000000   177.000000      7       -0.5  -0.866025            0
# 4   98.800003   177.199997      7       -0.5  -0.866025            3
#
#    sin_day_of_week  cos_day_of_week
# 0         0.433884        -0.900969
# 1        -0.974928        -0.222521
# 2        -0.781831         0.623490
# 3         0.000000         1.000000
# 4         0.433884        -0.900969
#
# [5 rows x 26 columns]

# %%
# 결측치 확인
print(train_X.isnull().sum())
print(train_y.isnull().sum())
print(test_X.isnull().sum())
print(test_y.isnull().sum())
# Out:
# Date                0
# days_since_start    0
# SPYG                0
# Cocoa               0
# Coffee              0
# Cotton              0
# Sugar               0
# Oats                0
# Rough Rice          0
# Soybeans            0
# Kansas Wheat        0
# Copper              0
# Gold                0
# Palladium           0
# Platinum            0
# Silver              0
# Natural Gas         0
# Feeder Cattle       0
# Lean Hogs           0
# Live Cattle         0
# Month               0
# sin_month           0
# cos_month           0
# day_of_week         0
# sin_day_of_week     0
# cos_day_of_week     0
# dtype: int64
# Brent Crude Oil    0
# dtype: int64
# Date                0
# days_since_start    0
# SPYG                0
# Cocoa               0
# Coffee              0
# Cotton              0
# Sugar               0
# Oats                0
# Rough Rice          0
# Soybeans            0
# Kansas Wheat        0
# Copper              0
# Gold                0
# Palladium           0
# Platinum            0
# Silver              0
# Natural Gas         0
# Feeder Cattle       0
# Lean Hogs           0
# Live Cattle         0
# Month               0
# sin_month           0
# cos_month           0
# day_of_week         0
# sin_day_of_week     0
# cos_day_of_week     0
# dtype: int64
# Brent Crude Oil    0
# dtype: int64

# %%
# 데이터 통합
train_data = pd.concat([train_X, train_y], axis=1)
test_data = pd.concat([test_X, test_y], axis=1)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)
# Out:
# 타겟 변수와의 상관관계:
#  Brent Crude Oil     1.000000
# Cotton              0.819240
# Kansas Wheat        0.782843
# Natural Gas         0.745098
# Coffee              0.731278
# Soybeans            0.687027
# Lean Hogs           0.672630
# Live Cattle         0.638459
# Copper              0.620224
# Oats                0.613573
# Feeder Cattle       0.594026
# Sugar               0.584207
# Date                0.442988
# days_since_start    0.442988
# Rough Rice          0.415543
# SPYG                0.404252
# Platinum            0.270246
# Silver              0.176611
# Gold                0.127774
# Cocoa               0.085087
# sin_day_of_week     0.016459
# sin_month           0.011236
# cos_day_of_week    -0.010879
# day_of_week        -0.015411
# Palladium          -0.030591
# Month              -0.038910
# cos_month          -0.070356
# Name: Brent Crude Oil, dtype: float64
# 타겟 변수와의 상관관계:
#  Brent Crude Oil     1.000000
# Cotton              0.819240
# Kansas Wheat        0.782843
# Natural Gas         0.745098
# Coffee              0.731278
# Soybeans            0.687027
# Lean Hogs           0.672630
# Live Cattle         0.638459
# Copper              0.620224
# Oats                0.613573
# Feeder Cattle       0.594026
# Sugar               0.584207
# Date                0.442988
# days_since_start    0.442988
# Rough Rice          0.415543
# SPYG                0.404252
# Platinum            0.270246
# Silver              0.176611
# Gold                0.127774
# Cocoa               0.085087
# sin_day_of_week     0.016459
# sin_month           0.011236
# cos_day_of_week    -0.010879
# day_of_week        -0.015411
# Palladium          -0.030591
# Month              -0.038910
# cos_month          -0.070356
# Name: Brent Crude Oil, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 상관관계 히트맵
plt.figure(figsize=(12, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 타겟 변수 제외한 상관관계 기반 Feature Selection
threshold=0.5
correlation_with_target = correlation['Brent Crude Oil'].drop(labels=['Brent Crude Oil'])
selected_features = correlation_with_target[correlation_with_target.abs() > threshold].index.tolist()
# selected_features.remove('Date')
print("선택된 변수들:", selected_features)
# Out:
# 선택된 변수들: ['Coffee', 'Cotton', 'Sugar', 'Oats', 'Soybeans', 'Kansas Wheat', 'Copper', 'Natural Gas', 'Feeder Cattle', 'Lean Hogs', 'Live Cattle']

# %%
# 피처 셀렉션
selected_train_X=train_X[selected_features+time_columns]
selected_test_X=test_X[selected_features+time_columns]

selected_test_X
# Out:
#          Coffee     Cotton      Sugar    Oats  Soybeans  Kansas Wheat  Copper  \
# 0    162.500000  83.430000  23.320000  379.25   1562.00        798.75  3.7790
# 1    161.050003  82.449997  23.530001  402.50   1547.25        849.25  3.7535
# 2    162.350006  82.879997  23.250000  416.75   1525.75        843.25  3.7200
# 3    162.800003  81.199997  23.530001  406.25   1485.50        817.50  3.7670
# 4    161.750000  79.949997  23.440001  414.00   1508.00        810.50  3.7715
# ..          ...        ...        ...     ...       ...           ...     ...
# 245  238.000000  71.290001  19.410000  308.50   1175.25        581.50  4.5270
# 246  231.199997  72.599998  19.100000  304.75   1163.25        576.00  4.3810
# 247  226.350006  72.699997  19.240000  294.50   1162.75        580.00  4.3675
# 248  228.250000  72.019997  20.120001  304.00   1152.25        592.00  4.3285
# 249  228.949997  69.809998  20.309999  309.75   1150.50        587.50  4.3905
#
#      Natural Gas  Feeder Cattle   Lean Hogs  Live Cattle     sin_month  \
# 0          2.709     247.899994   97.824997   176.824997 -5.000000e-01
# 1          2.657     244.699997  101.275002   174.949997 -5.000000e-01
# 2          2.609     242.274994  100.050003   174.574997 -5.000000e-01
# 3          2.582     245.425003   99.000000   177.000000 -5.000000e-01
# 4          2.669     246.250000   98.800003   177.199997 -5.000000e-01
# ..           ...            ...         ...          ...           ...
# 245        2.811     258.899994   89.949997   188.899994  1.224647e-16
# 246        2.756     259.049988   89.000000   189.475006  1.224647e-16
# 247        2.628     261.774994   89.900002   192.925003  1.224647e-16
# 248        2.685     260.649994   89.449997   194.175003  1.224647e-16
# 249        2.601     259.299988   89.574997   193.500000  1.224647e-16
#
#      cos_month  day_of_week  days_since_start  sin_day_of_week  \
# 0    -0.866025            3              1998         0.433884
# 1    -0.866025            5              2000        -0.974928
# 2    -0.866025            6              2001        -0.781831
# 3    -0.866025            0              2002         0.000000
# 4    -0.866025            3              2005         0.433884
# ..         ...          ...               ...              ...
# 245  -1.000000            3              2355         0.433884
# 246  -1.000000            4              2356        -0.433884
# 247  -1.000000            5              2357        -0.974928
# 248  -1.000000            6              2358        -0.781831
# 249  -1.000000            0              2359         0.000000
#
#      cos_day_of_week
# 0          -0.900969
# 1          -0.222521
# 2           0.623490
# 3           1.000000
# 4          -0.900969
# ..               ...
# 245        -0.900969
# 246        -0.900969
# 247        -0.222521
# 248         0.623490
# 249         1.000000
#
# [250 rows x 17 columns]

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 데이터 표준화
train_X_scaled = scaler.fit_transform(selected_train_X)
test_X_scaled = scaler.transform(selected_test_X)
train_y_scaled = scaler.fit_transform(train_y)
test_y_scaled = scaler.transform(test_y)

# 표준화된 결과 확인
print(train_X_scaled[:5])  # 첫 5개 행 출력
# Out:
# [[-0.31896259 -0.30428429 -0.065912   -0.90395425 -0.74203782 -0.95273171
#   -0.19448044 -0.25792155 -0.19937907 -0.350508   -0.05303156  0.65393104
#    1.25246416 -1.14896162 -1.73388323 -0.47966148  1.11661533]
#  [-0.35243856 -0.27476546 -0.07108287 -0.89014585 -0.72563201 -0.92318337
#   -0.22114479 -0.28513215 -0.20632476 -0.33254535 -0.07342589  0.65393104
#    1.25246416 -0.6565495  -1.73216224  0.78667477  0.57305487]
#  [-0.33256215 -0.21959921 -0.08659597 -0.8815156  -0.72735893 -0.92909304
#   -0.21342607 -0.35769349 -0.22253229 -0.31458312 -0.10911567  0.65393104
#    1.25246416 -0.16413737 -1.73044124  1.09943399 -0.64831441]
#  [-0.35557715 -0.27960453 -0.13054947 -0.86252905 -0.71958776 -0.93973044
#   -0.26324623 -0.40587886 -0.33366747 -0.31181951 -0.26207253  0.65393104
#    1.25246416  0.32827475 -1.72872025  0.22310212 -1.62777652]
#  [-0.42462164 -0.27331378 -0.20811447 -0.85217275 -0.73081279 -0.95982332
#   -0.27166659 -0.38320342 -0.34177124 -0.22615294 -0.36531849  0.65393104
#    1.25246416  1.80551112 -1.72355728 -1.74599773  0.57305487]]

# %% [markdown]
# ## 윈도우 크기 결정

# %%
def create_windows(X, y, window_size):
    X_windows, y_windows = [], []
    for i in range(len(X) - window_size):
        X_windows.append(X[i:i + window_size])  # .iloc 대신 기본 인덱싱 사용
        y_windows.append(y[i + window_size])    # .iloc 대신 기본 인덱싱 사용
    return np.array(X_windows), np.array(y_windows)

# %%
# 윈도우 크기
window_size = 30

# Train 데이터 슬라이싱
X_train, y_train = create_windows(
    train_X_scaled,  
    train_y_scaled,  
    window_size
)

# Test 데이터 슬라이싱
X_test, y_test = create_windows(
    test_X_scaled,  
    test_y_scaled,  
    window_size
)

# 결과 확인
print(f"Train X Shape: {X_train.shape}, Train y Shape: {y_train.shape}")
print(f"Test X Shape: {X_test.shape}, Test y Shape: {y_test.shape}")
# Out:
# Train X Shape: (1317, 30, 17), Train y Shape: (1317, 1)
# Test X Shape: (220, 30, 17), Test y Shape: (220, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional, TimeDistributed
from tensorflow.keras import backend as K

# RMSE 정의
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# LSTM 
model = Sequential([
    TimeDistributed(Dense(128, activation='relu', input_shape=(window_size, X_train.shape[2]))),  # 추가 Dense 레이어
    Dropout(0.3),
    LSTM(64, activation='relu'),
    Dropout(0.3),
    Bidirectional(LSTM(32, activation='relu', return_sequences=True)),
    Dense(y_train.shape[1])  # 출력 레이어 (타겟 변수 개수에 맞춤)
])

# 모델 컴파일 (loss에 rmse 사용)
model.compile(optimizer='adam', loss=rmse, metrics=[rmse])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# 체크포인트 콜백 설정
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # 모델이 저장될 경로
    monitor='val_loss',        # val_loss 기준으로 모니터링
    save_best_only=True,       # 최적의 모델만 저장
    mode='min',                # val_loss가 최소일 때 저장
    verbose=1                  # 저장 시 출력 메시지
)

# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=256,
    verbose=2,
    callbacks=[checkpoint_callback]  # 콜백 추가
)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.28950, saving model to best_model.h5
# 6/6 - 5s - loss: 0.7882 - rmse: 0.7497 - val_loss: 0.2895 - val_rmse: 0.2895 - 5s/epoch - 911ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.28950 to 0.24859, saving model to best_model.h5
# 6/6 - 1s - loss: 0.5322 - rmse: 0.5294 - val_loss: 0.2486 - val_rmse: 0.2486 - 686ms/epoch - 114ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.4109 - rmse: 0.4189 - val_loss: 0.3122 - val_rmse: 0.3122 - 656ms/epoch - 109ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.3369 - rmse: 0.3311 - val_loss: 0.4777 - val_rmse: 0.4777 - 712ms/epoch - 119ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.3146 - rmse: 0.3170 - val_loss: 0.4310 - val_rmse: 0.4310 - 614ms/epoch - 102ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.2970 - rmse: 0.2891 - val_loss: 0.3551 - val_rmse: 0.3551 - 557ms/epoch - 93ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.2680 - rmse: 0.2677 - val_loss: 0.7296 - val_rmse: 0.7296 - 585ms/epoch - 97ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.2330 - rmse: 0.2323 - val_loss: 0.6424 - val_rmse: 0.6424 - 589ms/epoch - 98ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.2188 - rmse: 0.2170 - val_loss: 0.6144 - val_rmse: 0.6144 - 669ms/epoch - 112ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.2182 - rmse: 0.2145 - val_loss: 0.6330 - val_rmse: 0.6330 - 625ms/epoch - 104ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.2092 - rmse: 0.2102 - val_loss: 0.4513 - val_rmse: 0.4513 - 594ms/epoch - 99ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.2001 - rmse: 0.2122 - val_loss: 0.5314 - val_rmse: 0.5314 - 631ms/epoch - 105ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1944 - rmse: 0.1914 - val_loss: 0.5068 - val_rmse: 0.5068 - 570ms/epoch - 95ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1829 - rmse: 0.1776 - val_loss: 0.5513 - val_rmse: 0.5513 - 630ms/epoch - 105ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1890 - rmse: 0.1829 - val_loss: 0.4087 - val_rmse: 0.4087 - 600ms/epoch - 100ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1738 - rmse: 0.1734 - val_loss: 0.5024 - val_rmse: 0.5024 - 627ms/epoch - 105ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1725 - rmse: 0.1702 - val_loss: 0.5173 - val_rmse: 0.5173 - 561ms/epoch - 94ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1726 - rmse: 0.1671 - val_loss: 0.4999 - val_rmse: 0.4999 - 592ms/epoch - 99ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1613 - rmse: 0.1643 - val_loss: 0.5211 - val_rmse: 0.5211 - 606ms/epoch - 101ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1792 - rmse: 0.1792 - val_loss: 0.5253 - val_rmse: 0.5253 - 593ms/epoch - 99ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1662 - rmse: 0.1646 - val_loss: 0.6004 - val_rmse: 0.6004 - 666ms/epoch - 111ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1581 - rmse: 0.1566 - val_loss: 0.5311 - val_rmse: 0.5311 - 625ms/epoch - 104ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1605 - rmse: 0.1599 - val_loss: 0.5541 - val_rmse: 0.5541 - 595ms/epoch - 99ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1548 - rmse: 0.1502 - val_loss: 0.5264 - val_rmse: 0.5264 - 593ms/epoch - 99ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1543 - rmse: 0.1545 - val_loss: 0.5354 - val_rmse: 0.5354 - 630ms/epoch - 105ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1515 - rmse: 0.1423 - val_loss: 0.5372 - val_rmse: 0.5372 - 593ms/epoch - 99ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1624 - rmse: 0.1628 - val_loss: 0.5531 - val_rmse: 0.5531 - 633ms/epoch - 105ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1570 - rmse: 0.1553 - val_loss: 0.4823 - val_rmse: 0.4823 - 643ms/epoch - 107ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1756 - rmse: 0.1799 - val_loss: 0.4563 - val_rmse: 0.4563 - 677ms/epoch - 113ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1551 - rmse: 0.1567 - val_loss: 0.5430 - val_rmse: 0.5430 - 636ms/epoch - 106ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1528 - rmse: 0.1522 - val_loss: 0.5196 - val_rmse: 0.5196 - 639ms/epoch - 106ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1557 - rmse: 0.1532 - val_loss: 0.4513 - val_rmse: 0.4513 - 639ms/epoch - 106ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1493 - rmse: 0.1501 - val_loss: 0.5253 - val_rmse: 0.5253 - 678ms/epoch - 113ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1481 - rmse: 0.1407 - val_loss: 0.5746 - val_rmse: 0.5746 - 616ms/epoch - 103ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1433 - rmse: 0.1403 - val_loss: 0.5843 - val_rmse: 0.5843 - 685ms/epoch - 114ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1501 - rmse: 0.1589 - val_loss: 0.5400 - val_rmse: 0.5400 - 609ms/epoch - 101ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1535 - rmse: 0.1532 - val_loss: 0.5502 - val_rmse: 0.5502 - 673ms/epoch - 112ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1599 - rmse: 0.1564 - val_loss: 0.5584 - val_rmse: 0.5584 - 579ms/epoch - 96ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1534 - rmse: 0.1546 - val_loss: 0.5258 - val_rmse: 0.5258 - 635ms/epoch - 106ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1503 - rmse: 0.1510 - val_loss: 0.4874 - val_rmse: 0.4874 - 567ms/epoch - 95ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1747 - rmse: 0.1740 - val_loss: 0.5371 - val_rmse: 0.5371 - 640ms/epoch - 107ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1653 - rmse: 0.1637 - val_loss: 0.5083 - val_rmse: 0.5083 - 633ms/epoch - 106ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1556 - rmse: 0.1544 - val_loss: 0.5435 - val_rmse: 0.5435 - 559ms/epoch - 93ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1519 - rmse: 0.1490 - val_loss: 0.5503 - val_rmse: 0.5503 - 560ms/epoch - 93ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1449 - rmse: 0.1434 - val_loss: 0.4872 - val_rmse: 0.4872 - 575ms/epoch - 96ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1404 - rmse: 0.1355 - val_loss: 0.4547 - val_rmse: 0.4547 - 563ms/epoch - 94ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1426 - rmse: 0.1421 - val_loss: 0.5387 - val_rmse: 0.5387 - 630ms/epoch - 105ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1387 - rmse: 0.1425 - val_loss: 0.5635 - val_rmse: 0.5635 - 634ms/epoch - 106ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1419 - rmse: 0.1415 - val_loss: 0.5984 - val_rmse: 0.5984 - 627ms/epoch - 105ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1441 - rmse: 0.1431 - val_loss: 0.5134 - val_rmse: 0.5134 - 596ms/epoch - 99ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1494 - rmse: 0.1519 - val_loss: 0.4867 - val_rmse: 0.4867 - 599ms/epoch - 100ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1465 - rmse: 0.1444 - val_loss: 0.5084 - val_rmse: 0.5084 - 604ms/epoch - 101ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1431 - rmse: 0.1395 - val_loss: 0.4993 - val_rmse: 0.4993 - 638ms/epoch - 106ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1522 - rmse: 0.1525 - val_loss: 0.5046 - val_rmse: 0.5046 - 605ms/epoch - 101ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1415 - rmse: 0.1416 - val_loss: 0.5631 - val_rmse: 0.5631 - 647ms/epoch - 108ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1406 - rmse: 0.1418 - val_loss: 0.5582 - val_rmse: 0.5582 - 676ms/epoch - 113ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1338 - rmse: 0.1296 - val_loss: 0.5520 - val_rmse: 0.5520 - 637ms/epoch - 106ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1345 - rmse: 0.1357 - val_loss: 0.5514 - val_rmse: 0.5514 - 565ms/epoch - 94ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1275 - rmse: 0.1233 - val_loss: 0.5196 - val_rmse: 0.5196 - 574ms/epoch - 96ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1290 - rmse: 0.1311 - val_loss: 0.5434 - val_rmse: 0.5434 - 628ms/epoch - 105ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1283 - rmse: 0.1208 - val_loss: 0.5576 - val_rmse: 0.5576 - 667ms/epoch - 111ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1311 - rmse: 0.1297 - val_loss: 0.5366 - val_rmse: 0.5366 - 596ms/epoch - 99ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1366 - rmse: 0.1360 - val_loss: 0.4935 - val_rmse: 0.4935 - 631ms/epoch - 105ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1317 - rmse: 0.1308 - val_loss: 0.5322 - val_rmse: 0.5322 - 648ms/epoch - 108ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1333 - rmse: 0.1358 - val_loss: 0.5273 - val_rmse: 0.5273 - 577ms/epoch - 96ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1285 - rmse: 0.1283 - val_loss: 0.4970 - val_rmse: 0.4970 - 594ms/epoch - 99ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1258 - rmse: 0.1243 - val_loss: 0.4826 - val_rmse: 0.4826 - 672ms/epoch - 112ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1226 - rmse: 0.1218 - val_loss: 0.5158 - val_rmse: 0.5158 - 662ms/epoch - 110ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1303 - rmse: 0.1289 - val_loss: 0.5090 - val_rmse: 0.5090 - 667ms/epoch - 111ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1276 - rmse: 0.1280 - val_loss: 0.5461 - val_rmse: 0.5461 - 616ms/epoch - 103ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1257 - rmse: 0.1275 - val_loss: 0.5651 - val_rmse: 0.5651 - 625ms/epoch - 104ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1241 - rmse: 0.1213 - val_loss: 0.5435 - val_rmse: 0.5435 - 662ms/epoch - 110ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1302 - rmse: 0.1281 - val_loss: 0.5268 - val_rmse: 0.5268 - 681ms/epoch - 113ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1285 - rmse: 0.1243 - val_loss: 0.5669 - val_rmse: 0.5669 - 617ms/epoch - 103ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1267 - rmse: 0.1248 - val_loss: 0.5311 - val_rmse: 0.5311 - 709ms/epoch - 118ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1326 - rmse: 0.1297 - val_loss: 0.5124 - val_rmse: 0.5124 - 696ms/epoch - 116ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1299 - rmse: 0.1240 - val_loss: 0.5407 - val_rmse: 0.5407 - 656ms/epoch - 109ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1188 - rmse: 0.1164 - val_loss: 0.5053 - val_rmse: 0.5053 - 630ms/epoch - 105ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1209 - rmse: 0.1173 - val_loss: 0.5300 - val_rmse: 0.5300 - 618ms/epoch - 103ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1260 - rmse: 0.1248 - val_loss: 0.5106 - val_rmse: 0.5106 - 595ms/epoch - 99ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1224 - rmse: 0.1247 - val_loss: 0.4825 - val_rmse: 0.4825 - 692ms/epoch - 115ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1274 - rmse: 0.1269 - val_loss: 0.4772 - val_rmse: 0.4772 - 650ms/epoch - 108ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1184 - rmse: 0.1189 - val_loss: 0.5400 - val_rmse: 0.5400 - 658ms/epoch - 110ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1302 - rmse: 0.1336 - val_loss: 0.4920 - val_rmse: 0.4920 - 608ms/epoch - 101ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1291 - rmse: 0.1232 - val_loss: 0.4980 - val_rmse: 0.4980 - 601ms/epoch - 100ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1252 - rmse: 0.1271 - val_loss: 0.5457 - val_rmse: 0.5457 - 605ms/epoch - 101ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1221 - rmse: 0.1206 - val_loss: 0.4949 - val_rmse: 0.4949 - 652ms/epoch - 109ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1185 - rmse: 0.1195 - val_loss: 0.5108 - val_rmse: 0.5108 - 682ms/epoch - 114ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1236 - rmse: 0.1238 - val_loss: 0.5373 - val_rmse: 0.5373 - 580ms/epoch - 97ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1203 - rmse: 0.1301 - val_loss: 0.4985 - val_rmse: 0.4985 - 611ms/epoch - 102ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1246 - rmse: 0.1202 - val_loss: 0.5552 - val_rmse: 0.5552 - 607ms/epoch - 101ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1236 - rmse: 0.1213 - val_loss: 0.5147 - val_rmse: 0.5147 - 636ms/epoch - 106ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1206 - rmse: 0.1225 - val_loss: 0.4985 - val_rmse: 0.4985 - 564ms/epoch - 94ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1210 - rmse: 0.1224 - val_loss: 0.5076 - val_rmse: 0.5076 - 646ms/epoch - 108ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1190 - rmse: 0.1164 - val_loss: 0.4870 - val_rmse: 0.4870 - 639ms/epoch - 106ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1196 - rmse: 0.1175 - val_loss: 0.5308 - val_rmse: 0.5308 - 600ms/epoch - 100ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1121 - rmse: 0.1186 - val_loss: 0.5130 - val_rmse: 0.5130 - 666ms/epoch - 111ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1154 - rmse: 0.1148 - val_loss: 0.5655 - val_rmse: 0.5655 - 709ms/epoch - 118ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1164 - rmse: 0.1137 - val_loss: 0.5194 - val_rmse: 0.5194 - 651ms/epoch - 108ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.24859
# 6/6 - 1s - loss: 0.1183 - rmse: 0.1237 - val_loss: 0.5262 - val_rmse: 0.5262 - 746ms/epoch - 124ms/step

# %%
from tensorflow.keras.models import load_model

# 저장된 최적의 모델 로드
best_model = load_model('best_model.h5', custom_objects={'rmse': rmse})

# 모델 평가
loss, rmse_v = best_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss}, Test RMSE: {rmse_v}")
# Out:
# Test Loss: 0.23433317244052887, Test RMSE: 0.23357507586479187

# %%
# 원하는 에포크 시작점 설정 (예: 10번째 에포크부터)
start_epoch = 100
history_dict= history.history
# 슬라이싱해서 데이터 제한
epochs = range(start_epoch, len(history_dict['rmse']) + 1)  # 에포크는 10부터 시작
loss = history_dict['rmse'][start_epoch - 1:]              # 10번째 에포크부터
val_loss = history_dict['val_rmse'][start_epoch - 1:]      # 10번째 에포크부터

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, val_loss, label='Validation Loss', marker='x', linestyle='--')
plt.title(f'Training and Validation Loss from Epoch {start_epoch}')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 예측
y_pred = best_model.predict(X_test)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted Prices')
plt.show()
# Out:
# 7/7 [==============================] - 1s 19ms/step

# %%
# RMSE 정의
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))  # Keras 없이 NumPy로 계산

# 예측 수행
y_pred_scaled = best_model.predict(X_test)  # 학습된 모델로 예측 (이미 스케일링된 X_test 사용)

# Test 데이터에서 y_pred_scaled와 같은 샘플 수만큼 슬라이싱
y_test_trimmed = test_y[window_size:].to_numpy()  # 원본 y_test 크기 맞추기

# 복원: y_pred_scaled와 pivot_test_X_scaled를 합쳐서 원래 스케일 복원
pivot_test_X_trimmed = test_X_scaled[window_size:]

# 예측 결과와 입력 데이터를 합침
test_combined = np.hstack([pivot_test_X_trimmed, y_pred_scaled])

# 스케일러로 역변환 (y_pred 복원)
test_combined_restored = scaler.inverse_transform(test_combined)
y_pred_restored = test_combined_restored[:, -1]  # 마지막 열이 복원된 y 예측값

# RMSE 계산 (y_test_trimmed은 복원할 필요 없음)
rmse_value = rmse(y_test_trimmed, y_pred_restored)
print("복원된 데이터 평가 (RMSE):", rmse_value)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test_trimmed, label="Actual")
plt.plot(y_pred_restored, label="Predicted")
plt.legend()
plt.title("Actual vs Predicted Prices (Restored)")
plt.show()
# Out:
# 7/7 [==============================] - 0s 18ms/step
# 복원된 데이터 평가 (RMSE): 5.476497258347724
