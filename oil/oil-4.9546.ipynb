# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
train_X = pd.read_excel('.\\preprocess\\train_x_data.xlsx')
train_y = pd.read_excel('.\\preprocess\\train_y_data.xlsx')
test_X = pd.read_excel('.\\preprocess\\test_x_data.xlsx')
test_y = pd.read_excel('.\\preprocess\\test_y_data.xlsx')

train_X
# Out:
#            Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0    2018-01-02                 0  33.279999   1936  130.199997  77.500000
# 1    2018-01-03                 1  33.570000   1907  128.600006  78.110001
# 2    2018-01-04                 2  33.700001   1905  129.550003  79.250000
# 3    2018-01-05                 3  34.029999   1895  128.449997  78.010002
# 4    2018-01-08                 6  34.099998   1914  125.150002  78.139999
# ...         ...               ...        ...    ...         ...        ...
# 1342 2023-06-26              2001  59.279999   3206  167.949997  77.070000
# 1343 2023-06-27              2002  59.930000   3212  169.449997  77.639999
# 1344 2023-06-28              2003  60.000000   3292  165.649994  80.120003
# 1345 2023-06-29              2004  60.209999   3218  163.600006  81.250000
# 1346 2023-06-30              2005  61.010000   3318  161.000000  82.839996
#
#           Sugar    Oats  Rough Rice  Soybeans  Kansas Wheat  Copper  \
# 0     15.330000  242.50      1153.5    955.00        434.75  3.2560
# 1     15.310000  244.50      1141.0    959.75        441.00  3.2370
# 2     15.250000  245.75      1147.5    959.25        439.75  3.2425
# 3     15.080000  248.50      1156.5    961.50        437.50  3.2070
# 4     14.780000  250.00      1164.5    958.25        433.25  3.2010
# ...         ...     ...         ...       ...           ...     ...
# 1342  23.719999  391.25      1794.0   1521.00        866.50  3.7865
# 1343  23.030001  385.00      1767.5   1495.00        837.75  3.7815
# 1344  22.570000  377.00      1748.5   1451.00        800.75  3.7205
# 1345  22.070000  367.75      1770.5   1483.00        794.25  3.6775
# 1346  22.889999  377.25      1805.5   1557.25        801.25  3.7410
#
#              Gold    Palladium    Platinum     Silver  Natural Gas  \
# 0     1313.699951  1090.000000  943.799988  17.121000        3.056
# 1     1316.199951  1086.000000  957.799988  17.184999        3.008
# 2     1319.400024  1097.400024  966.099976  17.188999        2.880
# 3     1320.300049  1084.849976  971.200012  17.205000        2.795
# 4     1318.599976  1098.550049  972.299988  17.063999        2.835
# ...           ...          ...         ...        ...          ...
# 1342  1923.699951  1291.800049  936.700012  22.805000        2.791
# 1343  1914.000000  1283.199951  936.599976  22.938999        2.763
# 1344  1912.300049  1236.000000  923.400024  22.868000        2.603
# 1345  1909.199951  1218.800049  897.799988  22.591000        2.701
# 1346  1921.099976  1213.400024  904.500000  22.809999        2.798
#
#       Feeder Cattle  Lean Hogs  Live Cattle
# 0        149.524994  70.724998   123.349998
# 1        149.375000  71.050003   122.949997
# 2        149.024994  71.375000   122.250000
# 3        146.625000  71.425003   119.250000
# 4        146.449997  72.974998   117.224998
# ...             ...        ...          ...
# 1342     233.675003  93.400002   177.699997
# 1343     238.500000  94.125000   179.300003
# 1344     240.250000  94.275002   179.625000
# 1345     242.375000  95.449997   179.750000
# 1346     247.574997  95.650002   181.500000
#
# [1347 rows x 20 columns]

# %%
import pandas as pd
import numpy as np

time_columns=['sin_month','cos_month', 'day_of_week','days_since_start','sin_day_of_week','cos_day_of_week']

# Date 컬럼을 날짜 형식으로 변환
train_X['Date'] = pd.to_datetime(train_X['Date'])
test_X['Date'] = pd.to_datetime(test_X['Date'])


# 월(Month) 추출
train_X['Month'] = train_X['Date'].dt.month
test_X['Month'] = test_X['Date'].dt.month

# 월 주기 변환 (sin, cos)
train_X['sin_month'] = np.sin(2 * np.pi * train_X['Month'] / 12)
train_X['cos_month'] = np.cos(2 * np.pi * train_X['Month'] / 12)

test_X['sin_month'] = np.sin(2 * np.pi * test_X['Month'] / 12)
test_X['cos_month'] = np.cos(2 * np.pi * test_X['Month'] / 12)

print(train_X.head())
test_X.head()
# Out:
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2018-01-02                 0  33.279999   1936  130.199997  77.500000
# 1 2018-01-03                 1  33.570000   1907  128.600006  78.110001
# 2 2018-01-04                 2  33.700001   1905  129.550003  79.250000
# 3 2018-01-05                 3  34.029999   1895  128.449997  78.010002
# 4 2018-01-08                 6  34.099998   1914  125.150002  78.139999
#
#    Sugar    Oats  Rough Rice  Soybeans  ...    Palladium    Platinum  \
# 0  15.33  242.50      1153.5    955.00  ...  1090.000000  943.799988
# 1  15.31  244.50      1141.0    959.75  ...  1086.000000  957.799988
# 2  15.25  245.75      1147.5    959.25  ...  1097.400024  966.099976
# 3  15.08  248.50      1156.5    961.50  ...  1084.849976  971.200012
# 4  14.78  250.00      1164.5    958.25  ...  1098.550049  972.299988
#
#       Silver  Natural Gas  Feeder Cattle  Lean Hogs  Live Cattle  Month  \
# 0  17.121000        3.056     149.524994  70.724998   123.349998      1
# 1  17.184999        3.008     149.375000  71.050003   122.949997      1
# 2  17.188999        2.880     149.024994  71.375000   122.250000      1
# 3  17.205000        2.795     146.625000  71.425003   119.250000      1
# 4  17.063999        2.835     146.449997  72.974998   117.224998      1
#
#    sin_month  cos_month
# 0        0.5   0.866025
# 1        0.5   0.866025
# 2        0.5   0.866025
# 3        0.5   0.866025
# 4        0.5   0.866025
#
# [5 rows x 23 columns]
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2023-07-03              1998  61.049999   3364  162.500000  83.430000
# 1 2023-07-05              2000  60.939999   3334  161.050003  82.449997
# 2 2023-07-06              2001  60.470001   3277  162.350006  82.879997
# 3 2023-07-07              2002  60.240002   3274  162.800003  81.199997
# 4 2023-07-10              2005  60.209999   3299  161.750000  79.949997
#
#        Sugar    Oats  Rough Rice  Soybeans  ...    Palladium    Platinum  \
# 0  23.320000  379.25      1804.5   1562.00  ...  1218.400024  909.299988
# 1  23.530001  402.50      1827.0   1547.25  ...  1249.300049  918.099976
# 2  23.250000  416.75      1864.0   1525.75  ...  1230.800049  904.500000
# 3  23.530001  406.25      1868.5   1485.50  ...  1236.500000  910.099976
# 4  23.440001  414.00      1910.0   1508.00  ...  1228.099976  929.200012
#
#       Silver  Natural Gas  Feeder Cattle   Lean Hogs  Live Cattle  Month  \
# 0  22.896000        2.709     247.899994   97.824997   176.824997      7
# 1  23.197001        2.657     244.699997  101.275002   174.949997      7
# 2  22.686001        2.609     242.274994  100.050003   174.574997      7
# 3  23.091999        2.582     245.425003   99.000000   177.000000      7
# 4  23.150999        2.669     246.250000   98.800003   177.199997      7
#
#    sin_month  cos_month
# 0       -0.5  -0.866025
# 1       -0.5  -0.866025
# 2       -0.5  -0.866025
# 3       -0.5  -0.866025
# 4       -0.5  -0.866025
#
# [5 rows x 23 columns]

# %%
# 요일 계산 (days_since_start를 7로 나눈 나머지)
train_X['day_of_week'] = train_X['days_since_start'] % 7
test_X['day_of_week'] = test_X['days_since_start'] % 7


# 요일 주기 변환 (sin, cos)
train_X['sin_day_of_week'] = np.sin(2 * np.pi * train_X['day_of_week'] / 7)
train_X['cos_day_of_week'] = np.cos(2 * np.pi * train_X['day_of_week'] / 7)

test_X['sin_day_of_week'] = np.sin(2 * np.pi * test_X['day_of_week'] / 7)
test_X['cos_day_of_week'] = np.cos(2 * np.pi * test_X['day_of_week'] / 7)

print(train_X.head())
test_X.head()
# Out:
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2018-01-02                 0  33.279999   1936  130.199997  77.500000
# 1 2018-01-03                 1  33.570000   1907  128.600006  78.110001
# 2 2018-01-04                 2  33.700001   1905  129.550003  79.250000
# 3 2018-01-05                 3  34.029999   1895  128.449997  78.010002
# 4 2018-01-08                 6  34.099998   1914  125.150002  78.139999
#
#    Sugar    Oats  Rough Rice  Soybeans  ...  Natural Gas  Feeder Cattle  \
# 0  15.33  242.50      1153.5    955.00  ...        3.056     149.524994
# 1  15.31  244.50      1141.0    959.75  ...        3.008     149.375000
# 2  15.25  245.75      1147.5    959.25  ...        2.880     149.024994
# 3  15.08  248.50      1156.5    961.50  ...        2.795     146.625000
# 4  14.78  250.00      1164.5    958.25  ...        2.835     146.449997
#
#    Lean Hogs  Live Cattle  Month  sin_month  cos_month  day_of_week  \
# 0  70.724998   123.349998      1        0.5   0.866025            0
# 1  71.050003   122.949997      1        0.5   0.866025            1
# 2  71.375000   122.250000      1        0.5   0.866025            2
# 3  71.425003   119.250000      1        0.5   0.866025            3
# 4  72.974998   117.224998      1        0.5   0.866025            6
#
#    sin_day_of_week  cos_day_of_week
# 0         0.000000         1.000000
# 1         0.781831         0.623490
# 2         0.974928        -0.222521
# 3         0.433884        -0.900969
# 4        -0.781831         0.623490
#
# [5 rows x 26 columns]
#         Date  days_since_start       SPYG  Cocoa      Coffee     Cotton  \
# 0 2023-07-03              1998  61.049999   3364  162.500000  83.430000
# 1 2023-07-05              2000  60.939999   3334  161.050003  82.449997
# 2 2023-07-06              2001  60.470001   3277  162.350006  82.879997
# 3 2023-07-07              2002  60.240002   3274  162.800003  81.199997
# 4 2023-07-10              2005  60.209999   3299  161.750000  79.949997
#
#        Sugar    Oats  Rough Rice  Soybeans  ...  Natural Gas  Feeder Cattle  \
# 0  23.320000  379.25      1804.5   1562.00  ...        2.709     247.899994
# 1  23.530001  402.50      1827.0   1547.25  ...        2.657     244.699997
# 2  23.250000  416.75      1864.0   1525.75  ...        2.609     242.274994
# 3  23.530001  406.25      1868.5   1485.50  ...        2.582     245.425003
# 4  23.440001  414.00      1910.0   1508.00  ...        2.669     246.250000
#
#     Lean Hogs  Live Cattle  Month  sin_month  cos_month  day_of_week  \
# 0   97.824997   176.824997      7       -0.5  -0.866025            3
# 1  101.275002   174.949997      7       -0.5  -0.866025            5
# 2  100.050003   174.574997      7       -0.5  -0.866025            6
# 3   99.000000   177.000000      7       -0.5  -0.866025            0
# 4   98.800003   177.199997      7       -0.5  -0.866025            3
#
#    sin_day_of_week  cos_day_of_week
# 0         0.433884        -0.900969
# 1        -0.974928        -0.222521
# 2        -0.781831         0.623490
# 3         0.000000         1.000000
# 4         0.433884        -0.900969
#
# [5 rows x 26 columns]

# %%
# 결측치 확인
print(train_X.isnull().sum())
print(train_y.isnull().sum())
print(test_X.isnull().sum())
print(test_y.isnull().sum())
# Out:
# Date                0
# days_since_start    0
# SPYG                0
# Cocoa               0
# Coffee              0
# Cotton              0
# Sugar               0
# Oats                0
# Rough Rice          0
# Soybeans            0
# Kansas Wheat        0
# Copper              0
# Gold                0
# Palladium           0
# Platinum            0
# Silver              0
# Natural Gas         0
# Feeder Cattle       0
# Lean Hogs           0
# Live Cattle         0
# Month               0
# sin_month           0
# cos_month           0
# day_of_week         0
# sin_day_of_week     0
# cos_day_of_week     0
# dtype: int64
# Brent Crude Oil    0
# dtype: int64
# Date                0
# days_since_start    0
# SPYG                0
# Cocoa               0
# Coffee              0
# Cotton              0
# Sugar               0
# Oats                0
# Rough Rice          0
# Soybeans            0
# Kansas Wheat        0
# Copper              0
# Gold                0
# Palladium           0
# Platinum            0
# Silver              0
# Natural Gas         0
# Feeder Cattle       0
# Lean Hogs           0
# Live Cattle         0
# Month               0
# sin_month           0
# cos_month           0
# day_of_week         0
# sin_day_of_week     0
# cos_day_of_week     0
# dtype: int64
# Brent Crude Oil    0
# dtype: int64

# %%
# 데이터 통합
train_data = pd.concat([train_X, train_y], axis=1)
test_data = pd.concat([test_X, test_y], axis=1)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)
# Out:
# 타겟 변수와의 상관관계:
#  Brent Crude Oil     1.000000
# Cotton              0.819240
# Kansas Wheat        0.782843
# Natural Gas         0.745098
# Coffee              0.731278
# Soybeans            0.687027
# Lean Hogs           0.672630
# Live Cattle         0.638459
# Copper              0.620224
# Oats                0.613573
# Feeder Cattle       0.594026
# Sugar               0.584207
# Date                0.442988
# days_since_start    0.442988
# Rough Rice          0.415543
# SPYG                0.404252
# Platinum            0.270246
# Silver              0.176611
# Gold                0.127774
# Cocoa               0.085087
# sin_day_of_week     0.016459
# sin_month           0.011236
# cos_day_of_week    -0.010879
# day_of_week        -0.015411
# Palladium          -0.030591
# Month              -0.038910
# cos_month          -0.070356
# Name: Brent Crude Oil, dtype: float64
# 타겟 변수와의 상관관계:
#  Brent Crude Oil     1.000000
# Cotton              0.819240
# Kansas Wheat        0.782843
# Natural Gas         0.745098
# Coffee              0.731278
# Soybeans            0.687027
# Lean Hogs           0.672630
# Live Cattle         0.638459
# Copper              0.620224
# Oats                0.613573
# Feeder Cattle       0.594026
# Sugar               0.584207
# Date                0.442988
# days_since_start    0.442988
# Rough Rice          0.415543
# SPYG                0.404252
# Platinum            0.270246
# Silver              0.176611
# Gold                0.127774
# Cocoa               0.085087
# sin_day_of_week     0.016459
# sin_month           0.011236
# cos_day_of_week    -0.010879
# day_of_week        -0.015411
# Palladium          -0.030591
# Month              -0.038910
# cos_month          -0.070356
# Name: Brent Crude Oil, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 상관관계 히트맵
plt.figure(figsize=(12, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 타겟 변수 제외한 상관관계 기반 Feature Selection
threshold=0.5
correlation_with_target = correlation['Brent Crude Oil'].drop(labels=['Brent Crude Oil'])
selected_features = correlation_with_target[correlation_with_target.abs() > threshold].index.tolist()
if 'Date' in selected_features:
    selected_features.remove('Date')
print("선택된 변수들:", selected_features)
print("시간 변수:",time_columns)
# Out:
# 선택된 변수들: ['Coffee', 'Cotton', 'Sugar', 'Oats', 'Soybeans', 'Kansas Wheat', 'Copper', 'Natural Gas', 'Feeder Cattle', 'Lean Hogs', 'Live Cattle']
# 시간 변수: ['sin_month', 'cos_month', 'day_of_week', 'days_since_start', 'sin_day_of_week', 'cos_day_of_week']

# %%
# 피처 셀렉션
# selected_train_X=train_X[selected_features+time_columns]
# selected_test_X=test_X[selected_features+time_columns]
selected_train_X=train_X[selected_features+['cos_day_of_week']]
selected_test_X=test_X[selected_features+['cos_day_of_week']]

selected_test_X
# Out:
#          Coffee     Cotton      Sugar    Oats  Soybeans  Kansas Wheat  Copper  \
# 0    162.500000  83.430000  23.320000  379.25   1562.00        798.75  3.7790
# 1    161.050003  82.449997  23.530001  402.50   1547.25        849.25  3.7535
# 2    162.350006  82.879997  23.250000  416.75   1525.75        843.25  3.7200
# 3    162.800003  81.199997  23.530001  406.25   1485.50        817.50  3.7670
# 4    161.750000  79.949997  23.440001  414.00   1508.00        810.50  3.7715
# ..          ...        ...        ...     ...       ...           ...     ...
# 245  238.000000  71.290001  19.410000  308.50   1175.25        581.50  4.5270
# 246  231.199997  72.599998  19.100000  304.75   1163.25        576.00  4.3810
# 247  226.350006  72.699997  19.240000  294.50   1162.75        580.00  4.3675
# 248  228.250000  72.019997  20.120001  304.00   1152.25        592.00  4.3285
# 249  228.949997  69.809998  20.309999  309.75   1150.50        587.50  4.3905
#
#      Natural Gas  Feeder Cattle   Lean Hogs  Live Cattle  cos_day_of_week
# 0          2.709     247.899994   97.824997   176.824997        -0.900969
# 1          2.657     244.699997  101.275002   174.949997        -0.222521
# 2          2.609     242.274994  100.050003   174.574997         0.623490
# 3          2.582     245.425003   99.000000   177.000000         1.000000
# 4          2.669     246.250000   98.800003   177.199997        -0.900969
# ..           ...            ...         ...          ...              ...
# 245        2.811     258.899994   89.949997   188.899994        -0.900969
# 246        2.756     259.049988   89.000000   189.475006        -0.900969
# 247        2.628     261.774994   89.900002   192.925003        -0.222521
# 248        2.685     260.649994   89.449997   194.175003         0.623490
# 249        2.601     259.299988   89.574997   193.500000         1.000000
#
# [250 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 데이터 표준화
train_X_scaled = scaler.fit_transform(selected_train_X)
test_X_scaled = scaler.transform(selected_test_X)
train_y_scaled = scaler.fit_transform(train_y)
test_y_scaled = scaler.transform(test_y)

# 표준화된 결과 확인
print(train_X_scaled[:5])  # 첫 5개 행 출력
# Out:
# [[-0.31896259 -0.30428429 -0.065912   -0.90395425 -0.74203782 -0.95273171
#   -0.19448044 -0.25792155 -0.19937907 -0.350508   -0.05303156  1.11661533]
#  [-0.35243856 -0.27476546 -0.07108287 -0.89014585 -0.72563201 -0.92318337
#   -0.22114479 -0.28513215 -0.20632476 -0.33254535 -0.07342589  0.57305487]
#  [-0.33256215 -0.21959921 -0.08659597 -0.8815156  -0.72735893 -0.92909304
#   -0.21342607 -0.35769349 -0.22253229 -0.31458312 -0.10911567 -0.64831441]
#  [-0.35557715 -0.27960453 -0.13054947 -0.86252905 -0.71958776 -0.93973044
#   -0.26324623 -0.40587886 -0.33366747 -0.31181951 -0.26207253 -1.62777652]
#  [-0.42462164 -0.27331378 -0.20811447 -0.85217275 -0.73081279 -0.95982332
#   -0.27166659 -0.38320342 -0.34177124 -0.22615294 -0.36531849  0.57305487]]

# %% [markdown]
# ## 윈도우 크기 결정

# %%
def create_windows(X, y, window_size):
    X_windows, y_windows = [], []
    for i in range(len(X) - window_size):
        X_windows.append(X[i:i + window_size])  # .iloc 대신 기본 인덱싱 사용
        y_windows.append(y[i + window_size])    # .iloc 대신 기본 인덱싱 사용
    return np.array(X_windows), np.array(y_windows)

# %%
# 윈도우 크기
window_size = 15

# Train 데이터 슬라이싱
X_train, y_train = create_windows(
    train_X_scaled,  
    train_y_scaled,  
    window_size
)

# Test 데이터 슬라이싱
X_test, y_test = create_windows(
    test_X_scaled,  
    test_y_scaled,  
    window_size
)

# 결과 확인
print(f"Train X Shape: {X_train.shape}, Train y Shape: {y_train.shape}")
print(f"Test X Shape: {X_test.shape}, Test y Shape: {y_test.shape}")
# Out:
# Train X Shape: (1332, 15, 12), Train y Shape: (1332, 1)
# Test X Shape: (235, 15, 12), Test y Shape: (235, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dropout, Dense, Bidirectional
from tensorflow.keras import backend as K

# RMSE 정의
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# 모델 정의
model = Sequential([
    Dropout(0.3),
    Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(window_size, X_train.shape[2])),  # Conv1D 레이어
    Dropout(0.3),
    LSTM(64, activation='relu', return_sequences=True),  # LSTM 레이어
    Dropout(0.3),
    Conv1D(filters=32, kernel_size=3, activation='relu'),  # Conv1D 레이어
    Dropout(0.3),
    Bidirectional(LSTM(32, activation='relu')),  # Bidirectional LSTM
    Dense(y_train.shape[1])  # 출력 레이어
])
# 모델을 빌드 (X_train을 이용해 모델을 실행)
model.build(input_shape=(None, window_size, X_train.shape[2]))  # 입력 형태에 맞게 빌드

# 모델 컴파일 (loss에 rmse 사용)
model.compile(optimizer='adam', loss=rmse, metrics=[rmse])

# 모델 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout (Dropout)           (None, 15, 12)            0
#
#  conv1d (Conv1D)             (None, 15, 64)            832
#
#  dropout_1 (Dropout)         (None, 15, 64)            0
#
#  lstm (LSTM)                 (None, 15, 64)            33024
#
#  dropout_2 (Dropout)         (None, 15, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 13, 32)            6176
#
#  dropout_3 (Dropout)         (None, 13, 32)            0
#
#  bidirectional (Bidirectiona  (None, 64)               16640
#  l)
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 56,737
# Trainable params: 56,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

# 모델 구조를 이미지로 출력 (파일로 저장)
plot_model(model, to_file='model_structure.png', show_shapes=True, show_layer_names=True)

# 주피터 노트북에서 이미지 직접 출력
from IPython.display import Image, HTML
Image('model_structure.png')


# 이미지를 출력하면서 다운로드 링크 생성
file_path = 'model_structure.png'
display(HTML(f'<a href="{file_path}" download>모델 구조 이미지 다운로드</a>'))
# Out:
# <a href="model_structure.png" download>모델 구조 이미지 다운로드</a>

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# 체크포인트 콜백 설정
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # 모델이 저장될 경로
    monitor='val_loss',        # val_loss 기준으로 모니터링
    save_best_only=True,       # 최적의 모델만 저장
    mode='min',                # val_loss가 최소일 때 저장
    verbose=1                  # 저장 시 출력 메시지
)

# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=256,
    verbose=2,
    callbacks=[checkpoint_callback]  # 콜백 추가
)
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.20425, saving model to best_model.h5
# 6/6 - 5s - loss: 0.8915 - rmse: 0.8706 - val_loss: 0.2043 - val_rmse: 0.2043 - 5s/epoch - 833ms/step
# Epoch 2/50
#
# Epoch 2: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.7037 - rmse: 0.6936 - val_loss: 0.4428 - val_rmse: 0.4428 - 395ms/epoch - 66ms/step
# Epoch 3/50
#
# Epoch 3: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.6090 - rmse: 0.6134 - val_loss: 0.2707 - val_rmse: 0.2707 - 394ms/epoch - 66ms/step
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.5474 - rmse: 0.5402 - val_loss: 0.3080 - val_rmse: 0.3080 - 392ms/epoch - 65ms/step
# Epoch 5/50
#
# Epoch 5: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.5054 - rmse: 0.5053 - val_loss: 0.3808 - val_rmse: 0.3808 - 403ms/epoch - 67ms/step
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.4816 - rmse: 0.4751 - val_loss: 0.4213 - val_rmse: 0.4213 - 396ms/epoch - 66ms/step
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.4465 - rmse: 0.4447 - val_loss: 0.4874 - val_rmse: 0.4874 - 398ms/epoch - 66ms/step
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.4226 - rmse: 0.4220 - val_loss: 0.4196 - val_rmse: 0.4196 - 394ms/epoch - 66ms/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.4183 - rmse: 0.4053 - val_loss: 0.4883 - val_rmse: 0.4883 - 385ms/epoch - 64ms/step
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.4121 - rmse: 0.4069 - val_loss: 0.5249 - val_rmse: 0.5249 - 389ms/epoch - 65ms/step
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3907 - rmse: 0.3928 - val_loss: 0.5396 - val_rmse: 0.5396 - 388ms/epoch - 65ms/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3781 - rmse: 0.3693 - val_loss: 0.5510 - val_rmse: 0.5510 - 390ms/epoch - 65ms/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3731 - rmse: 0.3642 - val_loss: 0.5494 - val_rmse: 0.5494 - 364ms/epoch - 61ms/step
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3732 - rmse: 0.3774 - val_loss: 0.6322 - val_rmse: 0.6322 - 406ms/epoch - 68ms/step
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3570 - rmse: 0.3501 - val_loss: 0.6882 - val_rmse: 0.6882 - 386ms/epoch - 64ms/step
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3631 - rmse: 0.3653 - val_loss: 0.6726 - val_rmse: 0.6726 - 353ms/epoch - 59ms/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3553 - rmse: 0.3505 - val_loss: 0.6929 - val_rmse: 0.6929 - 393ms/epoch - 65ms/step
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3472 - rmse: 0.3480 - val_loss: 0.6012 - val_rmse: 0.6012 - 389ms/epoch - 65ms/step
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3341 - rmse: 0.3398 - val_loss: 0.7214 - val_rmse: 0.7214 - 389ms/epoch - 65ms/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3413 - rmse: 0.3365 - val_loss: 0.6895 - val_rmse: 0.6895 - 385ms/epoch - 64ms/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3359 - rmse: 0.3419 - val_loss: 0.6662 - val_rmse: 0.6662 - 391ms/epoch - 65ms/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3404 - rmse: 0.3425 - val_loss: 0.5826 - val_rmse: 0.5826 - 401ms/epoch - 67ms/step
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3431 - rmse: 0.3397 - val_loss: 0.6763 - val_rmse: 0.6763 - 400ms/epoch - 67ms/step
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3305 - rmse: 0.3283 - val_loss: 0.6726 - val_rmse: 0.6726 - 397ms/epoch - 66ms/step
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3205 - rmse: 0.3212 - val_loss: 0.6899 - val_rmse: 0.6899 - 408ms/epoch - 68ms/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3212 - rmse: 0.3188 - val_loss: 0.6981 - val_rmse: 0.6981 - 409ms/epoch - 68ms/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3162 - rmse: 0.3163 - val_loss: 0.5850 - val_rmse: 0.5850 - 408ms/epoch - 68ms/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3192 - rmse: 0.3125 - val_loss: 0.6976 - val_rmse: 0.6976 - 391ms/epoch - 65ms/step
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3225 - rmse: 0.3188 - val_loss: 0.6531 - val_rmse: 0.6531 - 386ms/epoch - 64ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3140 - rmse: 0.3132 - val_loss: 0.6928 - val_rmse: 0.6928 - 396ms/epoch - 66ms/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3134 - rmse: 0.3138 - val_loss: 0.6584 - val_rmse: 0.6584 - 386ms/epoch - 64ms/step
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3036 - rmse: 0.3045 - val_loss: 0.6635 - val_rmse: 0.6635 - 356ms/epoch - 59ms/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3080 - rmse: 0.3080 - val_loss: 0.6109 - val_rmse: 0.6109 - 397ms/epoch - 66ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3051 - rmse: 0.3053 - val_loss: 0.7073 - val_rmse: 0.7073 - 393ms/epoch - 66ms/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3006 - rmse: 0.2954 - val_loss: 0.6300 - val_rmse: 0.6300 - 389ms/epoch - 65ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2909 - rmse: 0.2880 - val_loss: 0.6260 - val_rmse: 0.6260 - 407ms/epoch - 68ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2845 - rmse: 0.2836 - val_loss: 0.6126 - val_rmse: 0.6126 - 398ms/epoch - 66ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.3012 - rmse: 0.3008 - val_loss: 0.5649 - val_rmse: 0.5649 - 409ms/epoch - 68ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2871 - rmse: 0.2880 - val_loss: 0.6504 - val_rmse: 0.6504 - 408ms/epoch - 68ms/step
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2856 - rmse: 0.2847 - val_loss: 0.6301 - val_rmse: 0.6301 - 404ms/epoch - 67ms/step
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2828 - rmse: 0.2825 - val_loss: 0.6994 - val_rmse: 0.6994 - 401ms/epoch - 67ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2855 - rmse: 0.2845 - val_loss: 0.5643 - val_rmse: 0.5643 - 411ms/epoch - 69ms/step
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2766 - rmse: 0.2790 - val_loss: 0.5890 - val_rmse: 0.5890 - 413ms/epoch - 69ms/step
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2739 - rmse: 0.2791 - val_loss: 0.5635 - val_rmse: 0.5635 - 404ms/epoch - 67ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2749 - rmse: 0.2740 - val_loss: 0.5390 - val_rmse: 0.5390 - 382ms/epoch - 64ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2756 - rmse: 0.2762 - val_loss: 0.5871 - val_rmse: 0.5871 - 443ms/epoch - 74ms/step
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2634 - rmse: 0.2567 - val_loss: 0.5493 - val_rmse: 0.5493 - 405ms/epoch - 67ms/step
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2689 - rmse: 0.2694 - val_loss: 0.5943 - val_rmse: 0.5943 - 407ms/epoch - 68ms/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2607 - rmse: 0.2582 - val_loss: 0.5737 - val_rmse: 0.5737 - 415ms/epoch - 69ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.20425
# 6/6 - 0s - loss: 0.2647 - rmse: 0.2592 - val_loss: 0.5997 - val_rmse: 0.5997 - 379ms/epoch - 63ms/step

# %%
from tensorflow.keras.models import load_model

# 저장된 최적의 모델 로드
best_model = load_model('best_model.h5', custom_objects={'rmse': rmse})

# 모델 평가
loss, rmse_v = best_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss}, Test RMSE: {rmse_v}")
# Out:
# Test Loss: 0.1935434192419052, Test RMSE: 0.18476863205432892

# %%
# 원하는 에포크 시작점 설정 (예: 10번째 에포크부터)
start_epoch = 1
history_dict= history.history
# 슬라이싱해서 데이터 제한
epochs = range(start_epoch, len(history_dict['rmse']) + 1)  # 에포크는 10부터 시작
loss = history_dict['rmse'][start_epoch - 1:]              # 10번째 에포크부터
val_loss = history_dict['val_rmse'][start_epoch - 1:]      # 10번째 에포크부터

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, val_loss, label='Validation Loss', marker='x', linestyle='--')
plt.title(f'Training and Validation Loss from Epoch {start_epoch}')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 예측
y_pred = best_model.predict(X_test)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted Prices')
plt.show()
# Out:
# 8/8 [==============================] - 1s 5ms/step

# %%
# RMSE 정의
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))  # Keras 없이 NumPy로 계산

# 예측 수행
y_pred_scaled = best_model.predict(X_test)  # 학습된 모델로 예측 (이미 스케일링된 X_test 사용)

# Test 데이터에서 y_pred_scaled와 같은 샘플 수만큼 슬라이싱
y_test_trimmed = test_y[window_size:].to_numpy()  # 원본 y_test 크기 맞추기

# 복원: y_pred_scaled와 pivot_test_X_scaled를 합쳐서 원래 스케일 복원
pivot_test_X_trimmed = test_X_scaled[window_size:]

# 예측 결과와 입력 데이터를 합침
test_combined = np.hstack([pivot_test_X_trimmed, y_pred_scaled])

# 스케일러로 역변환 (y_pred 복원)
test_combined_restored = scaler.inverse_transform(test_combined)
y_pred_restored = test_combined_restored[:, -1]  # 마지막 열이 복원된 y 예측값

# RMSE 계산 (y_test_trimmed은 복원할 필요 없음)
rmse_value = rmse(y_test_trimmed, y_pred_restored)
print("복원된 데이터 평가 (RMSE):", rmse_value)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test_trimmed, label="Actual")
plt.plot(y_pred_restored, label="Predicted")
plt.legend()
plt.title("Actual vs Predicted Prices (Restored)")
plt.show()
# Out:
# 8/8 [==============================] - 0s 5ms/step
# 복원된 데이터 평가 (RMSE): 4.954645010758732
