# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
train_X = pd.read_excel('train_x_data.xlsx')
train_y = pd.read_excel('train_y_data.xlsx')
test_X = pd.read_excel('test_x_data.xlsx')
test_y = pd.read_excel('test_y_data.xlsx')

train_X
# Out:
#      Commodity       Date  Close Commodity.1     Date.1     Close.1  \
# 0        Cocoa 2018-01-02   1936      Coffee 2018-01-02  130.199997
# 1        Cocoa 2018-01-03   1907      Coffee 2018-01-03  128.600006
# 2        Cocoa 2018-01-04   1905      Coffee 2018-01-04  129.550003
# 3        Cocoa 2018-01-05   1895      Coffee 2018-01-05  128.449997
# 4        Cocoa 2018-01-08   1914      Coffee 2018-01-08  125.150002
# ...        ...        ...    ...         ...        ...         ...
# 1342     Cocoa 2023-06-26   3206      Coffee 2023-06-26  167.949997
# 1343     Cocoa 2023-06-27   3212      Coffee 2023-06-27  169.449997
# 1344     Cocoa 2023-06-28   3292      Coffee 2023-06-28  165.649994
# 1345     Cocoa 2023-06-29   3218      Coffee 2023-06-29  163.600006
# 1346     Cocoa 2023-06-30   3318      Coffee 2023-06-30  161.000000
#
#      Commodity.2     Date.2    Close.2 Commodity.3  ... Close.13  \
# 0         Cotton 2018-01-02  77.500000       Sugar  ...    3.056
# 1         Cotton 2018-01-03  78.110001       Sugar  ...    3.008
# 2         Cotton 2018-01-04  79.250000       Sugar  ...    2.880
# 3         Cotton 2018-01-05  78.010002       Sugar  ...    2.795
# 4         Cotton 2018-01-08  78.139999       Sugar  ...    2.835
# ...          ...        ...        ...         ...  ...      ...
# 1342      Cotton 2023-06-26  77.070000       Sugar  ...    2.791
# 1343      Cotton 2023-06-27  77.639999       Sugar  ...    2.763
# 1344      Cotton 2023-06-28  80.120003       Sugar  ...    2.603
# 1345      Cotton 2023-06-29  81.250000       Sugar  ...    2.701
# 1346      Cotton 2023-06-30  82.839996       Sugar  ...    2.798
#
#        Commodity.14    Date.14    Close.14  Commodity.15    Date.15  \
# 0     Feeder Cattle 2018-01-02  149.524994     Lean Hogs 2018-01-02
# 1     Feeder Cattle 2018-01-03  149.375000     Lean Hogs 2018-01-03
# 2     Feeder Cattle 2018-01-04  149.024994     Lean Hogs 2018-01-04
# 3     Feeder Cattle 2018-01-05  146.625000     Lean Hogs 2018-01-05
# 4     Feeder Cattle 2018-01-08  146.449997     Lean Hogs 2018-01-08
# ...             ...        ...         ...           ...        ...
# 1342  Feeder Cattle 2023-06-26  233.675003     Lean Hogs 2023-06-26
# 1343  Feeder Cattle 2023-06-27  238.500000     Lean Hogs 2023-06-27
# 1344  Feeder Cattle 2023-06-28  240.250000     Lean Hogs 2023-06-28
# 1345  Feeder Cattle 2023-06-29  242.375000     Lean Hogs 2023-06-29
# 1346  Feeder Cattle 2023-06-30  247.574997     Lean Hogs 2023-06-30
#
#        Close.15  Commodity.16    Date.16    Close.16
# 0     70.724998   Live Cattle 2018-01-02  123.349998
# 1     71.050003   Live Cattle 2018-01-03  122.949997
# 2     71.375000   Live Cattle 2018-01-04  122.250000
# 3     71.425003   Live Cattle 2018-01-05  119.250000
# 4     72.974998   Live Cattle 2018-01-08  117.224998
# ...         ...           ...        ...         ...
# 1342  93.400002   Live Cattle 2023-06-26  177.699997
# 1343  94.125000   Live Cattle 2023-06-27  179.300003
# 1344  94.275002   Live Cattle 2023-06-28  179.625000
# 1345  95.449997   Live Cattle 2023-06-29  179.750000
# 1346  95.650002   Live Cattle 2023-06-30  181.500000
#
# [1347 rows x 51 columns]

# %%
# 결측치 확인
print(train_X.isnull().sum())
print(train_y.isnull().sum())
print(test_X.isnull().sum())
print(test_y.isnull().sum())
# Out:
# Commodity       0
# Date            0
# Close           0
# Commodity.1     0
# Date.1          0
# Close.1         0
# Commodity.2     0
# Date.2          0
# Close.2         0
# Commodity.3     0
# Date.3          0
# Close.3         0
# Commodity.4     0
# Date.4          0
# Close.4         0
# Commodity.5     0
# Date.5          0
# Close.5         0
# Commodity.6     0
# Date.6          0
# Close.6         0
# Commodity.7     0
# Date.7          0
# Close.7         0
# Commodity.8     0
# Date.8          0
# Close.8         0
# Commodity.9     0
# Date.9          0
# Close.9         0
# Commodity.10    0
# Date.10         0
# Close.10        0
# Commodity.11    0
# Date.11         0
# Close.11        0
# Commodity.12    0
# Date.12         0
# Close.12        0
# Commodity.13    0
# Date.13         0
# Close.13        0
# Commodity.14    0
# Date.14         0
# Close.14        0
# Commodity.15    0
# Date.15         0
# Close.15        0
# Commodity.16    0
# Date.16         0
# Close.16        0
# dtype: int64
# Commodity    0
# Date         0
# Close        0
# dtype: int64
# Commodity       0
# Date            0
# Close           0
# Commodity.1     0
# Date.1          0
# Close.1         0
# Commodity.2     0
# Date.2          0
# Close.2         0
# Commodity.3     0
# Date.3          0
# Close.3         0
# Commodity.4     0
# Date.4          0
# Close.4         0
# Commodity.5     0
# Date.5          0
# Close.5         0
# Commodity.6     0
# Date.6          0
# Close.6         0
# Commodity.7     0
# Date.7          0
# Close.7         0
# Commodity.8     0
# Date.8          0
# Close.8         0
# Commodity.9     0
# Date.9          0
# Close.9         0
# Commodity.10    0
# Date.10         0
# Close.10        0
# Commodity.11    0
# Date.11         0
# Close.11        0
# Commodity.12    0
# Date.12         0
# Close.12        0
# Commodity.13    0
# Date.13         0
# Close.13        0
# Commodity.14    0
# Date.14         0
# Close.14        0
# Commodity.15    0
# Date.15         0
# Close.15        0
# Commodity.16    0
# Date.16         0
# Close.16        0
# dtype: int64
# Commodity    0
# Date         0
# Close        0
# dtype: int64

# %%
# 3개 단위로 나누기 (예: 'Commodity', 'Date', 'Close')
grouped_train_X_cols = [train_X.columns[i:i+3] for i in range(0, len(train_X.columns), 3)]
grouped_test_X_cols = [test_X.columns[i:i+3] for i in range(0, len(test_X.columns), 3)]
grouped_train_y_cols = [train_y.columns[i:i+3] for i in range(0, len(train_y.columns), 3)]
grouped_test_y_cols = [test_y.columns[i:i+3] for i in range(0, len(test_y.columns), 3)]
grouped_train_X_cols
# Out:
# [Index(['Commodity', 'Date', 'Close'], dtype='object'),
#  Index(['Commodity.1', 'Date.1', 'Close.1'], dtype='object'),
#  Index(['Commodity.2', 'Date.2', 'Close.2'], dtype='object'),
#  Index(['Commodity.3', 'Date.3', 'Close.3'], dtype='object'),
#  Index(['Commodity.4', 'Date.4', 'Close.4'], dtype='object'),
#  Index(['Commodity.5', 'Date.5', 'Close.5'], dtype='object'),
#  Index(['Commodity.6', 'Date.6', 'Close.6'], dtype='object'),
#  Index(['Commodity.7', 'Date.7', 'Close.7'], dtype='object'),
#  Index(['Commodity.8', 'Date.8', 'Close.8'], dtype='object'),
#  Index(['Commodity.9', 'Date.9', 'Close.9'], dtype='object'),
#  Index(['Commodity.10', 'Date.10', 'Close.10'], dtype='object'),
#  Index(['Commodity.11', 'Date.11', 'Close.11'], dtype='object'),
#  Index(['Commodity.12', 'Date.12', 'Close.12'], dtype='object'),
#  Index(['Commodity.13', 'Date.13', 'Close.13'], dtype='object'),
#  Index(['Commodity.14', 'Date.14', 'Close.14'], dtype='object'),
#  Index(['Commodity.15', 'Date.15', 'Close.15'], dtype='object'),
#  Index(['Commodity.16', 'Date.16', 'Close.16'], dtype='object')]

# %%
# Long Format으로 변환
long_train_X_data = []
long_test_X_data = []

for group in grouped_train_X_cols:
    temp = train_X[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_train_X_data.append(temp)

# 모든 그룹을 하나로 합치기
long_train_X = pd.concat(long_train_X_data, ignore_index=True)

for group in grouped_test_X_cols:
    temp = test_X[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_test_X_data.append(temp)

# 모든 그룹을 하나로 합치기
long_test_X = pd.concat(long_test_X_data, ignore_index=True)

# 결과 확인
long_train_X.head()
# Out:
#   Commodity       Date   Close
# 0     Cocoa 2018-01-02  1936.0
# 1     Cocoa 2018-01-03  1907.0
# 2     Cocoa 2018-01-04  1905.0
# 3     Cocoa 2018-01-05  1895.0
# 4     Cocoa 2018-01-08  1914.0

# %%
# Long Format으로 변환
long_train_y_data = []
long_test_y_data = []

for group in grouped_train_y_cols:
    temp = train_y[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_train_y_data.append(temp)

# 모든 그룹을 하나로 합치기
long_train_y = pd.concat(long_train_y_data, ignore_index=True)

for group in grouped_test_y_cols:
    temp = test_y[group]
    temp.columns = ['Commodity', 'Date', 'Close']  # 열 이름을 통일
    long_test_y_data.append(temp)

# 모든 그룹을 하나로 합치기
long_test_y = pd.concat(long_test_y_data, ignore_index=True)

# 결과 확인
long_train_y.head()
# Out:
#          Commodity       Date      Close
# 0  Brent Crude Oil 2018-01-02  66.570000
# 1  Brent Crude Oil 2018-01-03  67.839996
# 2  Brent Crude Oil 2018-01-04  68.070000
# 3  Brent Crude Oil 2018-01-05  67.620003
# 4  Brent Crude Oil 2018-01-08  67.779999

# %%
# 날짜 형식 변환
long_train_X['Date'] = pd.to_datetime(long_train_X['Date'])
long_test_X['Date'] = pd.to_datetime(long_test_X['Date'])
long_train_y['Date'] = pd.to_datetime(long_train_y['Date'])
long_test_y['Date'] = pd.to_datetime(long_test_y['Date'])

# 중복 제거
long_train_X = long_train_X.drop_duplicates()
long_test_X = long_test_X.drop_duplicates()
long_train_y = long_train_y.drop_duplicates()
long_test_y = long_test_y.drop_duplicates()

# 결과 확인
long_train_X
# Out:
#          Commodity       Date        Close
# 0            Cocoa 2018-01-02  1936.000000
# 1            Cocoa 2018-01-03  1907.000000
# 2            Cocoa 2018-01-04  1905.000000
# 3            Cocoa 2018-01-05  1895.000000
# 4            Cocoa 2018-01-08  1914.000000
# ...            ...        ...          ...
# 22894  Live Cattle 2023-06-26   177.699997
# 22895  Live Cattle 2023-06-27   179.300003
# 22896  Live Cattle 2023-06-28   179.625000
# 22897  Live Cattle 2023-06-29   179.750000
# 22898  Live Cattle 2023-06-30   181.500000
#
# [22899 rows x 3 columns]

# %%
# Date 기준 정렬
long_train_X = long_train_X.sort_values(by='Date')
long_test_X = long_train_X.sort_values(by='Date')
long_train_y = long_train_y.sort_values(by='Date')
long_test_y = long_train_y.sort_values(by='Date')

# 결과 확인
long_train_X
# Out:
#            Commodity       Date        Close
# 0              Cocoa 2018-01-02  1936.000000
# 16164         Silver 2018-01-02    17.121000
# 21552    Live Cattle 2018-01-02   123.349998
# 1347          Coffee 2018-01-02   130.199997
# 2694          Cotton 2018-01-02    77.500000
# ...              ...        ...          ...
# 2693          Coffee 2023-06-30   161.000000
# 20204  Feeder Cattle 2023-06-30   247.574997
# 21551      Lean Hogs 2023-06-30    95.650002
# 8081      Rough Rice 2023-06-30  1805.500000
# 22898    Live Cattle 2023-06-30   181.500000
#
# [22899 rows x 3 columns]

# %%
# Date를 인덱스로 설정하고 Pivot
pivot_train_X = long_train_X.pivot(index='Date', columns='Commodity', values='Close')
pivot_test_X = long_test_X.pivot(index='Date', columns='Commodity', values='Close')
pivot_train_y = long_train_y.pivot(index='Date', columns='Commodity', values='Close')
pivot_test_y = long_test_y.pivot(index='Date', columns='Commodity', values='Close')

# MultiIndex 제거
pivot_train_X.columns.name = None
pivot_train_X = pivot_train_X.reset_index()
pivot_train_y.columns.name = None
pivot_train_y = pivot_train_y.reset_index()
pivot_test_X.columns.name = None
pivot_test_X = pivot_test_X.reset_index()
pivot_test_y.columns.name = None
pivot_test_y = pivot_test_y.reset_index()

# 결과 확인
pivot_train_X.head()
# Out:
#         Date   Cocoa      Coffee  Copper     Cotton  Feeder Cattle  \
# 0 2018-01-02  1936.0  130.199997  3.2560  77.500000     149.524994
# 1 2018-01-03  1907.0  128.600006  3.2370  78.110001     149.375000
# 2 2018-01-04  1905.0  129.550003  3.2425  79.250000     149.024994
# 3 2018-01-05  1895.0  128.449997  3.2070  78.010002     146.625000
# 4 2018-01-08  1914.0  125.150002  3.2010  78.139999     146.449997
#
#           Gold  Kansas Wheat  Lean Hogs  Live Cattle  Natural Gas    Oats  \
# 0  1313.699951        434.75  70.724998   123.349998        3.056  242.50
# 1  1316.199951        441.00  71.050003   122.949997        3.008  244.50
# 2  1319.400024        439.75  71.375000   122.250000        2.880  245.75
# 3  1320.300049        437.50  71.425003   119.250000        2.795  248.50
# 4  1318.599976        433.25  72.974998   117.224998        2.835  250.00
#
#      Palladium    Platinum  Rough Rice     Silver  Soybeans  Sugar
# 0  1090.000000  943.799988      1153.5  17.121000    955.00  15.33
# 1  1086.000000  957.799988      1141.0  17.184999    959.75  15.31
# 2  1097.400024  966.099976      1147.5  17.188999    959.25  15.25
# 3  1084.849976  971.200012      1156.5  17.205000    961.50  15.08
# 4  1098.550049  972.299988      1164.5  17.063999    958.25  14.78

# %%
print(pivot_train_X.columns)
print(pivot_test_X.columns)
print(pivot_train_y.columns)
print(pivot_test_y.columns)
pivot_train_y.head()
# Out:
# Index(['Date', 'Cocoa', 'Coffee', 'Copper', 'Cotton', 'Feeder Cattle', 'Gold',
#        'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats',
#        'Palladium', 'Platinum', 'Rough Rice', 'Silver', 'Soybeans', 'Sugar'],
#       dtype='object')
# Index(['Date', 'Cocoa', 'Coffee', 'Copper', 'Cotton', 'Feeder Cattle', 'Gold',
#        'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats',
#        'Palladium', 'Platinum', 'Rough Rice', 'Silver', 'Soybeans', 'Sugar'],
#       dtype='object')
# Index(['Date', 'Brent Crude Oil'], dtype='object')
# Index(['Date', 'Brent Crude Oil'], dtype='object')
#         Date  Brent Crude Oil
# 0 2018-01-02        66.570000
# 1 2018-01-03        67.839996
# 2 2018-01-04        68.070000
# 3 2018-01-05        67.620003
# 4 2018-01-08        67.779999

# %%
pivot_test_X.reset_index(inplace=True)
pivot_train_X.reset_index(inplace=True)
pivot_test_y.reset_index(inplace=True)
pivot_train_y.reset_index(inplace=True)

pivot_train_X.drop('Date',axis=1, inplace=True)
pivot_test_X.drop('Date',axis=1, inplace=True)
pivot_train_y.drop('Date',axis=1, inplace=True)
pivot_test_y.drop('Date',axis=1, inplace=True)

pivot_train_y.head()
# Out:
#    index  Brent Crude Oil
# 0      0        66.570000
# 1      1        67.839996
# 2      2        68.070000
# 3      3        67.620003
# 4      4        67.779999

# %%
# 'index' 열 삭제
pivot_train_X.drop('index', axis=1, inplace=True)
pivot_test_X.drop('index', axis=1, inplace=True)
pivot_train_y.drop('index', axis=1, inplace=True)
pivot_test_y.drop('index', axis=1, inplace=True)

# 결과 확인
pivot_train_y.head()
# Out:
#    Brent Crude Oil
# 0        66.570000
# 1        67.839996
# 2        68.070000
# 3        67.620003
# 4        67.779999

# %%
# 데이터 통합
train_data = pd.concat([pivot_train_X, pivot_train_y], axis=1)
test_data = pd.concat([pivot_test_X, pivot_test_y], axis=1)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)

# 상관관계 계산
correlation = train_data.corr()

# 타겟 변수와의 상관관계 추출
correlation_with_target = correlation['Brent Crude Oil'].sort_values(ascending=False)
print("타겟 변수와의 상관관계:\n", correlation_with_target)
# Out:
# 타겟 변수와의 상관관계:
#  Brent Crude Oil    1.000000
# Cotton             0.819240
# Kansas Wheat       0.782843
# Natural Gas        0.745098
# Coffee             0.731278
# Soybeans           0.687027
# Lean Hogs          0.672630
# Live Cattle        0.638459
# Copper             0.620224
# Oats               0.613573
# Feeder Cattle      0.594026
# Sugar              0.584207
# Rough Rice         0.415543
# Platinum           0.270246
# Silver             0.176611
# Gold               0.127774
# Cocoa              0.085087
# Palladium         -0.030591
# Name: Brent Crude Oil, dtype: float64
# 타겟 변수와의 상관관계:
#  Brent Crude Oil    1.000000
# Cotton             0.819240
# Kansas Wheat       0.782843
# Natural Gas        0.745098
# Coffee             0.731278
# Soybeans           0.687027
# Lean Hogs          0.672630
# Live Cattle        0.638459
# Copper             0.620224
# Oats               0.613573
# Feeder Cattle      0.594026
# Sugar              0.584207
# Rough Rice         0.415543
# Platinum           0.270246
# Silver             0.176611
# Gold               0.127774
# Cocoa              0.085087
# Palladium         -0.030591
# Name: Brent Crude Oil, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 상관관계 히트맵
plt.figure(figsize=(12, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 타겟 변수 제외한 상관관계 기반 Feature Selection
threshold=0.6
correlation_with_target = correlation['Brent Crude Oil'].drop(labels=['Brent Crude Oil'])
selected_features = correlation_with_target[correlation_with_target.abs() > threshold].index.tolist()

print("선택된 변수들:", selected_features)
# Out:
# 선택된 변수들: ['Coffee', 'Copper', 'Cotton', 'Kansas Wheat', 'Lean Hogs', 'Live Cattle', 'Natural Gas', 'Oats', 'Soybeans']

# %%
# 피처 셀렉션
pivot_train_X=pivot_train_X[selected_features]
pivot_test_X=pivot_test_X[selected_features]

pivot_test_X
# Out:
#           Coffee  Copper     Cotton  Kansas Wheat  Lean Hogs  Live Cattle  \
# 0     130.199997  3.2560  77.500000        434.75  70.724998   123.349998
# 1     128.600006  3.2370  78.110001        441.00  71.050003   122.949997
# 2     129.550003  3.2425  79.250000        439.75  71.375000   122.250000
# 3     128.449997  3.2070  78.010002        437.50  71.425003   119.250000
# 4     125.150002  3.2010  78.139999        433.25  72.974998   117.224998
# ...          ...     ...        ...           ...        ...          ...
# 1342  167.949997  3.7865  77.070000        866.50  93.400002   177.699997
# 1343  169.449997  3.7815  77.639999        837.75  94.125000   179.300003
# 1344  165.649994  3.7205  80.120003        800.75  94.275002   179.625000
# 1345  163.600006  3.6775  81.250000        794.25  95.449997   179.750000
# 1346  161.000000  3.7410  82.839996        801.25  95.650002   181.500000
#
#       Natural Gas    Oats  Soybeans
# 0           3.056  242.50    955.00
# 1           3.008  244.50    959.75
# 2           2.880  245.75    959.25
# 3           2.795  248.50    961.50
# 4           2.835  250.00    958.25
# ...           ...     ...       ...
# 1342        2.791  391.25   1521.00
# 1343        2.763  385.00   1495.00
# 1344        2.603  377.00   1451.00
# 1345        2.701  367.75   1483.00
# 1346        2.798  377.25   1557.25
#
# [1347 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np


# X와 y를 합침 (Train)
pivot_train_combined = np.hstack([pivot_train_X, pivot_train_y])
pivot_test_combined = np.hstack([pivot_test_X, pivot_test_y])

# 스케일링 객체 생성
scaler = StandardScaler()

# Train 데이터 스케일링
pivot_train_combined_scaled = scaler.fit_transform(pivot_train_combined)

# Test 데이터 스케일링
pivot_test_combined_scaled = scaler.transform(pivot_test_combined)

# 다시 X와 y로 분리 (Train)
pivot_train_X_scaled = pivot_train_combined_scaled[:, :-1]
pivot_train_y_scaled = pivot_train_combined_scaled[:, -1].reshape(-1, 1)

# 다시 X와 y로 분리 (Test)
pivot_test_X_scaled = pivot_test_combined_scaled[:, :-1]
pivot_test_y_scaled = pivot_test_combined_scaled[:, -1].reshape(-1, 1)

# 결과 확인
print("Scaled Train X:", pivot_train_X_scaled[:5])
print("Scaled Train y:", pivot_train_y_scaled[:5])
# Out:
# Scaled Train X: [[-0.31896259 -0.19448044 -0.30428429 -0.95273171 -0.350508   -0.05303156
#   -0.25792155 -0.90395425 -0.74203782]
#  [-0.35243856 -0.22114479 -0.27476546 -0.92318337 -0.33254535 -0.07342589
#   -0.28513215 -0.89014585 -0.72563201]
#  [-0.33256215 -0.21342607 -0.21959921 -0.92909304 -0.31458312 -0.10911567
#   -0.35769349 -0.8815156  -0.72735893]
#  [-0.35557715 -0.26324623 -0.27960453 -0.93973044 -0.31181951 -0.26207253
#   -0.40587886 -0.86252905 -0.71958776]
#  [-0.42462164 -0.27166659 -0.27331378 -0.95982332 -0.22615294 -0.36531849
#   -0.38320342 -0.85217275 -0.73081279]]
# Scaled Train y: [[-0.21058725]
#  [-0.14499115]
#  [-0.13311134]
#  [-0.15635396]
#  [-0.14809006]]

# %% [markdown]
# ## 윈도우 크기 결정

# %%
def create_windows(X, y, window_size):
    X_windows, y_windows = [], []
    for i in range(len(X) - window_size):
        X_windows.append(X[i:i + window_size])  # .iloc 대신 기본 인덱싱 사용
        y_windows.append(y[i + window_size])    # .iloc 대신 기본 인덱싱 사용
    return np.array(X_windows), np.array(y_windows)

# %%
# 윈도우 크기
window_size = 30

# Train 데이터 슬라이싱
X_train, y_train = create_windows(
    pivot_train_X_scaled,  
    pivot_train_y_scaled,  
    window_size
)

# Test 데이터 슬라이싱
X_test, y_test = create_windows(
    pivot_test_X_scaled,  
    pivot_test_y_scaled,  
    window_size
)

# 결과 확인
print(f"Train X Shape: {X_train.shape}, Train y Shape: {y_train.shape}")
print(f"Test X Shape: {X_test.shape}, Test y Shape: {y_test.shape}")
# Out:
# Train X Shape: (1317, 30, 9), Train y Shape: (1317, 1)
# Test X Shape: (1317, 30, 9), Test y Shape: (1317, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional,TimeDistributed
from tensorflow.keras import backend as K

# RMSE 정의
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# grid LSTM 모델
model = Sequential([
    TimeDistributed(Dense(128, activation='relu', input_shape=(window_size, X_train.shape[2]))),  # 추가 Dense 레이어
    Dropout(0.3),
    Bidirectional(LSTM(64, activation='relu', return_sequences=True)),
    Bidirectional(LSTM(32, activation='relu')),
    Dense(y_train.shape[1])  # 출력 레이어 (타겟 변수 개수에 맞춤)
])

# 모델 컴파일 (loss에 rmse 사용)
model.compile(optimizer='adam', loss=rmse, metrics=[rmse])

# %%
# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10000,  # 에포크 조정
    batch_size=256,  # 배치 크기 조정
    shuffle=True,
    verbose=2,
)
# Out:
# Epoch 1/10000
# 6/6 - 7s - loss: 0.8688 - rmse: 0.8411 - val_loss: 0.5632 - val_rmse: 0.5146 - 7s/epoch - 1s/step
# Epoch 2/10000
# 6/6 - 1s - loss: 0.5971 - rmse: 0.6006 - val_loss: 0.4710 - val_rmse: 0.4179 - 614ms/epoch - 102ms/step
# Epoch 3/10000
# 6/6 - 1s - loss: 0.4921 - rmse: 0.4898 - val_loss: 0.4472 - val_rmse: 0.4109 - 620ms/epoch - 103ms/step
# Epoch 4/10000
# 6/6 - 1s - loss: 0.4618 - rmse: 0.4472 - val_loss: 0.4080 - val_rmse: 0.3772 - 618ms/epoch - 103ms/step
# Epoch 5/10000
# 6/6 - 1s - loss: 0.4124 - rmse: 0.4137 - val_loss: 0.3720 - val_rmse: 0.3360 - 630ms/epoch - 105ms/step
# Epoch 6/10000
# 6/6 - 1s - loss: 0.3939 - rmse: 0.3963 - val_loss: 0.3412 - val_rmse: 0.3077 - 617ms/epoch - 103ms/step
# Epoch 7/10000
# 6/6 - 1s - loss: 0.3593 - rmse: 0.3558 - val_loss: 0.3238 - val_rmse: 0.2928 - 617ms/epoch - 103ms/step
# Epoch 8/10000
# 6/6 - 1s - loss: 0.3266 - rmse: 0.3425 - val_loss: 0.2784 - val_rmse: 0.2504 - 618ms/epoch - 103ms/step
# Epoch 9/10000
# 6/6 - 1s - loss: 0.3253 - rmse: 0.3326 - val_loss: 0.3085 - val_rmse: 0.2839 - 629ms/epoch - 105ms/step
# Epoch 10/10000
# 6/6 - 1s - loss: 0.3071 - rmse: 0.3121 - val_loss: 0.2701 - val_rmse: 0.2440 - 621ms/epoch - 103ms/step
# Epoch 11/10000
# 6/6 - 1s - loss: 0.2919 - rmse: 0.2904 - val_loss: 0.2589 - val_rmse: 0.2390 - 614ms/epoch - 102ms/step
# Epoch 12/10000
# 6/6 - 1s - loss: 0.2695 - rmse: 0.2685 - val_loss: 0.2403 - val_rmse: 0.2191 - 612ms/epoch - 102ms/step
# Epoch 13/10000
# 6/6 - 1s - loss: 0.2477 - rmse: 0.2417 - val_loss: 0.2115 - val_rmse: 0.2020 - 616ms/epoch - 103ms/step
# Epoch 14/10000
# 6/6 - 1s - loss: 0.2340 - rmse: 0.2310 - val_loss: 0.2001 - val_rmse: 0.1915 - 615ms/epoch - 102ms/step
# Epoch 15/10000
# 6/6 - 1s - loss: 0.2113 - rmse: 0.2107 - val_loss: 0.1853 - val_rmse: 0.1717 - 617ms/epoch - 103ms/step
# Epoch 16/10000
# 6/6 - 1s - loss: 0.2004 - rmse: 0.1938 - val_loss: 0.1733 - val_rmse: 0.1648 - 617ms/epoch - 103ms/step
# Epoch 17/10000
# 6/6 - 1s - loss: 0.1922 - rmse: 0.1889 - val_loss: 0.1769 - val_rmse: 0.1703 - 616ms/epoch - 103ms/step
# Epoch 18/10000
# 6/6 - 1s - loss: 0.1859 - rmse: 0.1856 - val_loss: 0.1633 - val_rmse: 0.1564 - 616ms/epoch - 103ms/step
# Epoch 19/10000
# 6/6 - 1s - loss: 0.1831 - rmse: 0.1821 - val_loss: 0.1578 - val_rmse: 0.1490 - 613ms/epoch - 102ms/step
# Epoch 20/10000
# 6/6 - 1s - loss: 0.1703 - rmse: 0.1662 - val_loss: 0.1719 - val_rmse: 0.1618 - 619ms/epoch - 103ms/step
# Epoch 21/10000
# 6/6 - 1s - loss: 0.1764 - rmse: 0.1745 - val_loss: 0.1701 - val_rmse: 0.1582 - 615ms/epoch - 103ms/step
# Epoch 22/10000
# 6/6 - 1s - loss: 0.1645 - rmse: 0.1816 - val_loss: 0.1711 - val_rmse: 0.1606 - 622ms/epoch - 104ms/step
# Epoch 23/10000
# 6/6 - 1s - loss: 0.1657 - rmse: 0.1673 - val_loss: 0.1468 - val_rmse: 0.1398 - 613ms/epoch - 102ms/step
# Epoch 24/10000
# 6/6 - 1s - loss: 0.1607 - rmse: 0.1622 - val_loss: 0.1579 - val_rmse: 0.1484 - 614ms/epoch - 102ms/step
# Epoch 25/10000
# 6/6 - 1s - loss: 0.1612 - rmse: 0.1639 - val_loss: 0.1422 - val_rmse: 0.1355 - 636ms/epoch - 106ms/step
# Epoch 26/10000
# 6/6 - 1s - loss: 0.1540 - rmse: 0.1556 - val_loss: 0.1353 - val_rmse: 0.1377 - 615ms/epoch - 103ms/step
# Epoch 27/10000
# 6/6 - 1s - loss: 0.1492 - rmse: 0.1491 - val_loss: 0.1382 - val_rmse: 0.1372 - 617ms/epoch - 103ms/step
# Epoch 28/10000
# 6/6 - 1s - loss: 0.1552 - rmse: 0.1514 - val_loss: 0.1561 - val_rmse: 0.1467 - 619ms/epoch - 103ms/step
# Epoch 29/10000
# 6/6 - 1s - loss: 0.1563 - rmse: 0.1551 - val_loss: 0.1633 - val_rmse: 0.1557 - 618ms/epoch - 103ms/step
# Epoch 30/10000
# 6/6 - 1s - loss: 0.1622 - rmse: 0.1578 - val_loss: 0.1357 - val_rmse: 0.1294 - 623ms/epoch - 104ms/step
# Epoch 31/10000
# 6/6 - 1s - loss: 0.1509 - rmse: 0.1596 - val_loss: 0.1328 - val_rmse: 0.1260 - 627ms/epoch - 104ms/step
# Epoch 32/10000
# 6/6 - 1s - loss: 0.1481 - rmse: 0.1447 - val_loss: 0.1300 - val_rmse: 0.1268 - 615ms/epoch - 102ms/step
# Epoch 33/10000
# 6/6 - 1s - loss: 0.1440 - rmse: 0.1423 - val_loss: 0.1244 - val_rmse: 0.1188 - 617ms/epoch - 103ms/step
# Epoch 34/10000
# 6/6 - 1s - loss: 0.1492 - rmse: 0.1548 - val_loss: 0.1264 - val_rmse: 0.1207 - 615ms/epoch - 102ms/step
# Epoch 35/10000
# 6/6 - 1s - loss: 0.1437 - rmse: 0.1465 - val_loss: 0.1264 - val_rmse: 0.1285 - 618ms/epoch - 103ms/step
# Epoch 36/10000
# 6/6 - 1s - loss: 0.1385 - rmse: 0.1425 - val_loss: 0.1252 - val_rmse: 0.1192 - 609ms/epoch - 101ms/step
# Epoch 37/10000
# 6/6 - 1s - loss: 0.1360 - rmse: 0.1343 - val_loss: 0.1211 - val_rmse: 0.1180 - 615ms/epoch - 102ms/step
# Epoch 38/10000
# 6/6 - 1s - loss: 0.1312 - rmse: 0.1271 - val_loss: 0.1217 - val_rmse: 0.1186 - 611ms/epoch - 102ms/step
# Epoch 39/10000
# 6/6 - 1s - loss: 0.1291 - rmse: 0.1286 - val_loss: 0.1187 - val_rmse: 0.1171 - 615ms/epoch - 102ms/step
# Epoch 40/10000
# 6/6 - 1s - loss: 0.1334 - rmse: 0.1329 - val_loss: 0.1273 - val_rmse: 0.1217 - 621ms/epoch - 103ms/step
# Epoch 41/10000
# 6/6 - 1s - loss: 0.1430 - rmse: 0.1425 - val_loss: 0.1304 - val_rmse: 0.1239 - 614ms/epoch - 102ms/step
# Epoch 42/10000
# 6/6 - 1s - loss: 0.1434 - rmse: 0.1473 - val_loss: 0.1679 - val_rmse: 0.1587 - 630ms/epoch - 105ms/step
# Epoch 43/10000
# 6/6 - 1s - loss: 0.1565 - rmse: 0.1528 - val_loss: 0.1518 - val_rmse: 0.1484 - 615ms/epoch - 102ms/step
# Epoch 44/10000
# 6/6 - 1s - loss: 0.1465 - rmse: 0.1489 - val_loss: 0.1507 - val_rmse: 0.1435 - 612ms/epoch - 102ms/step
# Epoch 45/10000
# 6/6 - 1s - loss: 0.1533 - rmse: 0.1531 - val_loss: 0.1322 - val_rmse: 0.1322 - 623ms/epoch - 104ms/step
# Epoch 46/10000
# 6/6 - 1s - loss: 0.1386 - rmse: 0.1365 - val_loss: 0.1239 - val_rmse: 0.1189 - 615ms/epoch - 103ms/step
# Epoch 47/10000
# 6/6 - 1s - loss: 0.1340 - rmse: 0.1311 - val_loss: 0.1237 - val_rmse: 0.1199 - 620ms/epoch - 103ms/step
# Epoch 48/10000
# 6/6 - 1s - loss: 0.1383 - rmse: 0.1370 - val_loss: 0.1266 - val_rmse: 0.1199 - 622ms/epoch - 104ms/step
# Epoch 49/10000
# 6/6 - 1s - loss: 0.1338 - rmse: 0.1314 - val_loss: 0.1222 - val_rmse: 0.1190 - 624ms/epoch - 104ms/step
# Epoch 50/10000
# 6/6 - 1s - loss: 0.1390 - rmse: 0.1345 - val_loss: 0.1344 - val_rmse: 0.1306 - 622ms/epoch - 104ms/step
# Epoch 51/10000
# 6/6 - 1s - loss: 0.1302 - rmse: 0.1272 - val_loss: 0.1188 - val_rmse: 0.1137 - 614ms/epoch - 102ms/step
# Epoch 52/10000
# 6/6 - 1s - loss: 0.1280 - rmse: 0.1270 - val_loss: 0.1186 - val_rmse: 0.1142 - 609ms/epoch - 101ms/step
# Epoch 53/10000
# 6/6 - 1s - loss: 0.1246 - rmse: 0.1244 - val_loss: 0.1187 - val_rmse: 0.1148 - 615ms/epoch - 102ms/step
# Epoch 54/10000
# 6/6 - 1s - loss: 0.1341 - rmse: 0.1285 - val_loss: 0.1378 - val_rmse: 0.1367 - 613ms/epoch - 102ms/step
# Epoch 55/10000
# 6/6 - 1s - loss: 0.1341 - rmse: 0.1335 - val_loss: 0.1289 - val_rmse: 0.1235 - 620ms/epoch - 103ms/step
# Epoch 56/10000
# 6/6 - 1s - loss: 0.1339 - rmse: 0.1363 - val_loss: 0.1262 - val_rmse: 0.1195 - 612ms/epoch - 102ms/step
# Epoch 57/10000
# 6/6 - 1s - loss: 0.1342 - rmse: 0.1327 - val_loss: 0.1320 - val_rmse: 0.1287 - 616ms/epoch - 103ms/step
# Epoch 58/10000
# 6/6 - 1s - loss: 0.1335 - rmse: 0.1317 - val_loss: 0.1215 - val_rmse: 0.1178 - 632ms/epoch - 105ms/step
# Epoch 59/10000
# 6/6 - 1s - loss: 0.1308 - rmse: 0.1313 - val_loss: 0.1150 - val_rmse: 0.1099 - 616ms/epoch - 103ms/step
# Epoch 60/10000
# 6/6 - 1s - loss: 0.1294 - rmse: 0.1330 - val_loss: 0.1102 - val_rmse: 0.1056 - 622ms/epoch - 104ms/step
# Epoch 61/10000
# 6/6 - 1s - loss: 0.1224 - rmse: 0.1206 - val_loss: 0.1169 - val_rmse: 0.1150 - 618ms/epoch - 103ms/step
# Epoch 62/10000
# 6/6 - 1s - loss: 0.1180 - rmse: 0.1196 - val_loss: 0.1176 - val_rmse: 0.1159 - 613ms/epoch - 102ms/step
# Epoch 63/10000
# 6/6 - 1s - loss: 0.1245 - rmse: 0.1228 - val_loss: 0.1208 - val_rmse: 0.1156 - 613ms/epoch - 102ms/step
# Epoch 64/10000
# 6/6 - 1s - loss: 0.1249 - rmse: 0.1290 - val_loss: 0.1195 - val_rmse: 0.1219 - 613ms/epoch - 102ms/step
# Epoch 65/10000
# 6/6 - 1s - loss: 0.1316 - rmse: 0.1266 - val_loss: 0.1081 - val_rmse: 0.1041 - 618ms/epoch - 103ms/step
# Epoch 66/10000
# 6/6 - 1s - loss: 0.1221 - rmse: 0.1271 - val_loss: 0.1179 - val_rmse: 0.1169 - 612ms/epoch - 102ms/step
# Epoch 67/10000
# 6/6 - 1s - loss: 0.1183 - rmse: 0.1165 - val_loss: 0.1005 - val_rmse: 0.1042 - 614ms/epoch - 102ms/step
# Epoch 68/10000
# 6/6 - 1s - loss: 0.1224 - rmse: 0.1199 - val_loss: 0.1141 - val_rmse: 0.1151 - 610ms/epoch - 102ms/step
# Epoch 69/10000
# 6/6 - 1s - loss: 0.1203 - rmse: 0.1259 - val_loss: 0.1088 - val_rmse: 0.1065 - 612ms/epoch - 102ms/step
# Epoch 70/10000
# 6/6 - 1s - loss: 0.1177 - rmse: 0.1178 - val_loss: 0.1076 - val_rmse: 0.1037 - 631ms/epoch - 105ms/step
# Epoch 71/10000
# 6/6 - 1s - loss: 0.1234 - rmse: 0.1232 - val_loss: 0.1110 - val_rmse: 0.1062 - 642ms/epoch - 107ms/step
# Epoch 72/10000
# 6/6 - 1s - loss: 0.1197 - rmse: 0.1213 - val_loss: 0.1142 - val_rmse: 0.1116 - 630ms/epoch - 105ms/step
# Epoch 73/10000
# 6/6 - 1s - loss: 0.1224 - rmse: 0.1150 - val_loss: 0.1101 - val_rmse: 0.1118 - 611ms/epoch - 102ms/step
# Epoch 74/10000
# 6/6 - 1s - loss: 0.1175 - rmse: 0.1151 - val_loss: 0.1056 - val_rmse: 0.1035 - 624ms/epoch - 104ms/step
# Epoch 75/10000
# 6/6 - 1s - loss: 0.1177 - rmse: 0.1136 - val_loss: 0.1088 - val_rmse: 0.1082 - 627ms/epoch - 104ms/step
# Epoch 76/10000
# 6/6 - 1s - loss: 0.1158 - rmse: 0.1153 - val_loss: 0.1050 - val_rmse: 0.1072 - 614ms/epoch - 102ms/step
# Epoch 77/10000
# 6/6 - 1s - loss: 0.1141 - rmse: 0.1140 - val_loss: 0.1158 - val_rmse: 0.1122 - 618ms/epoch - 103ms/step
# Epoch 78/10000
# 6/6 - 1s - loss: 0.1210 - rmse: 0.1193 - val_loss: 0.0993 - val_rmse: 0.0969 - 622ms/epoch - 104ms/step
# Epoch 79/10000
# 6/6 - 1s - loss: 0.1200 - rmse: 0.1224 - val_loss: 0.1040 - val_rmse: 0.1035 - 620ms/epoch - 103ms/step
# Epoch 80/10000
# 6/6 - 1s - loss: 0.1205 - rmse: 0.1169 - val_loss: 0.1320 - val_rmse: 0.1257 - 615ms/epoch - 102ms/step
# Epoch 81/10000
# 6/6 - 1s - loss: 0.1257 - rmse: 0.1279 - val_loss: 0.1019 - val_rmse: 0.0982 - 611ms/epoch - 102ms/step
# Epoch 82/10000
# 6/6 - 1s - loss: 0.1269 - rmse: 0.1267 - val_loss: 0.1119 - val_rmse: 0.1075 - 610ms/epoch - 102ms/step
# Epoch 83/10000
# 6/6 - 1s - loss: 0.1194 - rmse: 0.1143 - val_loss: 0.1221 - val_rmse: 0.1183 - 609ms/epoch - 101ms/step
# Epoch 84/10000
# 6/6 - 1s - loss: 0.1187 - rmse: 0.1239 - val_loss: 0.1003 - val_rmse: 0.0967 - 609ms/epoch - 102ms/step
# Epoch 85/10000
# 6/6 - 1s - loss: 0.1156 - rmse: 0.1139 - val_loss: 0.0980 - val_rmse: 0.1000 - 616ms/epoch - 103ms/step
# Epoch 86/10000
# 6/6 - 1s - loss: 0.1165 - rmse: 0.1154 - val_loss: 0.1167 - val_rmse: 0.1131 - 610ms/epoch - 102ms/step
# Epoch 87/10000
# 6/6 - 1s - loss: 0.1144 - rmse: 0.1160 - val_loss: 0.0988 - val_rmse: 0.0962 - 617ms/epoch - 103ms/step
# Epoch 88/10000
# 6/6 - 1s - loss: 0.1165 - rmse: 0.1158 - val_loss: 0.0995 - val_rmse: 0.0961 - 615ms/epoch - 102ms/step
# Epoch 89/10000
# 6/6 - 1s - loss: 0.1106 - rmse: 0.1058 - val_loss: 0.1044 - val_rmse: 0.1005 - 613ms/epoch - 102ms/step
# Epoch 90/10000
# 6/6 - 1s - loss: 0.1118 - rmse: 0.1152 - val_loss: 0.1033 - val_rmse: 0.0997 - 622ms/epoch - 104ms/step
# Epoch 91/10000
# 6/6 - 1s - loss: 0.1145 - rmse: 0.1119 - val_loss: 0.1020 - val_rmse: 0.0994 - 626ms/epoch - 104ms/step
# Epoch 92/10000
# 6/6 - 1s - loss: 0.1078 - rmse: 0.1081 - val_loss: 0.1009 - val_rmse: 0.1001 - 612ms/epoch - 102ms/step
# Epoch 93/10000
# 6/6 - 1s - loss: 0.1094 - rmse: 0.1063 - val_loss: 0.0999 - val_rmse: 0.0970 - 614ms/epoch - 102ms/step
# Epoch 94/10000
# 6/6 - 1s - loss: 0.1113 - rmse: 0.1092 - val_loss: 0.1023 - val_rmse: 0.0984 - 617ms/epoch - 103ms/step
# Epoch 95/10000
# 6/6 - 1s - loss: 0.1070 - rmse: 0.1017 - val_loss: 0.0934 - val_rmse: 0.0920 - 614ms/epoch - 102ms/step
# Epoch 96/10000
# 6/6 - 1s - loss: 0.1066 - rmse: 0.1055 - val_loss: 0.0979 - val_rmse: 0.0982 - 614ms/epoch - 102ms/step
# Epoch 97/10000
# 6/6 - 1s - loss: 0.1077 - rmse: 0.1107 - val_loss: 0.0969 - val_rmse: 0.0987 - 612ms/epoch - 102ms/step
# Epoch 98/10000
# 6/6 - 1s - loss: 0.1022 - rmse: 0.1035 - val_loss: 0.0941 - val_rmse: 0.0927 - 617ms/epoch - 103ms/step
# Epoch 99/10000
# 6/6 - 1s - loss: 0.1096 - rmse: 0.1117 - val_loss: 0.1074 - val_rmse: 0.1079 - 619ms/epoch - 103ms/step
# Epoch 100/10000
# 6/6 - 1s - loss: 0.1104 - rmse: 0.1114 - val_loss: 0.0945 - val_rmse: 0.0924 - 621ms/epoch - 103ms/step
# Epoch 101/10000
# 6/6 - 1s - loss: 0.1116 - rmse: 0.1142 - val_loss: 0.0953 - val_rmse: 0.0933 - 617ms/epoch - 103ms/step
# Epoch 102/10000
# 6/6 - 1s - loss: 0.1135 - rmse: 0.1140 - val_loss: 0.1044 - val_rmse: 0.1006 - 617ms/epoch - 103ms/step
# Epoch 103/10000
# 6/6 - 1s - loss: 0.1095 - rmse: 0.1076 - val_loss: 0.0994 - val_rmse: 0.0985 - 617ms/epoch - 103ms/step
# Epoch 104/10000
# 6/6 - 1s - loss: 0.1079 - rmse: 0.1045 - val_loss: 0.0923 - val_rmse: 0.0928 - 617ms/epoch - 103ms/step
# Epoch 105/10000
# 6/6 - 1s - loss: 0.1053 - rmse: 0.1036 - val_loss: 0.0910 - val_rmse: 0.0891 - 627ms/epoch - 104ms/step
# Epoch 106/10000
# 6/6 - 1s - loss: 0.1072 - rmse: 0.1082 - val_loss: 0.1061 - val_rmse: 0.1028 - 622ms/epoch - 104ms/step
# Epoch 107/10000
# 6/6 - 1s - loss: 0.1116 - rmse: 0.1052 - val_loss: 0.0984 - val_rmse: 0.0959 - 636ms/epoch - 106ms/step
# Epoch 108/10000
# 6/6 - 1s - loss: 0.1073 - rmse: 0.1072 - val_loss: 0.0961 - val_rmse: 0.0968 - 641ms/epoch - 107ms/step
# Epoch 109/10000
# 6/6 - 1s - loss: 0.0997 - rmse: 0.1014 - val_loss: 0.0973 - val_rmse: 0.0973 - 633ms/epoch - 106ms/step
# Epoch 110/10000
# 6/6 - 1s - loss: 0.1049 - rmse: 0.1015 - val_loss: 0.0936 - val_rmse: 0.0929 - 634ms/epoch - 106ms/step
# Epoch 111/10000
# 6/6 - 1s - loss: 0.0988 - rmse: 0.0970 - val_loss: 0.0877 - val_rmse: 0.0871 - 626ms/epoch - 104ms/step
# Epoch 112/10000
# 6/6 - 1s - loss: 0.1017 - rmse: 0.1044 - val_loss: 0.0944 - val_rmse: 0.0919 - 641ms/epoch - 107ms/step
# Epoch 113/10000
# 6/6 - 1s - loss: 0.1023 - rmse: 0.1010 - val_loss: 0.0955 - val_rmse: 0.0937 - 629ms/epoch - 105ms/step
# Epoch 114/10000
# 6/6 - 1s - loss: 0.1022 - rmse: 0.1024 - val_loss: 0.1000 - val_rmse: 0.0995 - 622ms/epoch - 104ms/step
# Epoch 115/10000
# 6/6 - 1s - loss: 0.1033 - rmse: 0.1012 - val_loss: 0.0948 - val_rmse: 0.0934 - 643ms/epoch - 107ms/step
# Epoch 116/10000
# 6/6 - 1s - loss: 0.1064 - rmse: 0.1083 - val_loss: 0.0992 - val_rmse: 0.0965 - 634ms/epoch - 106ms/step
# Epoch 117/10000
# 6/6 - 1s - loss: 0.1091 - rmse: 0.1111 - val_loss: 0.0934 - val_rmse: 0.0915 - 643ms/epoch - 107ms/step
# Epoch 118/10000
# 6/6 - 1s - loss: 0.1063 - rmse: 0.1018 - val_loss: 0.1006 - val_rmse: 0.0969 - 625ms/epoch - 104ms/step
# Epoch 119/10000
# 6/6 - 1s - loss: 0.1075 - rmse: 0.1088 - val_loss: 0.1025 - val_rmse: 0.1034 - 619ms/epoch - 103ms/step
# Epoch 120/10000
# 6/6 - 1s - loss: 0.1041 - rmse: 0.1015 - val_loss: 0.0904 - val_rmse: 0.0907 - 625ms/epoch - 104ms/step
# Epoch 121/10000
# 6/6 - 1s - loss: 0.1004 - rmse: 0.1036 - val_loss: 0.0894 - val_rmse: 0.0877 - 620ms/epoch - 103ms/step
# Epoch 122/10000
# 6/6 - 1s - loss: 0.0985 - rmse: 0.0968 - val_loss: 0.0902 - val_rmse: 0.0880 - 617ms/epoch - 103ms/step
# Epoch 123/10000
# 6/6 - 1s - loss: 0.1048 - rmse: 0.1051 - val_loss: 0.0974 - val_rmse: 0.0959 - 632ms/epoch - 105ms/step
# Epoch 124/10000
# 6/6 - 1s - loss: 0.1008 - rmse: 0.0999 - val_loss: 0.0938 - val_rmse: 0.0926 - 630ms/epoch - 105ms/step
# Epoch 125/10000
# 6/6 - 1s - loss: 0.1008 - rmse: 0.1024 - val_loss: 0.0922 - val_rmse: 0.0904 - 624ms/epoch - 104ms/step
# Epoch 126/10000
# 6/6 - 1s - loss: 0.1029 - rmse: 0.1098 - val_loss: 0.0890 - val_rmse: 0.0884 - 612ms/epoch - 102ms/step
# Epoch 127/10000
# 6/6 - 1s - loss: 0.0975 - rmse: 0.0984 - val_loss: 0.0952 - val_rmse: 0.0967 - 622ms/epoch - 104ms/step
# Epoch 128/10000
# 6/6 - 1s - loss: 0.1034 - rmse: 0.1030 - val_loss: 0.0962 - val_rmse: 0.0934 - 613ms/epoch - 102ms/step
# Epoch 129/10000
# 6/6 - 1s - loss: 0.0990 - rmse: 0.0982 - val_loss: 0.0886 - val_rmse: 0.0867 - 615ms/epoch - 102ms/step
# Epoch 130/10000
# 6/6 - 1s - loss: 0.0998 - rmse: 0.0976 - val_loss: 0.0899 - val_rmse: 0.0879 - 623ms/epoch - 104ms/step
# Epoch 131/10000
# 6/6 - 1s - loss: 0.1008 - rmse: 0.1003 - val_loss: 0.0984 - val_rmse: 0.0985 - 614ms/epoch - 102ms/step
# Epoch 132/10000
# 6/6 - 1s - loss: 0.1004 - rmse: 0.1018 - val_loss: 0.0908 - val_rmse: 0.0886 - 622ms/epoch - 104ms/step
# Epoch 133/10000
# 6/6 - 1s - loss: 0.1046 - rmse: 0.1036 - val_loss: 0.0951 - val_rmse: 0.0927 - 635ms/epoch - 106ms/step
# Epoch 134/10000
# 6/6 - 1s - loss: 0.1043 - rmse: 0.1038 - val_loss: 0.0942 - val_rmse: 0.0933 - 618ms/epoch - 103ms/step
# Epoch 135/10000
# 6/6 - 1s - loss: 0.1002 - rmse: 0.1002 - val_loss: 0.0848 - val_rmse: 0.0838 - 619ms/epoch - 103ms/step
# Epoch 136/10000
# 6/6 - 1s - loss: 0.0937 - rmse: 0.0911 - val_loss: 0.0856 - val_rmse: 0.0844 - 613ms/epoch - 102ms/step
# Epoch 137/10000
# 6/6 - 1s - loss: 0.1003 - rmse: 0.1007 - val_loss: 0.0893 - val_rmse: 0.0880 - 614ms/epoch - 102ms/step
# Epoch 138/10000
# 6/6 - 1s - loss: 0.0949 - rmse: 0.0947 - val_loss: 0.0921 - val_rmse: 0.0912 - 619ms/epoch - 103ms/step
# Epoch 139/10000
# 6/6 - 1s - loss: 0.1008 - rmse: 0.0999 - val_loss: 0.0912 - val_rmse: 0.0899 - 613ms/epoch - 102ms/step
# Epoch 140/10000
# 6/6 - 1s - loss: 0.0966 - rmse: 0.0957 - val_loss: 0.0840 - val_rmse: 0.0828 - 631ms/epoch - 105ms/step
# Epoch 141/10000
# 6/6 - 1s - loss: 0.0979 - rmse: 0.0987 - val_loss: 0.0924 - val_rmse: 0.0929 - 615ms/epoch - 102ms/step
# Epoch 142/10000
# 6/6 - 1s - loss: 0.0955 - rmse: 0.0955 - val_loss: 0.0921 - val_rmse: 0.0934 - 619ms/epoch - 103ms/step
# Epoch 143/10000
# 6/6 - 1s - loss: 0.0980 - rmse: 0.0973 - val_loss: 0.0869 - val_rmse: 0.0853 - 617ms/epoch - 103ms/step
# Epoch 144/10000
# 6/6 - 1s - loss: 0.0984 - rmse: 0.0979 - val_loss: 0.0883 - val_rmse: 0.0896 - 613ms/epoch - 102ms/step
# Epoch 145/10000
# 6/6 - 1s - loss: 0.0990 - rmse: 0.0989 - val_loss: 0.0873 - val_rmse: 0.0875 - 626ms/epoch - 104ms/step
# Epoch 146/10000
# 6/6 - 1s - loss: 0.0953 - rmse: 0.1002 - val_loss: 0.0886 - val_rmse: 0.0874 - 618ms/epoch - 103ms/step
# Epoch 147/10000
# 6/6 - 1s - loss: 0.0988 - rmse: 0.0989 - val_loss: 0.0866 - val_rmse: 0.0858 - 615ms/epoch - 103ms/step
# Epoch 148/10000
# 6/6 - 1s - loss: 0.1001 - rmse: 0.1025 - val_loss: 0.0990 - val_rmse: 0.0990 - 614ms/epoch - 102ms/step
# Epoch 149/10000
# 6/6 - 1s - loss: 0.0999 - rmse: 0.0976 - val_loss: 0.0880 - val_rmse: 0.0875 - 614ms/epoch - 102ms/step
# Epoch 150/10000
# 6/6 - 1s - loss: 0.1017 - rmse: 0.1070 - val_loss: 0.0980 - val_rmse: 0.0952 - 621ms/epoch - 103ms/step
# Epoch 151/10000
# 6/6 - 1s - loss: 0.0994 - rmse: 0.0968 - val_loss: 0.0892 - val_rmse: 0.0894 - 615ms/epoch - 102ms/step
# Epoch 152/10000
# 6/6 - 1s - loss: 0.1005 - rmse: 0.0997 - val_loss: 0.0860 - val_rmse: 0.0852 - 610ms/epoch - 102ms/step
# Epoch 153/10000
# 6/6 - 1s - loss: 0.0980 - rmse: 0.0938 - val_loss: 0.0851 - val_rmse: 0.0839 - 610ms/epoch - 102ms/step
# Epoch 154/10000
# 6/6 - 1s - loss: 0.0949 - rmse: 0.0921 - val_loss: 0.0950 - val_rmse: 0.0958 - 612ms/epoch - 102ms/step
# Epoch 155/10000
# 6/6 - 1s - loss: 0.0961 - rmse: 0.0958 - val_loss: 0.0864 - val_rmse: 0.0850 - 618ms/epoch - 103ms/step
# Epoch 156/10000
# 6/6 - 1s - loss: 0.0976 - rmse: 0.0958 - val_loss: 0.0841 - val_rmse: 0.0838 - 626ms/epoch - 104ms/step
# Epoch 157/10000
# 6/6 - 1s - loss: 0.0908 - rmse: 0.0891 - val_loss: 0.0855 - val_rmse: 0.0839 - 610ms/epoch - 102ms/step
# Epoch 158/10000
# 6/6 - 1s - loss: 0.0923 - rmse: 0.0925 - val_loss: 0.0921 - val_rmse: 0.0914 - 609ms/epoch - 102ms/step
# Epoch 159/10000
# 6/6 - 1s - loss: 0.0972 - rmse: 0.0985 - val_loss: 0.0802 - val_rmse: 0.0796 - 607ms/epoch - 101ms/step
# Epoch 160/10000
# 6/6 - 1s - loss: 0.0961 - rmse: 0.0954 - val_loss: 0.0860 - val_rmse: 0.0849 - 615ms/epoch - 103ms/step
# Epoch 161/10000
# 6/6 - 1s - loss: 0.0924 - rmse: 0.0884 - val_loss: 0.0833 - val_rmse: 0.0832 - 613ms/epoch - 102ms/step
# Epoch 162/10000
# 6/6 - 1s - loss: 0.0922 - rmse: 0.0915 - val_loss: 0.0852 - val_rmse: 0.0841 - 614ms/epoch - 102ms/step
# Epoch 163/10000
# 6/6 - 1s - loss: 0.0905 - rmse: 0.0952 - val_loss: 0.0805 - val_rmse: 0.0797 - 612ms/epoch - 102ms/step
# Epoch 164/10000
# 6/6 - 1s - loss: 0.0900 - rmse: 0.0911 - val_loss: 0.0820 - val_rmse: 0.0827 - 632ms/epoch - 105ms/step
# Epoch 165/10000
# 6/6 - 1s - loss: 0.0918 - rmse: 0.0895 - val_loss: 0.0836 - val_rmse: 0.0825 - 616ms/epoch - 103ms/step
# Epoch 166/10000
# 6/6 - 1s - loss: 0.0959 - rmse: 0.0962 - val_loss: 0.0839 - val_rmse: 0.0834 - 615ms/epoch - 102ms/step
# Epoch 167/10000
# 6/6 - 1s - loss: 0.0908 - rmse: 0.0894 - val_loss: 0.0876 - val_rmse: 0.0860 - 611ms/epoch - 102ms/step
# Epoch 168/10000
# 6/6 - 1s - loss: 0.0931 - rmse: 0.0926 - val_loss: 0.0820 - val_rmse: 0.0818 - 617ms/epoch - 103ms/step
# Epoch 169/10000
# 6/6 - 1s - loss: 0.0950 - rmse: 0.0955 - val_loss: 0.0824 - val_rmse: 0.0812 - 611ms/epoch - 102ms/step
# Epoch 170/10000
# 6/6 - 1s - loss: 0.0946 - rmse: 0.0942 - val_loss: 0.0874 - val_rmse: 0.0880 - 617ms/epoch - 103ms/step
# Epoch 171/10000
# 6/6 - 1s - loss: 0.0947 - rmse: 0.0946 - val_loss: 0.0805 - val_rmse: 0.0795 - 611ms/epoch - 102ms/step
# Epoch 172/10000
# 6/6 - 1s - loss: 0.0899 - rmse: 0.0924 - val_loss: 0.0810 - val_rmse: 0.0799 - 611ms/epoch - 102ms/step
# Epoch 173/10000
# 6/6 - 1s - loss: 0.0907 - rmse: 0.0878 - val_loss: 0.0845 - val_rmse: 0.0829 - 633ms/epoch - 105ms/step
# Epoch 174/10000
# 6/6 - 1s - loss: 0.0920 - rmse: 0.0922 - val_loss: 0.0842 - val_rmse: 0.0828 - 623ms/epoch - 104ms/step
# Epoch 175/10000
# 6/6 - 1s - loss: 0.0988 - rmse: 0.0994 - val_loss: 0.0856 - val_rmse: 0.0840 - 633ms/epoch - 105ms/step
# Epoch 176/10000
# 6/6 - 1s - loss: 0.0899 - rmse: 0.0949 - val_loss: 0.0874 - val_rmse: 0.0853 - 646ms/epoch - 108ms/step
# Epoch 177/10000
# 6/6 - 1s - loss: 0.0907 - rmse: 0.0924 - val_loss: 0.0893 - val_rmse: 0.0893 - 681ms/epoch - 113ms/step
# Epoch 178/10000
# 6/6 - 1s - loss: 0.0950 - rmse: 0.0961 - val_loss: 0.0812 - val_rmse: 0.0803 - 633ms/epoch - 105ms/step
# Epoch 179/10000
# 6/6 - 1s - loss: 0.0964 - rmse: 0.0937 - val_loss: 0.0870 - val_rmse: 0.0852 - 619ms/epoch - 103ms/step
# Epoch 180/10000
# 6/6 - 1s - loss: 0.0903 - rmse: 0.0915 - val_loss: 0.0822 - val_rmse: 0.0812 - 626ms/epoch - 104ms/step
# Epoch 181/10000
# 6/6 - 1s - loss: 0.0894 - rmse: 0.0883 - val_loss: 0.0801 - val_rmse: 0.0795 - 630ms/epoch - 105ms/step
# Epoch 182/10000
# 6/6 - 1s - loss: 0.0894 - rmse: 0.0888 - val_loss: 0.0885 - val_rmse: 0.0877 - 612ms/epoch - 102ms/step
# Epoch 183/10000
# 6/6 - 1s - loss: 0.0906 - rmse: 0.0914 - val_loss: 0.0797 - val_rmse: 0.0789 - 618ms/epoch - 103ms/step
# Epoch 184/10000
# 6/6 - 1s - loss: 0.0924 - rmse: 0.0908 - val_loss: 0.0794 - val_rmse: 0.0787 - 619ms/epoch - 103ms/step
# Epoch 185/10000
# 6/6 - 1s - loss: 0.0912 - rmse: 0.0916 - val_loss: 0.0851 - val_rmse: 0.0838 - 618ms/epoch - 103ms/step
# Epoch 186/10000
# 6/6 - 1s - loss: 0.0858 - rmse: 0.0884 - val_loss: 0.0801 - val_rmse: 0.0790 - 620ms/epoch - 103ms/step
# Epoch 187/10000
# 6/6 - 1s - loss: 0.0906 - rmse: 0.0861 - val_loss: 0.0827 - val_rmse: 0.0817 - 609ms/epoch - 101ms/step
# Epoch 188/10000
# 6/6 - 1s - loss: 0.0931 - rmse: 0.0909 - val_loss: 0.0819 - val_rmse: 0.0804 - 618ms/epoch - 103ms/step
# Epoch 189/10000
# 6/6 - 1s - loss: 0.0987 - rmse: 0.0960 - val_loss: 0.0893 - val_rmse: 0.0880 - 634ms/epoch - 106ms/step
# Epoch 190/10000
# 6/6 - 1s - loss: 0.0937 - rmse: 0.0917 - val_loss: 0.0859 - val_rmse: 0.0837 - 621ms/epoch - 104ms/step
# Epoch 191/10000
# 6/6 - 1s - loss: 0.0909 - rmse: 0.0950 - val_loss: 0.0812 - val_rmse: 0.0805 - 613ms/epoch - 102ms/step
# Epoch 192/10000
# 6/6 - 1s - loss: 0.0929 - rmse: 0.0941 - val_loss: 0.0826 - val_rmse: 0.0809 - 615ms/epoch - 102ms/step
# Epoch 193/10000
# 6/6 - 1s - loss: 0.0896 - rmse: 0.0899 - val_loss: 0.0869 - val_rmse: 0.0864 - 613ms/epoch - 102ms/step
# Epoch 194/10000
# 6/6 - 1s - loss: 0.0927 - rmse: 0.0927 - val_loss: 0.0881 - val_rmse: 0.0861 - 614ms/epoch - 102ms/step
# Epoch 195/10000
# 6/6 - 1s - loss: 0.1007 - rmse: 0.0991 - val_loss: 0.0862 - val_rmse: 0.0857 - 616ms/epoch - 103ms/step
# Epoch 196/10000
# 6/6 - 1s - loss: 0.0949 - rmse: 0.0928 - val_loss: 0.0879 - val_rmse: 0.0870 - 611ms/epoch - 102ms/step
# Epoch 197/10000
# 6/6 - 1s - loss: 0.0917 - rmse: 0.0877 - val_loss: 0.0852 - val_rmse: 0.0854 - 612ms/epoch - 102ms/step
# Epoch 198/10000
# 6/6 - 1s - loss: 0.0910 - rmse: 0.0878 - val_loss: 0.0886 - val_rmse: 0.0863 - 613ms/epoch - 102ms/step
# Epoch 199/10000
# 6/6 - 1s - loss: 0.0973 - rmse: 0.0940 - val_loss: 0.0864 - val_rmse: 0.0846 - 610ms/epoch - 102ms/step
# Epoch 200/10000
# 6/6 - 1s - loss: 0.0968 - rmse: 0.0951 - val_loss: 0.0894 - val_rmse: 0.0873 - 617ms/epoch - 103ms/step
# Epoch 201/10000
# 6/6 - 1s - loss: 0.0910 - rmse: 0.0910 - val_loss: 0.0884 - val_rmse: 0.0863 - 614ms/epoch - 102ms/step
# Epoch 202/10000
# 6/6 - 1s - loss: 0.0928 - rmse: 0.0890 - val_loss: 0.0834 - val_rmse: 0.0818 - 613ms/epoch - 102ms/step
# Epoch 203/10000
# 6/6 - 1s - loss: 0.0881 - rmse: 0.0896 - val_loss: 0.0890 - val_rmse: 0.0881 - 609ms/epoch - 102ms/step
# Epoch 204/10000
# 6/6 - 1s - loss: 0.0960 - rmse: 0.0914 - val_loss: 0.0849 - val_rmse: 0.0832 - 612ms/epoch - 102ms/step
# Epoch 205/10000
# 6/6 - 1s - loss: 0.0944 - rmse: 0.0997 - val_loss: 0.0814 - val_rmse: 0.0811 - 621ms/epoch - 104ms/step
# Epoch 206/10000
# 6/6 - 1s - loss: 0.0896 - rmse: 0.0911 - val_loss: 0.0828 - val_rmse: 0.0820 - 613ms/epoch - 102ms/step
# Epoch 207/10000
# 6/6 - 1s - loss: 0.0906 - rmse: 0.0872 - val_loss: 0.0801 - val_rmse: 0.0798 - 607ms/epoch - 101ms/step
# Epoch 208/10000
# 6/6 - 1s - loss: 0.0929 - rmse: 0.0912 - val_loss: 0.0819 - val_rmse: 0.0814 - 610ms/epoch - 102ms/step
# Epoch 209/10000
# 6/6 - 1s - loss: 0.0862 - rmse: 0.0856 - val_loss: 0.0764 - val_rmse: 0.0760 - 622ms/epoch - 104ms/step
# Epoch 210/10000
# 6/6 - 1s - loss: 0.0869 - rmse: 0.0842 - val_loss: 0.0793 - val_rmse: 0.0788 - 613ms/epoch - 102ms/step
# Epoch 211/10000
# 6/6 - 1s - loss: 0.0852 - rmse: 0.0859 - val_loss: 0.0805 - val_rmse: 0.0792 - 609ms/epoch - 102ms/step
# Epoch 212/10000
# 6/6 - 1s - loss: 0.0864 - rmse: 0.0843 - val_loss: 0.0808 - val_rmse: 0.0802 - 613ms/epoch - 102ms/step
# Epoch 213/10000
# 6/6 - 1s - loss: 0.0853 - rmse: 0.0834 - val_loss: 0.0847 - val_rmse: 0.0828 - 615ms/epoch - 102ms/step
# Epoch 214/10000
# 6/6 - 1s - loss: 0.0861 - rmse: 0.0849 - val_loss: 0.0806 - val_rmse: 0.0794 - 612ms/epoch - 102ms/step
# Epoch 215/10000
# 6/6 - 1s - loss: 0.0912 - rmse: 0.0889 - val_loss: 0.0794 - val_rmse: 0.0783 - 612ms/epoch - 102ms/step
# Epoch 216/10000
# 6/6 - 1s - loss: 0.0884 - rmse: 0.0846 - val_loss: 0.0799 - val_rmse: 0.0785 - 642ms/epoch - 107ms/step
# Epoch 217/10000
# 6/6 - 1s - loss: 0.0887 - rmse: 0.0850 - val_loss: 0.0790 - val_rmse: 0.0784 - 607ms/epoch - 101ms/step
# Epoch 218/10000
# 6/6 - 1s - loss: 0.0895 - rmse: 0.0879 - val_loss: 0.0816 - val_rmse: 0.0803 - 610ms/epoch - 102ms/step
# Epoch 219/10000
# 6/6 - 1s - loss: 0.0882 - rmse: 0.0881 - val_loss: 0.0777 - val_rmse: 0.0787 - 608ms/epoch - 101ms/step
# Epoch 220/10000
# 6/6 - 1s - loss: 0.0858 - rmse: 0.0830 - val_loss: 0.0768 - val_rmse: 0.0788 - 612ms/epoch - 102ms/step
# Epoch 221/10000
# 6/6 - 1s - loss: 0.0881 - rmse: 0.0916 - val_loss: 0.0766 - val_rmse: 0.0766 - 611ms/epoch - 102ms/step
# Epoch 222/10000
# 6/6 - 1s - loss: 0.0855 - rmse: 0.0830 - val_loss: 0.0762 - val_rmse: 0.0757 - 621ms/epoch - 104ms/step
# Epoch 223/10000
# 6/6 - 1s - loss: 0.0840 - rmse: 0.0856 - val_loss: 0.0758 - val_rmse: 0.0761 - 607ms/epoch - 101ms/step
# Epoch 224/10000
# 6/6 - 1s - loss: 0.0837 - rmse: 0.0886 - val_loss: 0.0765 - val_rmse: 0.0755 - 607ms/epoch - 101ms/step
# Epoch 225/10000
# 6/6 - 1s - loss: 0.0856 - rmse: 0.0870 - val_loss: 0.0788 - val_rmse: 0.0792 - 613ms/epoch - 102ms/step
# Epoch 226/10000
# 6/6 - 1s - loss: 0.0880 - rmse: 0.0872 - val_loss: 0.0822 - val_rmse: 0.0810 - 609ms/epoch - 101ms/step
# Epoch 227/10000
# 6/6 - 1s - loss: 0.0912 - rmse: 0.0933 - val_loss: 0.0814 - val_rmse: 0.0802 - 607ms/epoch - 101ms/step
# Epoch 228/10000
# 6/6 - 1s - loss: 0.0861 - rmse: 0.0851 - val_loss: 0.0757 - val_rmse: 0.0753 - 604ms/epoch - 101ms/step
# Epoch 229/10000
# 6/6 - 1s - loss: 0.0848 - rmse: 0.0826 - val_loss: 0.0836 - val_rmse: 0.0826 - 607ms/epoch - 101ms/step
# Epoch 230/10000
# 6/6 - 1s - loss: 0.0899 - rmse: 0.0898 - val_loss: 0.0797 - val_rmse: 0.0794 - 609ms/epoch - 101ms/step
# Epoch 231/10000
# 6/6 - 1s - loss: 0.0898 - rmse: 0.0921 - val_loss: 0.0790 - val_rmse: 0.0782 - 607ms/epoch - 101ms/step
# Epoch 232/10000
# 6/6 - 1s - loss: 0.0868 - rmse: 0.0887 - val_loss: 0.0772 - val_rmse: 0.0764 - 608ms/epoch - 101ms/step
# Epoch 233/10000
# 6/6 - 1s - loss: 0.0885 - rmse: 0.0945 - val_loss: 0.0851 - val_rmse: 0.0850 - 606ms/epoch - 101ms/step
# Epoch 234/10000
# 6/6 - 1s - loss: 0.0846 - rmse: 0.0865 - val_loss: 0.0759 - val_rmse: 0.0760 - 609ms/epoch - 102ms/step
# Epoch 235/10000
# 6/6 - 1s - loss: 0.0877 - rmse: 0.0889 - val_loss: 0.0825 - val_rmse: 0.0804 - 617ms/epoch - 103ms/step
# Epoch 236/10000
# 6/6 - 1s - loss: 0.0887 - rmse: 0.0868 - val_loss: 0.0787 - val_rmse: 0.0775 - 612ms/epoch - 102ms/step
# Epoch 237/10000
# 6/6 - 1s - loss: 0.0867 - rmse: 0.0902 - val_loss: 0.0746 - val_rmse: 0.0742 - 607ms/epoch - 101ms/step
# Epoch 238/10000
# 6/6 - 1s - loss: 0.0844 - rmse: 0.0836 - val_loss: 0.0812 - val_rmse: 0.0825 - 609ms/epoch - 101ms/step
# Epoch 239/10000
# 6/6 - 1s - loss: 0.0867 - rmse: 0.0860 - val_loss: 0.0805 - val_rmse: 0.0804 - 625ms/epoch - 104ms/step
# Epoch 240/10000
# 6/6 - 1s - loss: 0.0872 - rmse: 0.0828 - val_loss: 0.0831 - val_rmse: 0.0813 - 612ms/epoch - 102ms/step
# Epoch 241/10000
# 6/6 - 1s - loss: 0.0912 - rmse: 0.0901 - val_loss: 0.0787 - val_rmse: 0.0772 - 608ms/epoch - 101ms/step
# Epoch 242/10000
# 6/6 - 1s - loss: 0.0877 - rmse: 0.0875 - val_loss: 0.0877 - val_rmse: 0.0859 - 607ms/epoch - 101ms/step
# Epoch 243/10000
# 6/6 - 1s - loss: 0.0907 - rmse: 0.0961 - val_loss: 0.0756 - val_rmse: 0.0754 - 614ms/epoch - 102ms/step
# Epoch 244/10000
# 6/6 - 1s - loss: 0.0841 - rmse: 0.0819 - val_loss: 0.0793 - val_rmse: 0.0793 - 607ms/epoch - 101ms/step
# Epoch 245/10000
# 6/6 - 1s - loss: 0.0859 - rmse: 0.0899 - val_loss: 0.0848 - val_rmse: 0.0827 - 610ms/epoch - 102ms/step
# Epoch 246/10000
# 6/6 - 1s - loss: 0.0900 - rmse: 0.0903 - val_loss: 0.0792 - val_rmse: 0.0797 - 605ms/epoch - 101ms/step
# Epoch 247/10000
# 6/6 - 1s - loss: 0.0893 - rmse: 0.0885 - val_loss: 0.0858 - val_rmse: 0.0843 - 607ms/epoch - 101ms/step
# Epoch 248/10000
# 6/6 - 1s - loss: 0.0865 - rmse: 0.0879 - val_loss: 0.0744 - val_rmse: 0.0736 - 613ms/epoch - 102ms/step
# Epoch 249/10000
# 6/6 - 1s - loss: 0.0859 - rmse: 0.0859 - val_loss: 0.0778 - val_rmse: 0.0769 - 608ms/epoch - 101ms/step
# Epoch 250/10000
# 6/6 - 1s - loss: 0.0862 - rmse: 0.0837 - val_loss: 0.0832 - val_rmse: 0.0831 - 613ms/epoch - 102ms/step
# Epoch 251/10000
# 6/6 - 1s - loss: 0.0867 - rmse: 0.0870 - val_loss: 0.0721 - val_rmse: 0.0720 - 608ms/epoch - 101ms/step
# Epoch 252/10000
# 6/6 - 1s - loss: 0.0844 - rmse: 0.0846 - val_loss: 0.0751 - val_rmse: 0.0750 - 611ms/epoch - 102ms/step
# Epoch 253/10000
# 6/6 - 1s - loss: 0.0828 - rmse: 0.0806 - val_loss: 0.0797 - val_rmse: 0.0816 - 611ms/epoch - 102ms/step
# Epoch 254/10000
# 6/6 - 1s - loss: 0.0843 - rmse: 0.0798 - val_loss: 0.0822 - val_rmse: 0.0817 - 609ms/epoch - 102ms/step
# Epoch 255/10000
# 6/6 - 1s - loss: 0.0917 - rmse: 0.0902 - val_loss: 0.0899 - val_rmse: 0.0876 - 632ms/epoch - 105ms/step
# Epoch 256/10000
# 6/6 - 1s - loss: 0.0920 - rmse: 0.0907 - val_loss: 0.0792 - val_rmse: 0.0780 - 611ms/epoch - 102ms/step
# Epoch 257/10000
# 6/6 - 1s - loss: 0.0872 - rmse: 0.0856 - val_loss: 0.0763 - val_rmse: 0.0758 - 616ms/epoch - 103ms/step
# Epoch 258/10000
# 6/6 - 1s - loss: 0.0866 - rmse: 0.0890 - val_loss: 0.0834 - val_rmse: 0.0836 - 628ms/epoch - 105ms/step
# Epoch 259/10000
# 6/6 - 1s - loss: 0.0863 - rmse: 0.0864 - val_loss: 0.0744 - val_rmse: 0.0738 - 611ms/epoch - 102ms/step
# Epoch 260/10000
# 6/6 - 1s - loss: 0.0848 - rmse: 0.0848 - val_loss: 0.0772 - val_rmse: 0.0761 - 619ms/epoch - 103ms/step
# Epoch 261/10000
# 6/6 - 1s - loss: 0.0832 - rmse: 0.0823 - val_loss: 0.0746 - val_rmse: 0.0745 - 611ms/epoch - 102ms/step
# Epoch 262/10000
# 6/6 - 1s - loss: 0.0807 - rmse: 0.0855 - val_loss: 0.0782 - val_rmse: 0.0774 - 610ms/epoch - 102ms/step
# Epoch 263/10000
# 6/6 - 1s - loss: 0.0832 - rmse: 0.0828 - val_loss: 0.0785 - val_rmse: 0.0773 - 610ms/epoch - 102ms/step
# Epoch 264/10000
# 6/6 - 1s - loss: 0.0882 - rmse: 0.0869 - val_loss: 0.0769 - val_rmse: 0.0761 - 614ms/epoch - 102ms/step
# Epoch 265/10000
# 6/6 - 1s - loss: 0.0809 - rmse: 0.0824 - val_loss: 0.0782 - val_rmse: 0.0769 - 613ms/epoch - 102ms/step
# Epoch 266/10000
# 6/6 - 1s - loss: 0.0856 - rmse: 0.0877 - val_loss: 0.0818 - val_rmse: 0.0806 - 607ms/epoch - 101ms/step
# Epoch 267/10000
# 6/6 - 1s - loss: 0.0857 - rmse: 0.0849 - val_loss: 0.0735 - val_rmse: 0.0735 - 618ms/epoch - 103ms/step
# Epoch 268/10000
# 6/6 - 1s - loss: 0.0810 - rmse: 0.0833 - val_loss: 0.0755 - val_rmse: 0.0744 - 613ms/epoch - 102ms/step
# Epoch 269/10000
# 6/6 - 1s - loss: 0.0806 - rmse: 0.0780 - val_loss: 0.0746 - val_rmse: 0.0741 - 613ms/epoch - 102ms/step
# Epoch 270/10000
# 6/6 - 1s - loss: 0.0825 - rmse: 0.0826 - val_loss: 0.0739 - val_rmse: 0.0756 - 620ms/epoch - 103ms/step
# Epoch 271/10000
# 6/6 - 1s - loss: 0.0811 - rmse: 0.0798 - val_loss: 0.0736 - val_rmse: 0.0731 - 613ms/epoch - 102ms/step
# Epoch 272/10000
# 6/6 - 1s - loss: 0.0801 - rmse: 0.0771 - val_loss: 0.0766 - val_rmse: 0.0762 - 623ms/epoch - 104ms/step
# Epoch 273/10000
# 6/6 - 1s - loss: 0.0807 - rmse: 0.0810 - val_loss: 0.0717 - val_rmse: 0.0720 - 609ms/epoch - 102ms/step
# Epoch 274/10000
# 6/6 - 1s - loss: 0.0794 - rmse: 0.0825 - val_loss: 0.0733 - val_rmse: 0.0731 - 613ms/epoch - 102ms/step
# Epoch 275/10000
# 6/6 - 1s - loss: 0.0801 - rmse: 0.0798 - val_loss: 0.0741 - val_rmse: 0.0734 - 620ms/epoch - 103ms/step
# Epoch 276/10000
# 6/6 - 1s - loss: 0.0802 - rmse: 0.0775 - val_loss: 0.0763 - val_rmse: 0.0753 - 617ms/epoch - 103ms/step
# Epoch 277/10000
# 6/6 - 1s - loss: 0.0824 - rmse: 0.0832 - val_loss: 0.0725 - val_rmse: 0.0724 - 617ms/epoch - 103ms/step
# Epoch 278/10000
# 6/6 - 1s - loss: 0.0817 - rmse: 0.0818 - val_loss: 0.0793 - val_rmse: 0.0785 - 606ms/epoch - 101ms/step
# Epoch 279/10000
# 6/6 - 1s - loss: 0.0818 - rmse: 0.0859 - val_loss: 0.0718 - val_rmse: 0.0712 - 609ms/epoch - 102ms/step
# Epoch 280/10000
# 6/6 - 1s - loss: 0.0796 - rmse: 0.0803 - val_loss: 0.0778 - val_rmse: 0.0768 - 613ms/epoch - 102ms/step
# Epoch 281/10000
# 6/6 - 1s - loss: 0.0874 - rmse: 0.0883 - val_loss: 0.0738 - val_rmse: 0.0743 - 610ms/epoch - 102ms/step
# Epoch 282/10000
# 6/6 - 1s - loss: 0.0813 - rmse: 0.0815 - val_loss: 0.0733 - val_rmse: 0.0727 - 612ms/epoch - 102ms/step
# Epoch 283/10000
# 6/6 - 1s - loss: 0.0833 - rmse: 0.0814 - val_loss: 0.0850 - val_rmse: 0.0826 - 609ms/epoch - 102ms/step
# Epoch 284/10000
# 6/6 - 1s - loss: 0.0844 - rmse: 0.0854 - val_loss: 0.0740 - val_rmse: 0.0733 - 610ms/epoch - 102ms/step
# Epoch 285/10000
# 6/6 - 1s - loss: 0.0882 - rmse: 0.0854 - val_loss: 0.0719 - val_rmse: 0.0728 - 618ms/epoch - 103ms/step
# Epoch 286/10000
# 6/6 - 1s - loss: 0.0832 - rmse: 0.0807 - val_loss: 0.0812 - val_rmse: 0.0810 - 608ms/epoch - 101ms/step
# Epoch 287/10000
# 6/6 - 1s - loss: 0.0878 - rmse: 0.0867 - val_loss: 0.0809 - val_rmse: 0.0816 - 607ms/epoch - 101ms/step
# Epoch 288/10000
# 6/6 - 1s - loss: 0.0890 - rmse: 0.0886 - val_loss: 0.0830 - val_rmse: 0.0832 - 625ms/epoch - 104ms/step
# Epoch 289/10000
# 6/6 - 1s - loss: 0.0844 - rmse: 0.0876 - val_loss: 0.0742 - val_rmse: 0.0741 - 609ms/epoch - 101ms/step
# Epoch 290/10000
# 6/6 - 1s - loss: 0.0853 - rmse: 0.0832 - val_loss: 0.0728 - val_rmse: 0.0724 - 608ms/epoch - 101ms/step
# Epoch 291/10000
# 6/6 - 1s - loss: 0.0846 - rmse: 0.0879 - val_loss: 0.0731 - val_rmse: 0.0726 - 611ms/epoch - 102ms/step
# Epoch 292/10000
# 6/6 - 1s - loss: 0.0809 - rmse: 0.0804 - val_loss: 0.0712 - val_rmse: 0.0708 - 608ms/epoch - 101ms/step
# Epoch 293/10000
# 6/6 - 1s - loss: 0.0799 - rmse: 0.0803 - val_loss: 0.0711 - val_rmse: 0.0726 - 607ms/epoch - 101ms/step
# Epoch 294/10000
# 6/6 - 1s - loss: 0.0787 - rmse: 0.0767 - val_loss: 0.0745 - val_rmse: 0.0760 - 608ms/epoch - 101ms/step
# Epoch 295/10000
# 6/6 - 1s - loss: 0.0806 - rmse: 0.0797 - val_loss: 0.0698 - val_rmse: 0.0696 - 617ms/epoch - 103ms/step
# Epoch 296/10000
# 6/6 - 1s - loss: 0.0781 - rmse: 0.0776 - val_loss: 0.0738 - val_rmse: 0.0740 - 614ms/epoch - 102ms/step
# Epoch 297/10000
# 6/6 - 1s - loss: 0.0842 - rmse: 0.0818 - val_loss: 0.0685 - val_rmse: 0.0689 - 608ms/epoch - 101ms/step
# Epoch 298/10000
# 6/6 - 1s - loss: 0.0795 - rmse: 0.0770 - val_loss: 0.0712 - val_rmse: 0.0707 - 606ms/epoch - 101ms/step
# Epoch 299/10000
# 6/6 - 1s - loss: 0.0789 - rmse: 0.0798 - val_loss: 0.0728 - val_rmse: 0.0721 - 620ms/epoch - 103ms/step
# Epoch 300/10000
# 6/6 - 1s - loss: 0.0825 - rmse: 0.0860 - val_loss: 0.0771 - val_rmse: 0.0782 - 609ms/epoch - 102ms/step
# Epoch 301/10000
# 6/6 - 1s - loss: 0.0827 - rmse: 0.0830 - val_loss: 0.0814 - val_rmse: 0.0811 - 610ms/epoch - 102ms/step
# Epoch 302/10000
# 6/6 - 1s - loss: 0.0863 - rmse: 0.0869 - val_loss: 0.0751 - val_rmse: 0.0744 - 610ms/epoch - 102ms/step
# Epoch 303/10000
# 6/6 - 1s - loss: 0.0801 - rmse: 0.0779 - val_loss: 0.0775 - val_rmse: 0.0763 - 612ms/epoch - 102ms/step
# Epoch 304/10000
# 6/6 - 1s - loss: 0.0838 - rmse: 0.0841 - val_loss: 0.0745 - val_rmse: 0.0741 - 606ms/epoch - 101ms/step
# Epoch 305/10000
# 6/6 - 1s - loss: 0.0818 - rmse: 0.0827 - val_loss: 0.0744 - val_rmse: 0.0752 - 616ms/epoch - 103ms/step
# Epoch 306/10000
# 6/6 - 1s - loss: 0.0835 - rmse: 0.0811 - val_loss: 0.0739 - val_rmse: 0.0766 - 607ms/epoch - 101ms/step
# Epoch 307/10000
# 6/6 - 1s - loss: 0.0824 - rmse: 0.0823 - val_loss: 0.0750 - val_rmse: 0.0746 - 600ms/epoch - 100ms/step
# Epoch 308/10000
# 6/6 - 1s - loss: 0.0784 - rmse: 0.0795 - val_loss: 0.0700 - val_rmse: 0.0706 - 605ms/epoch - 101ms/step
# Epoch 309/10000
# 6/6 - 1s - loss: 0.0779 - rmse: 0.0771 - val_loss: 0.0758 - val_rmse: 0.0746 - 608ms/epoch - 101ms/step
# Epoch 310/10000
# 6/6 - 1s - loss: 0.0787 - rmse: 0.0781 - val_loss: 0.0690 - val_rmse: 0.0685 - 611ms/epoch - 102ms/step
# Epoch 311/10000
# 6/6 - 1s - loss: 0.0796 - rmse: 0.0817 - val_loss: 0.0732 - val_rmse: 0.0755 - 612ms/epoch - 102ms/step
# Epoch 312/10000
# 6/6 - 1s - loss: 0.0771 - rmse: 0.0776 - val_loss: 0.0729 - val_rmse: 0.0726 - 605ms/epoch - 101ms/step
# Epoch 313/10000
# 6/6 - 1s - loss: 0.0817 - rmse: 0.0864 - val_loss: 0.0742 - val_rmse: 0.0736 - 610ms/epoch - 102ms/step
# Epoch 314/10000
# 6/6 - 1s - loss: 0.0834 - rmse: 0.0817 - val_loss: 0.0732 - val_rmse: 0.0736 - 616ms/epoch - 103ms/step
# Epoch 315/10000
# 6/6 - 1s - loss: 0.0840 - rmse: 0.0816 - val_loss: 0.0686 - val_rmse: 0.0684 - 608ms/epoch - 101ms/step
# Epoch 316/10000
# 6/6 - 1s - loss: 0.0796 - rmse: 0.0791 - val_loss: 0.0712 - val_rmse: 0.0718 - 609ms/epoch - 102ms/step
# Epoch 317/10000
# 6/6 - 1s - loss: 0.0804 - rmse: 0.0842 - val_loss: 0.0789 - val_rmse: 0.0801 - 604ms/epoch - 101ms/step
# Epoch 318/10000
# 6/6 - 1s - loss: 0.0814 - rmse: 0.0843 - val_loss: 0.0731 - val_rmse: 0.0724 - 606ms/epoch - 101ms/step
# Epoch 319/10000
# 6/6 - 1s - loss: 0.0829 - rmse: 0.0818 - val_loss: 0.0768 - val_rmse: 0.0754 - 608ms/epoch - 101ms/step
# Epoch 320/10000
# 6/6 - 1s - loss: 0.0836 - rmse: 0.0856 - val_loss: 0.0751 - val_rmse: 0.0746 - 610ms/epoch - 102ms/step
# Epoch 321/10000
# 6/6 - 1s - loss: 0.0833 - rmse: 0.0839 - val_loss: 0.0692 - val_rmse: 0.0689 - 625ms/epoch - 104ms/step
# Epoch 322/10000
# 6/6 - 1s - loss: 0.0809 - rmse: 0.0784 - val_loss: 0.0734 - val_rmse: 0.0726 - 614ms/epoch - 102ms/step
# Epoch 323/10000
# 6/6 - 1s - loss: 0.0807 - rmse: 0.0782 - val_loss: 0.0694 - val_rmse: 0.0692 - 615ms/epoch - 102ms/step
# Epoch 324/10000
# 6/6 - 1s - loss: 0.0792 - rmse: 0.0792 - val_loss: 0.0699 - val_rmse: 0.0699 - 608ms/epoch - 101ms/step
# Epoch 325/10000
# 6/6 - 1s - loss: 0.0824 - rmse: 0.0808 - val_loss: 0.0772 - val_rmse: 0.0768 - 616ms/epoch - 103ms/step
# Epoch 326/10000
# 6/6 - 1s - loss: 0.0806 - rmse: 0.0836 - val_loss: 0.0699 - val_rmse: 0.0695 - 617ms/epoch - 103ms/step
# Epoch 327/10000
# 6/6 - 1s - loss: 0.0814 - rmse: 0.0821 - val_loss: 0.0692 - val_rmse: 0.0697 - 608ms/epoch - 101ms/step
# Epoch 328/10000
# 6/6 - 1s - loss: 0.0785 - rmse: 0.0785 - val_loss: 0.0687 - val_rmse: 0.0694 - 607ms/epoch - 101ms/step
# Epoch 329/10000
# 6/6 - 1s - loss: 0.0755 - rmse: 0.0747 - val_loss: 0.0683 - val_rmse: 0.0680 - 613ms/epoch - 102ms/step
# Epoch 330/10000
# 6/6 - 1s - loss: 0.0772 - rmse: 0.0785 - val_loss: 0.0673 - val_rmse: 0.0680 - 612ms/epoch - 102ms/step
# Epoch 331/10000
# 6/6 - 1s - loss: 0.0769 - rmse: 0.0764 - val_loss: 0.0706 - val_rmse: 0.0702 - 613ms/epoch - 102ms/step
# Epoch 332/10000
# 6/6 - 1s - loss: 0.0768 - rmse: 0.0760 - val_loss: 0.0667 - val_rmse: 0.0672 - 614ms/epoch - 102ms/step
# Epoch 333/10000
# 6/6 - 1s - loss: 0.0762 - rmse: 0.0781 - val_loss: 0.0699 - val_rmse: 0.0700 - 609ms/epoch - 101ms/step
# Epoch 334/10000
# 6/6 - 1s - loss: 0.0750 - rmse: 0.0751 - val_loss: 0.0713 - val_rmse: 0.0706 - 608ms/epoch - 101ms/step
# Epoch 335/10000
# 6/6 - 1s - loss: 0.0760 - rmse: 0.0743 - val_loss: 0.0679 - val_rmse: 0.0677 - 606ms/epoch - 101ms/step
# Epoch 336/10000
# 6/6 - 1s - loss: 0.0765 - rmse: 0.0766 - val_loss: 0.0665 - val_rmse: 0.0670 - 620ms/epoch - 103ms/step
# Epoch 337/10000
# 6/6 - 1s - loss: 0.0744 - rmse: 0.0731 - val_loss: 0.0703 - val_rmse: 0.0703 - 611ms/epoch - 102ms/step
# Epoch 338/10000
# 6/6 - 1s - loss: 0.0741 - rmse: 0.0738 - val_loss: 0.0684 - val_rmse: 0.0681 - 620ms/epoch - 103ms/step
# Epoch 339/10000
# 6/6 - 1s - loss: 0.0770 - rmse: 0.0772 - val_loss: 0.0734 - val_rmse: 0.0726 - 606ms/epoch - 101ms/step
# Epoch 340/10000
# 6/6 - 1s - loss: 0.0771 - rmse: 0.0741 - val_loss: 0.0661 - val_rmse: 0.0670 - 610ms/epoch - 102ms/step
# Epoch 341/10000
# 6/6 - 1s - loss: 0.0782 - rmse: 0.0788 - val_loss: 0.0686 - val_rmse: 0.0682 - 629ms/epoch - 105ms/step
# Epoch 342/10000
# 6/6 - 1s - loss: 0.0772 - rmse: 0.0761 - val_loss: 0.0746 - val_rmse: 0.0777 - 602ms/epoch - 100ms/step
# Epoch 343/10000
# 6/6 - 1s - loss: 0.0791 - rmse: 0.0793 - val_loss: 0.0719 - val_rmse: 0.0716 - 605ms/epoch - 101ms/step
# Epoch 344/10000
# 6/6 - 1s - loss: 0.0794 - rmse: 0.0779 - val_loss: 0.0789 - val_rmse: 0.0777 - 604ms/epoch - 101ms/step
# Epoch 345/10000
# 6/6 - 1s - loss: 0.0804 - rmse: 0.0802 - val_loss: 0.0767 - val_rmse: 0.0758 - 648ms/epoch - 108ms/step
# Epoch 346/10000
# 6/6 - 1s - loss: 0.0811 - rmse: 0.0817 - val_loss: 0.0688 - val_rmse: 0.0694 - 613ms/epoch - 102ms/step
# Epoch 347/10000
# 6/6 - 1s - loss: 0.0748 - rmse: 0.0772 - val_loss: 0.0680 - val_rmse: 0.0684 - 603ms/epoch - 100ms/step
# Epoch 348/10000
# 6/6 - 1s - loss: 0.0785 - rmse: 0.0754 - val_loss: 0.0741 - val_rmse: 0.0728 - 607ms/epoch - 101ms/step
# Epoch 349/10000
# 6/6 - 1s - loss: 0.0791 - rmse: 0.0784 - val_loss: 0.0702 - val_rmse: 0.0702 - 606ms/epoch - 101ms/step
# Epoch 350/10000
# 6/6 - 1s - loss: 0.0764 - rmse: 0.0794 - val_loss: 0.0722 - val_rmse: 0.0710 - 610ms/epoch - 102ms/step
# Epoch 351/10000
# 6/6 - 1s - loss: 0.0803 - rmse: 0.0787 - val_loss: 0.0691 - val_rmse: 0.0685 - 618ms/epoch - 103ms/step
# Epoch 352/10000
# 6/6 - 1s - loss: 0.0818 - rmse: 0.0825 - val_loss: 0.0767 - val_rmse: 0.0766 - 610ms/epoch - 102ms/step
# Epoch 353/10000
# 6/6 - 1s - loss: 0.0766 - rmse: 0.0760 - val_loss: 0.0699 - val_rmse: 0.0689 - 610ms/epoch - 102ms/step
# Epoch 354/10000
# 6/6 - 1s - loss: 0.0764 - rmse: 0.0764 - val_loss: 0.0764 - val_rmse: 0.0758 - 614ms/epoch - 102ms/step
# Epoch 355/10000
# 6/6 - 1s - loss: 0.0787 - rmse: 0.0754 - val_loss: 0.0669 - val_rmse: 0.0673 - 621ms/epoch - 103ms/step
# Epoch 356/10000
# 6/6 - 1s - loss: 0.0756 - rmse: 0.0770 - val_loss: 0.0714 - val_rmse: 0.0705 - 622ms/epoch - 104ms/step
# Epoch 357/10000
# 6/6 - 1s - loss: 0.0752 - rmse: 0.0728 - val_loss: 0.0658 - val_rmse: 0.0659 - 604ms/epoch - 101ms/step
# Epoch 358/10000
# 6/6 - 1s - loss: 0.0767 - rmse: 0.0770 - val_loss: 0.0686 - val_rmse: 0.0703 - 607ms/epoch - 101ms/step
# Epoch 359/10000
# 6/6 - 1s - loss: 0.0716 - rmse: 0.0714 - val_loss: 0.0721 - val_rmse: 0.0718 - 608ms/epoch - 101ms/step
# Epoch 360/10000
# 6/6 - 1s - loss: 0.0764 - rmse: 0.0799 - val_loss: 0.0674 - val_rmse: 0.0671 - 606ms/epoch - 101ms/step
# Epoch 361/10000
# 6/6 - 1s - loss: 0.0734 - rmse: 0.0757 - val_loss: 0.0684 - val_rmse: 0.0681 - 610ms/epoch - 102ms/step
# Epoch 362/10000
# 6/6 - 1s - loss: 0.0750 - rmse: 0.0756 - val_loss: 0.0680 - val_rmse: 0.0679 - 604ms/epoch - 101ms/step
# Epoch 363/10000
# 6/6 - 1s - loss: 0.0788 - rmse: 0.0818 - val_loss: 0.0680 - val_rmse: 0.0680 - 607ms/epoch - 101ms/step
# Epoch 364/10000
# 6/6 - 1s - loss: 0.0783 - rmse: 0.0774 - val_loss: 0.0772 - val_rmse: 0.0754 - 607ms/epoch - 101ms/step
# Epoch 365/10000
# 6/6 - 1s - loss: 0.0797 - rmse: 0.0808 - val_loss: 0.0683 - val_rmse: 0.0689 - 608ms/epoch - 101ms/step
# Epoch 366/10000
# 6/6 - 1s - loss: 0.0730 - rmse: 0.0740 - val_loss: 0.0666 - val_rmse: 0.0665 - 613ms/epoch - 102ms/step
# Epoch 367/10000
# 6/6 - 1s - loss: 0.0741 - rmse: 0.0722 - val_loss: 0.0650 - val_rmse: 0.0660 - 612ms/epoch - 102ms/step
# Epoch 368/10000
# 6/6 - 1s - loss: 0.0735 - rmse: 0.0709 - val_loss: 0.0718 - val_rmse: 0.0713 - 607ms/epoch - 101ms/step
# Epoch 369/10000
# 6/6 - 1s - loss: 0.0760 - rmse: 0.0746 - val_loss: 0.0673 - val_rmse: 0.0671 - 601ms/epoch - 100ms/step
# Epoch 370/10000
# 6/6 - 1s - loss: 0.0774 - rmse: 0.0768 - val_loss: 0.0661 - val_rmse: 0.0669 - 605ms/epoch - 101ms/step
# Epoch 371/10000
# 6/6 - 1s - loss: 0.0734 - rmse: 0.0721 - val_loss: 0.0662 - val_rmse: 0.0660 - 626ms/epoch - 104ms/step
# Epoch 372/10000
# 6/6 - 1s - loss: 0.0744 - rmse: 0.0739 - val_loss: 0.0672 - val_rmse: 0.0676 - 609ms/epoch - 101ms/step
# Epoch 373/10000
# 6/6 - 1s - loss: 0.0775 - rmse: 0.0792 - val_loss: 0.0716 - val_rmse: 0.0715 - 608ms/epoch - 101ms/step
# Epoch 374/10000
# 6/6 - 1s - loss: 0.0779 - rmse: 0.0788 - val_loss: 0.0699 - val_rmse: 0.0691 - 609ms/epoch - 102ms/step
# Epoch 375/10000
# 6/6 - 1s - loss: 0.0771 - rmse: 0.0778 - val_loss: 0.0664 - val_rmse: 0.0662 - 614ms/epoch - 102ms/step
# Epoch 376/10000
# 6/6 - 1s - loss: 0.0750 - rmse: 0.0738 - val_loss: 0.0715 - val_rmse: 0.0733 - 620ms/epoch - 103ms/step
# Epoch 377/10000
# 6/6 - 1s - loss: 0.0774 - rmse: 0.0769 - val_loss: 0.0670 - val_rmse: 0.0671 - 612ms/epoch - 102ms/step
# Epoch 378/10000
# 6/6 - 1s - loss: 0.0790 - rmse: 0.0794 - val_loss: 0.0702 - val_rmse: 0.0693 - 610ms/epoch - 102ms/step
# Epoch 379/10000
# 6/6 - 1s - loss: 0.0752 - rmse: 0.0766 - val_loss: 0.0668 - val_rmse: 0.0678 - 610ms/epoch - 102ms/step
# Epoch 380/10000
# 6/6 - 1s - loss: 0.0743 - rmse: 0.0722 - val_loss: 0.0675 - val_rmse: 0.0667 - 612ms/epoch - 102ms/step
# Epoch 381/10000
# 6/6 - 1s - loss: 0.0772 - rmse: 0.0784 - val_loss: 0.0731 - val_rmse: 0.0727 - 614ms/epoch - 102ms/step
# Epoch 382/10000
# 6/6 - 1s - loss: 0.0803 - rmse: 0.0790 - val_loss: 0.0784 - val_rmse: 0.0766 - 610ms/epoch - 102ms/step
# Epoch 383/10000
# 6/6 - 1s - loss: 0.0828 - rmse: 0.0845 - val_loss: 0.0811 - val_rmse: 0.0824 - 628ms/epoch - 105ms/step
# Epoch 384/10000
# 6/6 - 1s - loss: 0.0778 - rmse: 0.0807 - val_loss: 0.0686 - val_rmse: 0.0697 - 637ms/epoch - 106ms/step
# Epoch 385/10000
# 6/6 - 1s - loss: 0.0758 - rmse: 0.0748 - val_loss: 0.0684 - val_rmse: 0.0686 - 619ms/epoch - 103ms/step
# Epoch 386/10000
# 6/6 - 1s - loss: 0.0762 - rmse: 0.0743 - val_loss: 0.0665 - val_rmse: 0.0671 - 615ms/epoch - 103ms/step
# Epoch 387/10000
# 6/6 - 1s - loss: 0.0729 - rmse: 0.0752 - val_loss: 0.0666 - val_rmse: 0.0666 - 617ms/epoch - 103ms/step
# Epoch 388/10000
# 6/6 - 1s - loss: 0.0756 - rmse: 0.0771 - val_loss: 0.0701 - val_rmse: 0.0731 - 627ms/epoch - 105ms/step
# Epoch 389/10000
# 6/6 - 1s - loss: 0.0770 - rmse: 0.0805 - val_loss: 0.0727 - val_rmse: 0.0721 - 611ms/epoch - 102ms/step
# Epoch 390/10000
# 6/6 - 1s - loss: 0.0834 - rmse: 0.0825 - val_loss: 0.0754 - val_rmse: 0.0742 - 612ms/epoch - 102ms/step
# Epoch 391/10000
# 6/6 - 1s - loss: 0.0760 - rmse: 0.0731 - val_loss: 0.0657 - val_rmse: 0.0655 - 613ms/epoch - 102ms/step
# Epoch 392/10000
# 6/6 - 1s - loss: 0.0726 - rmse: 0.0686 - val_loss: 0.0666 - val_rmse: 0.0670 - 616ms/epoch - 103ms/step
# Epoch 393/10000
# 6/6 - 1s - loss: 0.0749 - rmse: 0.0757 - val_loss: 0.0650 - val_rmse: 0.0650 - 619ms/epoch - 103ms/step
# Epoch 394/10000
# 6/6 - 1s - loss: 0.0728 - rmse: 0.0704 - val_loss: 0.0683 - val_rmse: 0.0694 - 613ms/epoch - 102ms/step
# Epoch 395/10000
# 6/6 - 1s - loss: 0.0733 - rmse: 0.0714 - val_loss: 0.0656 - val_rmse: 0.0658 - 617ms/epoch - 103ms/step
# Epoch 396/10000
# 6/6 - 1s - loss: 0.0733 - rmse: 0.0707 - val_loss: 0.0687 - val_rmse: 0.0683 - 622ms/epoch - 104ms/step
# Epoch 397/10000
# 6/6 - 1s - loss: 0.0730 - rmse: 0.0741 - val_loss: 0.0639 - val_rmse: 0.0636 - 612ms/epoch - 102ms/step
# Epoch 398/10000
# 6/6 - 1s - loss: 0.0719 - rmse: 0.0731 - val_loss: 0.0669 - val_rmse: 0.0661 - 612ms/epoch - 102ms/step
# Epoch 399/10000
# 6/6 - 1s - loss: 0.0732 - rmse: 0.0738 - val_loss: 0.0651 - val_rmse: 0.0653 - 620ms/epoch - 103ms/step
# Epoch 400/10000
# 6/6 - 1s - loss: 0.0753 - rmse: 0.0743 - val_loss: 0.0686 - val_rmse: 0.0692 - 638ms/epoch - 106ms/step
# Epoch 401/10000
# ...
# Epoch 9869/10000
# 6/6 - 1s - loss: 0.0094 - rmse: 0.0095 - val_loss: 0.0068 - val_rmse: 0.0066 - 618ms/epoch - 103ms/step
# Epoch 9870/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0092 - val_loss: 0.0077 - val_rmse: 0.0071 - 656ms/epoch - 109ms/step
# Epoch 9871/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0093 - val_loss: 0.0068 - val_rmse: 0.0067 - 616ms/epoch - 103ms/step
# Epoch 9872/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0098 - val_loss: 0.0071 - val_rmse: 0.0068 - 641ms/epoch - 107ms/step
# Epoch 9873/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0093 - val_loss: 0.0065 - val_rmse: 0.0060 - 619ms/epoch - 103ms/step
# Epoch 9874/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0089 - val_loss: 0.0059 - val_rmse: 0.0054 - 651ms/epoch - 109ms/step
# Epoch 9875/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0086 - val_loss: 0.0072 - val_rmse: 0.0066 - 630ms/epoch - 105ms/step
# Epoch 9876/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0091 - val_loss: 0.0060 - val_rmse: 0.0058 - 628ms/epoch - 105ms/step
# Epoch 9877/10000
# 6/6 - 1s - loss: 0.0086 - rmse: 0.0087 - val_loss: 0.0064 - val_rmse: 0.0060 - 626ms/epoch - 104ms/step
# Epoch 9878/10000
# 6/6 - 1s - loss: 0.0087 - rmse: 0.0089 - val_loss: 0.0062 - val_rmse: 0.0057 - 670ms/epoch - 112ms/step
# Epoch 9879/10000
# 6/6 - 1s - loss: 0.0087 - rmse: 0.0088 - val_loss: 0.0062 - val_rmse: 0.0058 - 630ms/epoch - 105ms/step
# Epoch 9880/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0089 - val_loss: 0.0057 - val_rmse: 0.0057 - 630ms/epoch - 105ms/step
# Epoch 9881/10000
# 6/6 - 1s - loss: 0.0086 - rmse: 0.0087 - val_loss: 0.0069 - val_rmse: 0.0066 - 619ms/epoch - 103ms/step
# Epoch 9882/10000
# 6/6 - 1s - loss: 0.0096 - rmse: 0.0097 - val_loss: 0.0074 - val_rmse: 0.0070 - 650ms/epoch - 108ms/step
# Epoch 9883/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0093 - val_loss: 0.0090 - val_rmse: 0.0084 - 618ms/epoch - 103ms/step
# Epoch 9884/10000
# 6/6 - 1s - loss: 0.0105 - rmse: 0.0102 - val_loss: 0.0092 - val_rmse: 0.0086 - 631ms/epoch - 105ms/step
# Epoch 9885/10000
# 6/6 - 1s - loss: 0.0103 - rmse: 0.0105 - val_loss: 0.0075 - val_rmse: 0.0069 - 623ms/epoch - 104ms/step
# Epoch 9886/10000
# 6/6 - 1s - loss: 0.0100 - rmse: 0.0100 - val_loss: 0.0057 - val_rmse: 0.0054 - 657ms/epoch - 109ms/step
# Epoch 9887/10000
# 6/6 - 1s - loss: 0.0085 - rmse: 0.0086 - val_loss: 0.0064 - val_rmse: 0.0061 - 631ms/epoch - 105ms/step
# Epoch 9888/10000
# 6/6 - 1s - loss: 0.0090 - rmse: 0.0091 - val_loss: 0.0070 - val_rmse: 0.0068 - 618ms/epoch - 103ms/step
# Epoch 9889/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0091 - val_loss: 0.0073 - val_rmse: 0.0070 - 641ms/epoch - 107ms/step
# Epoch 9890/10000
# 6/6 - 1s - loss: 0.0093 - rmse: 0.0091 - val_loss: 0.0069 - val_rmse: 0.0064 - 657ms/epoch - 110ms/step
# Epoch 9891/10000
# 6/6 - 1s - loss: 0.0090 - rmse: 0.0091 - val_loss: 0.0070 - val_rmse: 0.0066 - 629ms/epoch - 105ms/step
# Epoch 9892/10000
# 6/6 - 1s - loss: 0.0094 - rmse: 0.0094 - val_loss: 0.0058 - val_rmse: 0.0056 - 625ms/epoch - 104ms/step
# Epoch 9893/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0091 - val_loss: 0.0065 - val_rmse: 0.0062 - 637ms/epoch - 106ms/step
# Epoch 9894/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0097 - val_loss: 0.0066 - val_rmse: 0.0070 - 638ms/epoch - 106ms/step
# Epoch 9895/10000
# 6/6 - 1s - loss: 0.0087 - rmse: 0.0087 - val_loss: 0.0068 - val_rmse: 0.0066 - 632ms/epoch - 105ms/step
# Epoch 9896/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0088 - val_loss: 0.0058 - val_rmse: 0.0057 - 618ms/epoch - 103ms/step
# Epoch 9897/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0089 - val_loss: 0.0065 - val_rmse: 0.0062 - 626ms/epoch - 104ms/step
# Epoch 9898/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0090 - val_loss: 0.0058 - val_rmse: 0.0055 - 642ms/epoch - 107ms/step
# Epoch 9899/10000
# 6/6 - 1s - loss: 0.0084 - rmse: 0.0085 - val_loss: 0.0062 - val_rmse: 0.0058 - 633ms/epoch - 106ms/step
# Epoch 9900/10000
# 6/6 - 1s - loss: 0.0083 - rmse: 0.0082 - val_loss: 0.0066 - val_rmse: 0.0062 - 621ms/epoch - 103ms/step
# Epoch 9901/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0087 - val_loss: 0.0065 - val_rmse: 0.0062 - 641ms/epoch - 107ms/step
# Epoch 9902/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0084 - val_loss: 0.0063 - val_rmse: 0.0060 - 644ms/epoch - 107ms/step
# Epoch 9903/10000
# 6/6 - 1s - loss: 0.0087 - rmse: 0.0083 - val_loss: 0.0063 - val_rmse: 0.0057 - 629ms/epoch - 105ms/step
# Epoch 9904/10000
# 6/6 - 1s - loss: 0.0086 - rmse: 0.0087 - val_loss: 0.0066 - val_rmse: 0.0061 - 630ms/epoch - 105ms/step
# Epoch 9905/10000
# 6/6 - 1s - loss: 0.0085 - rmse: 0.0079 - val_loss: 0.0063 - val_rmse: 0.0059 - 630ms/epoch - 105ms/step
# Epoch 9906/10000
# 6/6 - 1s - loss: 0.0090 - rmse: 0.0090 - val_loss: 0.0059 - val_rmse: 0.0062 - 651ms/epoch - 109ms/step
# Epoch 9907/10000
# 6/6 - 1s - loss: 0.0084 - rmse: 0.0084 - val_loss: 0.0060 - val_rmse: 0.0058 - 631ms/epoch - 105ms/step
# Epoch 9908/10000
# 6/6 - 1s - loss: 0.0087 - rmse: 0.0087 - val_loss: 0.0062 - val_rmse: 0.0061 - 632ms/epoch - 105ms/step
# Epoch 9909/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0091 - val_loss: 0.0083 - val_rmse: 0.0077 - 630ms/epoch - 105ms/step
# Epoch 9910/10000
# 6/6 - 1s - loss: 0.0100 - rmse: 0.0097 - val_loss: 0.0071 - val_rmse: 0.0069 - 643ms/epoch - 107ms/step
# Epoch 9911/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0089 - val_loss: 0.0075 - val_rmse: 0.0070 - 631ms/epoch - 105ms/step
# Epoch 9912/10000
# 6/6 - 1s - loss: 0.0098 - rmse: 0.0095 - val_loss: 0.0068 - val_rmse: 0.0063 - 622ms/epoch - 104ms/step
# Epoch 9913/10000
# 6/6 - 1s - loss: 0.0094 - rmse: 0.0094 - val_loss: 0.0077 - val_rmse: 0.0072 - 631ms/epoch - 105ms/step
# Epoch 9914/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0089 - val_loss: 0.0076 - val_rmse: 0.0070 - 648ms/epoch - 108ms/step
# Epoch 9915/10000
# 6/6 - 1s - loss: 0.0099 - rmse: 0.0100 - val_loss: 0.0062 - val_rmse: 0.0057 - 645ms/epoch - 108ms/step
# Epoch 9916/10000
# 6/6 - 1s - loss: 0.0085 - rmse: 0.0086 - val_loss: 0.0062 - val_rmse: 0.0057 - 618ms/epoch - 103ms/step
# Epoch 9917/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0090 - val_loss: 0.0075 - val_rmse: 0.0070 - 634ms/epoch - 106ms/step
# Epoch 9918/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0090 - val_loss: 0.0061 - val_rmse: 0.0059 - 643ms/epoch - 107ms/step
# Epoch 9919/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0088 - val_loss: 0.0067 - val_rmse: 0.0064 - 635ms/epoch - 106ms/step
# Epoch 9920/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0094 - val_loss: 0.0068 - val_rmse: 0.0067 - 625ms/epoch - 104ms/step
# Epoch 9921/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0094 - val_loss: 0.0075 - val_rmse: 0.0072 - 632ms/epoch - 105ms/step
# Epoch 9922/10000
# 6/6 - 1s - loss: 0.0101 - rmse: 0.0099 - val_loss: 0.0066 - val_rmse: 0.0064 - 674ms/epoch - 112ms/step
# Epoch 9923/10000
# 6/6 - 1s - loss: 0.0090 - rmse: 0.0091 - val_loss: 0.0075 - val_rmse: 0.0074 - 640ms/epoch - 107ms/step
# Epoch 9924/10000
# 6/6 - 1s - loss: 0.0115 - rmse: 0.0114 - val_loss: 0.0092 - val_rmse: 0.0085 - 628ms/epoch - 105ms/step
# Epoch 9925/10000
# 6/6 - 1s - loss: 0.0136 - rmse: 0.0134 - val_loss: 0.0102 - val_rmse: 0.0093 - 634ms/epoch - 106ms/step
# Epoch 9926/10000
# 6/6 - 1s - loss: 0.0144 - rmse: 0.0142 - val_loss: 0.0092 - val_rmse: 0.0084 - 647ms/epoch - 108ms/step
# Epoch 9927/10000
# 6/6 - 1s - loss: 0.0130 - rmse: 0.0127 - val_loss: 0.0112 - val_rmse: 0.0101 - 632ms/epoch - 105ms/step
# Epoch 9928/10000
# 6/6 - 1s - loss: 0.0131 - rmse: 0.0162 - val_loss: 0.0110 - val_rmse: 0.0100 - 626ms/epoch - 104ms/step
# Epoch 9929/10000
# 6/6 - 1s - loss: 0.0117 - rmse: 0.0114 - val_loss: 0.0082 - val_rmse: 0.0075 - 636ms/epoch - 106ms/step
# Epoch 9930/10000
# 6/6 - 1s - loss: 0.0122 - rmse: 0.0124 - val_loss: 0.0077 - val_rmse: 0.0072 - 644ms/epoch - 107ms/step
# Epoch 9931/10000
# 6/6 - 1s - loss: 0.0114 - rmse: 0.0113 - val_loss: 0.0090 - val_rmse: 0.0083 - 632ms/epoch - 105ms/step
# Epoch 9932/10000
# 6/6 - 1s - loss: 0.0117 - rmse: 0.0115 - val_loss: 0.0099 - val_rmse: 0.0090 - 623ms/epoch - 104ms/step
# Epoch 9933/10000
# 6/6 - 1s - loss: 0.0131 - rmse: 0.0125 - val_loss: 0.0077 - val_rmse: 0.0070 - 640ms/epoch - 107ms/step
# Epoch 9934/10000
# 6/6 - 1s - loss: 0.0112 - rmse: 0.0112 - val_loss: 0.0079 - val_rmse: 0.0073 - 652ms/epoch - 109ms/step
# Epoch 9935/10000
# 6/6 - 1s - loss: 0.0120 - rmse: 0.0123 - val_loss: 0.0087 - val_rmse: 0.0085 - 639ms/epoch - 106ms/step
# Epoch 9936/10000
# 6/6 - 1s - loss: 0.0114 - rmse: 0.0114 - val_loss: 0.0085 - val_rmse: 0.0079 - 624ms/epoch - 104ms/step
# Epoch 9937/10000
# 6/6 - 1s - loss: 0.0105 - rmse: 0.0109 - val_loss: 0.0077 - val_rmse: 0.0071 - 632ms/epoch - 105ms/step
# Epoch 9938/10000
# 6/6 - 1s - loss: 0.0116 - rmse: 0.0117 - val_loss: 0.0079 - val_rmse: 0.0072 - 659ms/epoch - 110ms/step
# Epoch 9939/10000
# 6/6 - 1s - loss: 0.0105 - rmse: 0.0100 - val_loss: 0.0072 - val_rmse: 0.0066 - 635ms/epoch - 106ms/step
# Epoch 9940/10000
# 6/6 - 1s - loss: 0.0100 - rmse: 0.0098 - val_loss: 0.0065 - val_rmse: 0.0059 - 637ms/epoch - 106ms/step
# Epoch 9941/10000
# 6/6 - 1s - loss: 0.0093 - rmse: 0.0096 - val_loss: 0.0080 - val_rmse: 0.0073 - 637ms/epoch - 106ms/step
# Epoch 9942/10000
# 6/6 - 1s - loss: 0.0100 - rmse: 0.0099 - val_loss: 0.0072 - val_rmse: 0.0066 - 648ms/epoch - 108ms/step
# Epoch 9943/10000
# 6/6 - 1s - loss: 0.0104 - rmse: 0.0102 - val_loss: 0.0089 - val_rmse: 0.0082 - 640ms/epoch - 107ms/step
# Epoch 9944/10000
# 6/6 - 1s - loss: 0.0105 - rmse: 0.0107 - val_loss: 0.0072 - val_rmse: 0.0065 - 625ms/epoch - 104ms/step
# Epoch 9945/10000
# 6/6 - 1s - loss: 0.0101 - rmse: 0.0103 - val_loss: 0.0068 - val_rmse: 0.0063 - 650ms/epoch - 108ms/step
# Epoch 9946/10000
# 6/6 - 1s - loss: 0.0094 - rmse: 0.0095 - val_loss: 0.0072 - val_rmse: 0.0068 - 650ms/epoch - 108ms/step
# Epoch 9947/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0097 - val_loss: 0.0066 - val_rmse: 0.0060 - 631ms/epoch - 105ms/step
# Epoch 9948/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0101 - val_loss: 0.0074 - val_rmse: 0.0072 - 630ms/epoch - 105ms/step
# Epoch 9949/10000
# 6/6 - 1s - loss: 0.0100 - rmse: 0.0095 - val_loss: 0.0078 - val_rmse: 0.0073 - 632ms/epoch - 105ms/step
# Epoch 9950/10000
# 6/6 - 1s - loss: 0.0103 - rmse: 0.0101 - val_loss: 0.0068 - val_rmse: 0.0067 - 646ms/epoch - 108ms/step
# Epoch 9951/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0095 - val_loss: 0.0065 - val_rmse: 0.0060 - 634ms/epoch - 106ms/step
# Epoch 9952/10000
# 6/6 - 1s - loss: 0.0102 - rmse: 0.0106 - val_loss: 0.0066 - val_rmse: 0.0062 - 641ms/epoch - 107ms/step
# Epoch 9953/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0103 - val_loss: 0.0077 - val_rmse: 0.0072 - 632ms/epoch - 105ms/step
# Epoch 9954/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0098 - val_loss: 0.0081 - val_rmse: 0.0075 - 655ms/epoch - 109ms/step
# Epoch 9955/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0094 - val_loss: 0.0080 - val_rmse: 0.0075 - 633ms/epoch - 106ms/step
# Epoch 9956/10000
# 6/6 - 1s - loss: 0.0102 - rmse: 0.0103 - val_loss: 0.0085 - val_rmse: 0.0082 - 622ms/epoch - 104ms/step
# Epoch 9957/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0097 - val_loss: 0.0073 - val_rmse: 0.0067 - 642ms/epoch - 107ms/step
# Epoch 9958/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0096 - val_loss: 0.0097 - val_rmse: 0.0090 - 642ms/epoch - 107ms/step
# Epoch 9959/10000
# 6/6 - 1s - loss: 0.0109 - rmse: 0.0108 - val_loss: 0.0074 - val_rmse: 0.0071 - 643ms/epoch - 107ms/step
# Epoch 9960/10000
# 6/6 - 1s - loss: 0.0104 - rmse: 0.0104 - val_loss: 0.0079 - val_rmse: 0.0077 - 625ms/epoch - 104ms/step
# Epoch 9961/10000
# 6/6 - 1s - loss: 0.0094 - rmse: 0.0092 - val_loss: 0.0066 - val_rmse: 0.0065 - 633ms/epoch - 106ms/step
# Epoch 9962/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0087 - val_loss: 0.0063 - val_rmse: 0.0060 - 643ms/epoch - 107ms/step
# Epoch 9963/10000
# 6/6 - 1s - loss: 0.0093 - rmse: 0.0089 - val_loss: 0.0064 - val_rmse: 0.0060 - 632ms/epoch - 105ms/step
# Epoch 9964/10000
# 6/6 - 1s - loss: 0.0090 - rmse: 0.0091 - val_loss: 0.0062 - val_rmse: 0.0058 - 626ms/epoch - 104ms/step
# Epoch 9965/10000
# 6/6 - 1s - loss: 0.0090 - rmse: 0.0090 - val_loss: 0.0069 - val_rmse: 0.0065 - 629ms/epoch - 105ms/step
# Epoch 9966/10000
# 6/6 - 1s - loss: 0.0093 - rmse: 0.0100 - val_loss: 0.0061 - val_rmse: 0.0057 - 673ms/epoch - 112ms/step
# Epoch 9967/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0089 - val_loss: 0.0069 - val_rmse: 0.0063 - 629ms/epoch - 105ms/step
# Epoch 9968/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0088 - val_loss: 0.0062 - val_rmse: 0.0061 - 635ms/epoch - 106ms/step
# Epoch 9969/10000
# 6/6 - 1s - loss: 0.0093 - rmse: 0.0093 - val_loss: 0.0063 - val_rmse: 0.0060 - 621ms/epoch - 104ms/step
# Epoch 9970/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0090 - val_loss: 0.0068 - val_rmse: 0.0064 - 655ms/epoch - 109ms/step
# Epoch 9971/10000
# 6/6 - 1s - loss: 0.0085 - rmse: 0.0085 - val_loss: 0.0068 - val_rmse: 0.0063 - 622ms/epoch - 104ms/step
# Epoch 9972/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0104 - val_loss: 0.0064 - val_rmse: 0.0059 - 635ms/epoch - 106ms/step
# Epoch 9973/10000
# 6/6 - 1s - loss: 0.0085 - rmse: 0.0088 - val_loss: 0.0064 - val_rmse: 0.0059 - 626ms/epoch - 104ms/step
# Epoch 9974/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0092 - val_loss: 0.0062 - val_rmse: 0.0057 - 651ms/epoch - 109ms/step
# Epoch 9975/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0090 - val_loss: 0.0065 - val_rmse: 0.0060 - 618ms/epoch - 103ms/step
# Epoch 9976/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0092 - val_loss: 0.0079 - val_rmse: 0.0072 - 633ms/epoch - 106ms/step
# Epoch 9977/10000
# 6/6 - 1s - loss: 0.0104 - rmse: 0.0100 - val_loss: 0.0063 - val_rmse: 0.0058 - 628ms/epoch - 105ms/step
# Epoch 9978/10000
# 6/6 - 1s - loss: 0.0096 - rmse: 0.0095 - val_loss: 0.0077 - val_rmse: 0.0071 - 656ms/epoch - 109ms/step
# Epoch 9979/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0095 - val_loss: 0.0072 - val_rmse: 0.0070 - 628ms/epoch - 105ms/step
# Epoch 9980/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0092 - val_loss: 0.0072 - val_rmse: 0.0066 - 643ms/epoch - 107ms/step
# Epoch 9981/10000
# 6/6 - 1s - loss: 0.0090 - rmse: 0.0088 - val_loss: 0.0073 - val_rmse: 0.0073 - 621ms/epoch - 103ms/step
# Epoch 9982/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0090 - val_loss: 0.0070 - val_rmse: 0.0066 - 660ms/epoch - 110ms/step
# Epoch 9983/10000
# 6/6 - 1s - loss: 0.0093 - rmse: 0.0092 - val_loss: 0.0069 - val_rmse: 0.0065 - 618ms/epoch - 103ms/step
# Epoch 9984/10000
# 6/6 - 1s - loss: 0.0094 - rmse: 0.0096 - val_loss: 0.0065 - val_rmse: 0.0066 - 615ms/epoch - 103ms/step
# Epoch 9985/10000
# 6/6 - 1s - loss: 0.0098 - rmse: 0.0099 - val_loss: 0.0091 - val_rmse: 0.0086 - 627ms/epoch - 105ms/step
# Epoch 9986/10000
# 6/6 - 1s - loss: 0.0103 - rmse: 0.0101 - val_loss: 0.0064 - val_rmse: 0.0063 - 658ms/epoch - 110ms/step
# Epoch 9987/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0097 - val_loss: 0.0067 - val_rmse: 0.0063 - 639ms/epoch - 107ms/step
# Epoch 9988/10000
# 6/6 - 1s - loss: 0.0087 - rmse: 0.0087 - val_loss: 0.0066 - val_rmse: 0.0060 - 623ms/epoch - 104ms/step
# Epoch 9989/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0086 - val_loss: 0.0063 - val_rmse: 0.0061 - 627ms/epoch - 104ms/step
# Epoch 9990/10000
# 6/6 - 1s - loss: 0.0086 - rmse: 0.0085 - val_loss: 0.0063 - val_rmse: 0.0061 - 643ms/epoch - 107ms/step
# Epoch 9991/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0088 - val_loss: 0.0065 - val_rmse: 0.0061 - 635ms/epoch - 106ms/step
# Epoch 9992/10000
# 6/6 - 1s - loss: 0.0093 - rmse: 0.0091 - val_loss: 0.0070 - val_rmse: 0.0066 - 623ms/epoch - 104ms/step
# Epoch 9993/10000
# 6/6 - 1s - loss: 0.0092 - rmse: 0.0093 - val_loss: 0.0061 - val_rmse: 0.0062 - 630ms/epoch - 105ms/step
# Epoch 9994/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0086 - val_loss: 0.0070 - val_rmse: 0.0070 - 660ms/epoch - 110ms/step
# Epoch 9995/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0090 - val_loss: 0.0067 - val_rmse: 0.0064 - 633ms/epoch - 106ms/step
# Epoch 9996/10000
# 6/6 - 1s - loss: 0.0089 - rmse: 0.0089 - val_loss: 0.0077 - val_rmse: 0.0077 - 631ms/epoch - 105ms/step
# Epoch 9997/10000
# 6/6 - 1s - loss: 0.0095 - rmse: 0.0096 - val_loss: 0.0072 - val_rmse: 0.0071 - 633ms/epoch - 105ms/step
# Epoch 9998/10000
# 6/6 - 1s - loss: 0.0097 - rmse: 0.0094 - val_loss: 0.0060 - val_rmse: 0.0060 - 644ms/epoch - 107ms/step
# Epoch 9999/10000
# 6/6 - 1s - loss: 0.0091 - rmse: 0.0090 - val_loss: 0.0067 - val_rmse: 0.0067 - 630ms/epoch - 105ms/step
# Epoch 10000/10000
# 6/6 - 1s - loss: 0.0088 - rmse: 0.0087 - val_loss: 0.0065 - val_rmse: 0.0063 - 631ms/epoch - 105ms/step

# %%
# 모델 평가
loss, rmse  = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss}, Test RMSE: {rmse}")
# Out:
# Test Loss: 0.006104409694671631, Test RMSE: 0.006044298410415649

# %%
import matplotlib.pyplot as plt

# Assuming `history.history` contains training and validation loss data
# Replace with your actual `history.history` dictionary
history_dict = history.history  # If using your model's `history` object

# Extract loss values
loss = history_dict['rmse']        # Training loss
val_loss = history_dict['val_rmse']  # Validation loss
epochs = range(1, len(loss) + 1)

# Plot Training and Validation Loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, val_loss, label='Validation Loss', marker='x', linestyle='--')
plt.title('Training and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 예측
y_pred = model.predict(X_test)
rmse_value = rmse(y_test, y_pred)
print("정규화 데이터 평가 (RMSE):", rmse_value)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted Prices')
plt.show()
# Out:
# 42/42 [==============================] - 1s 25ms/step
# 정규화 데이터 평가 (RMSE): tf.Tensor(0.0065824574002038665, shape=(), dtype=float64)

# %%
# RMSE 정의
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))
# 예측 수행
y_pred_scaled = model.predict(X_test)  # 학습된 모델로 예측 (이미 스케일링된 X_test 사용)

# 복원: y_pred_scaled와 pivot_test_X_scaled를 합쳐서 원래 스케일 복원
# Test 데이터에서 y_pred_scaled와 같은 샘플 수만큼 슬라이싱 -> 윈도우 처리하면서 잘림
pivot_test_X_trimmed = pivot_test_X_scaled[:y_pred_scaled.shape[0]]

# 예측 결과와 입력 데이터를 합침
test_combined = np.hstack([pivot_test_X_trimmed, y_pred_scaled])

# 스케일러로 역변환
test_combined_restored = scaler.inverse_transform(test_combined)

# 복원된 y 값 추출
y_pred_restored = test_combined_restored[:, -1]  # 마지막 열이 복원된 y 예측값

# 실제 y 값 복원
y_test_restored = pivot_test_y_scaled[:y_pred_scaled.shape[0]]  # 테스트 y 데이터를 맞춘 크기로 자르기
y_test_restored = scaler.inverse_transform(
    np.hstack([pivot_test_X_trimmed, y_test_restored])
)[:, -1]  # 실제 y 값 복원


rmse_value = rmse(y_test_restored, y_pred_restored)
print("복원된 데이터 평가 (RMSE):", rmse_value)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test_restored, label="Actual")
plt.plot(y_pred_restored, label="Predicted")
plt.legend()
plt.title("Actual vs Predicted Prices (Restored)")
plt.show()
# Out:
# 42/42 [==============================] - 1s 24ms/step
# 복원된 데이터 평가 (RMSE): tf.Tensor(9.456491320883558, shape=(), dtype=float64)
